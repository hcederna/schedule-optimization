# %% [markdown]
# # Compare Single Optimized & Previous NESCAC Volleyball Conference Schedules - Chart Creation
#
# Let's compare the single optimized schedules with the previous NESCAC schedules to see how we did.

# %%
from src.configuration import *
from src.analyze_schedule import *

print("Loading necessary information ...\n")
best_single_optimized_schedule_analysis_df = pd.read_pickle(BEST_SINGLE_OPTIMIZED_SCHEDULE_ANALYSIS_FILENAME)
nescac_schedule_analysis_df = pd.read_pickle(NESCAC_SCHEDULE_ANALYSIS_FILENAME)

print("Creating single schedule comparison DataFrame ...\n")
single_schedule_comparison_df = best_single_optimized_schedule_analysis_df.append(nescac_schedule_analysis_df)
single_schedule_comparison_df = create_score_columns(
    analysis_df=single_schedule_comparison_df, 
    score_total_cost_weight=SCHEDULE_SCORE_TOTAL_COST_WEIGHT)
single_schedule_comparison_df = create_optimized_change_columns(single_schedule_comparison_df)
single_schedule_comparison_df = single_schedule_comparison_df.sort_values('Schedule Score', ascending=True).reset_index(drop=True)

print("Saving single schedule comparison to pickle ...")
single_schedule_comparison_df.to_pickle(SINGLE_SCHEDULE_COMPARISON_FILENAME)
print("... Saved as \"{}\"".format(SINGLE_SCHEDULE_COMPARISON_FILENAME))

print("Preview:")
display(single_schedule_comparison_df.head())
print()
# Out:
# Loading necessary information ...
#
# Creating single schedule comparison DataFrame ...
#
# Saving single schedule comparison to pickle ...
# ... Saved as "results/single/single_schedule_comparison.pickle"
# Preview:
#    Total Distance  Total Duration in Hours  Total Overnight  Total Cost  \
# 0           10688                      188               18    54892.56
# 1            9900                      176               18    52434.00
# 2            9886                      173               18    52390.32
# 3            9940                      176               18    52558.80
# 4            9974                      176               18    52664.88
#
#    Total Distance Cost  Total Overnight Cost  \
# 0             33346.56                 21546
# 1             30888.00                 21546
# 2             30844.32                 21546
# 3             31012.80                 21546
# 4             31118.88                 21546
#
#                                   Team Distance Dict  \
# 0  {0: 984, 1: 1282, 2: 1118, 3: 1360, 4: 684, 5:...
# 1  {0: 678, 1: 1172, 2: 1106, 3: 1348, 4: 1018, 5...
# 2  {0: 1012, 1: 662, 2: 750, 3: 956, 4: 566, 5: 1...
# 3  {0: 998, 1: 774, 2: 664, 3: 968, 4: 566, 5: 15...
# 4  {0: 998, 1: 748, 2: 738, 3: 846, 4: 566, 5: 17...
#
#                          Team Duration in Hours Dict  \
# 0  {0: 17, 1: 22, 2: 19, 3: 22, 4: 11, 5: 24, 6: ...
# 1  {0: 12, 1: 21, 2: 19, 3: 22, 4: 16, 5: 24, 6: ...
# 2  {0: 19, 1: 12, 2: 13, 3: 15, 4: 10, 5: 25, 6: ...
# 3  {0: 19, 1: 14, 2: 12, 3: 16, 4: 10, 5: 26, 6: ...
# 4  {0: 19, 1: 13, 2: 13, 3: 14, 4: 10, 5: 28, 6: ...
#
#   Team Duration in Hours (Min, Max, Rng)  Team Duration in Hours Average  ...  \
# 0                            (9, 24, 15)                       17.000000  ...
# 1                            (5, 24, 19)                       15.909091  ...
# 2                            (6, 26, 20)                       15.727273  ...
# 3                            (7, 26, 19)                       16.000000  ...
# 4                            (7, 28, 21)                       15.909091  ...
#
#    s8_2_3 Total Duration in Hours Change  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#   s8_2_3 Total Duration in Hours Percent Change s8_2_3 Total Overnight Change  \
# 0                                           NaN                           NaN
# 1                                           NaN                           NaN
# 2                                           NaN                           NaN
# 3                                           NaN                           NaN
# 4                                           NaN                           NaN
#
#    s8_2_3 Total Overnight Percent Change  s9_2_3 Total Cost Change  \
# 0                                    NaN                       NaN
# 1                                    NaN                       NaN
# 2                                    NaN                       NaN
# 3                                    NaN                       NaN
# 4                                    NaN                       NaN
#
#   s9_2_3 Total Cost Percent Change s9_2_3 Total Duration in Hours Change  \
# 0                              NaN                                   NaN
# 1                              NaN                                   NaN
# 2                              NaN                                   NaN
# 3                              NaN                                   NaN
# 4                              NaN                                   NaN
#
#   s9_2_3 Total Duration in Hours Percent Change  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#    s9_2_3 Total Overnight Change s9_2_3 Total Overnight Percent Change
# 0                            NaN                                   NaN
# 1                            NaN                                   NaN
# 2                            NaN                                   NaN
# 3                            NaN                                   NaN
# 4                            NaN                                   NaN
#
# [5 rows x 100 columns]

# %% [markdown]
# Let's take a closer look at the single schedule comparison between optimized and previous schedules.

# %%
from src.configuration import *
from src.figures import *


# Select two optimized single schedules to compare to the previous NESCAC single schedules
selected_idxs = [0, 5]

columns = [
#     'Schedule ID',
    'Abbreviated Schedule ID',
    'Schedule Score',
    'Total Cost',
    'Team Experience Score',
    'Team Home Game (Min, Max, Rng)',
    'Team Home Game Fairness Index',
    'Team Home Game Score',        
    'Team Duration in Hours Average',
    'Team Duration in Hours Fairness Index',
    'Team Duration in Hours Score',    
    'Team Overnight Average',
    'Team Overnight Fairness Index', 
    'Team Overnight Score', 
    'Test Success',    
#     'Total Distance',
    'Total Duration in Hours',        
    'Total Overnight', 
#     'Total Distance Cost',
#     'Total Overnight Cost',
#     'Matches List'
]


print("Loading necessary information ...\n")
single_schedule_comparison_df = pd.read_pickle(SINGLE_SCHEDULE_COMPARISON_FILENAME)

# Comment/uncomment to see full DF or just selected indexes
single_schedule_comparison_df = single_schedule_comparison_df.iloc[selected_idxs][columns].append(single_schedule_comparison_df[10:21][columns])

print("Applying color gradient to NESCAC schedule analysis DataFrame ...\n")
color_gradient_df = apply_color_gradient(single_schedule_comparison_df, columns)

print("Displaying NESCAC schedule analysis DataFrame ...")
display(color_gradient_df)
# Out:
# Loading necessary information ...
#
# Applying color gradient to NESCAC schedule analysis DataFrame ...
#
# Displaying NESCAC schedule analysis DataFrame ...
# <style  type="text/css" >
#     #T_4cb49520_68a4_11ea_a31e_8c2937e6cdeerow0_col1 {
#             background-color:  #2e8b57;
#             color:  #000000;
#         }    #T_4cb49520_68a4_11ea_a31e_8c2937e6cdeerow0_col2 {
#             background-color:  #2e8b57;
#             color:  #000000;
#         }    #T_4cb49520_68a4_11ea_a31e_8c2937e6cdeerow0_col3 {
#             background-color:  #2e8b57;
#             color:  #000000;
#         }    #T_4cb49520_68a4_11ea_a31e_8c2937e6cdeerow0_col5 {
#             background-color:  #81bb9a;
#             color:  #000000;
#         }    #T_4cb49520_68a4_11ea_a31e_8c2937e6cdeerow0_col6 {
#             background-color:  #81bb9a;
#             color:  #000000;
#         }    #T_4cb49520_68a4_11ea_a31e_8c2937e6cdeerow0_col7 {
#             background-color:  #2e8b57;
#             color:  #000000;
#         }    #T_4cb49520_68a4_11ea_a31e_8c2937e6cdeerow0_col8 {
#             background-color:  #93c5a9;
#             color:  #000000;
#         }    #T_4cb49520_68a4_11ea_a31e_8c2937e6cdeerow0_col9 {
#             background-color:  #328e5b;
#             color:  #000000;
#         }    #T_4cb49520_68a4_11ea_a31e_8c2937e6cdeerow0_col10 {
#             background-color:  #2e8b57;
#             color:  #000000;
#         }    #T_4cb49520_68a4_11ea_a31e_8c2937e6cdeerow0_col11 {
#             background-color:  #4d9d70;
#             color:  #000000;
#         }    #T_4cb49520_68a4_11ea_a31e_8c2937e6cdeerow0_col12 {
#             background-color:  #2e8b57;
#             color:  #000000;
#         }    #T_4cb49520_68a4_11ea_a31e_8c2937e6cdeerow0_col14 {
#             background-color:  #2e8b57;
#             color:  #000000;
#         }    #T_4cb49520_68a4_11ea_a31e_8c2937e6cdeerow0_col15 {
#             background-color:  #2e8b57;
#             color:  #000000;
#         }    #T_4cb49520_68a4_11ea_a31e_8c2937e6cdeerow1_col1 {
#             background-color:  #489a6c;
#             color:  #000000;
#         }    #T_4cb49520_68a4_11ea_a31e_8c2937e6cdeerow1_col2 {
#             background-color:  #2f8b58;
#             color:  #000000;
#         }    #T_4cb49520_68a4_11ea_a31e_8c2937e6cdeerow1_col3 {
#             background-color:  #87be9f;
#             color:  #000000;
#         }    #T_4cb49520_68a4_11ea_a31e_8c2937e6cdeerow1_col5 {
#             background-color:  #4e9d71;
#             color:  #000000;
#         }    #T_4cb49520_68a4_11ea_a31e_8c2937e6cdeerow1_col6 {
#             background-color:  #4e9d71;
#             color:  #000000;
#         }    #T_4cb49520_68a4_11ea_a31e_8c2937e6cdeerow1_col7 {
#             background-color:  #38915f;
#             color:  #000000;
#         }    #T_4cb49520_68a4_11ea_a31e_8c2937e6cdeerow1_col8 {
#             background-color:  #ecf9f1;
#             color:  #000000;
#         }    #T_4cb49520_68a4_11ea_a31e_8c2937e6cdeerow1_col9 {
#             background-color:  #6fb08c;
#             color:  #000000;
#         }    #T_4cb49520_68a4_11ea_a31e_8c2937e6cdeerow1_col10 {
#             background-color:  #2e8b57;
#             color:  #000000;
#         }    #T_4cb49520_68a4_11ea_a31e_8c2937e6cdeerow1_col11 {
#             background-color:  #ecf9f1;
#             color:  #000000;
#         }    #T_4cb49520_68a4_11ea_a31e_8c2937e6cdeerow1_col12 {
#             background-color:  #aed5bf;
#             color:  #000000;
#         }    #T_4cb49520_68a4_11ea_a31e_8c2937e6cdeerow1_col14 {
#             background-color:  #38915f;
#             color:  #000000;
#         }    #T_4cb49520_68a4_11ea_a31e_8c2937e6cdeerow1_col15 {
#             background-color:  #2e8b57;
#             color:  #000000;
#         }    #T_4cb49520_68a4_11ea_a31e_8c2937e6cdeerow2_col1 {
#             background-color:  #8fc3a6;
#             color:  #000000;
#         }    #T_4cb49520_68a4_11ea_a31e_8c2937e6cdeerow2_col2 {
#             background-color:  #89bfa1;
#             color:  #000000;
#         }    #T_4cb49520_68a4_11ea_a31e_8c2937e6cdeerow2_col3 {
#             background-color:  #9bcab0;
#             color:  #000000;
#         }    #T_4cb49520_68a4_11ea_a31e_8c2937e6cdeerow2_col5 {
#             background-color:  #75b491;
#             color:  #000000;
#         }    #T_4cb49520_68a4_11ea_a31e_8c2937e6cdeerow2_col6 {
#             background-color:  #75b491;
#             color:  #000000;
#         }    #T_4cb49520_68a4_11ea_a31e_8c2937e6cdeerow2_col7 {
#             background-color:  #409566;
#             color:  #000000;
#         }    #T_4cb49520_68a4_11ea_a31e_8c2937e6cdeerow2_col8 {
#             background-color:  #72b38f;
#             color:  #000000;
#         }    #T_4cb49520_68a4_11ea_a31e_8c2937e6cdeerow2_col9 {
#             background-color:  #2e8b57;
#             color:  #000000;
#         }    #T_4cb49520_68a4_11ea_a31e_8c2937e6cdeerow2_col10 {
#             background-color:  #d5ebdf;
#             color:  #000000;
#         }    #T_4cb49520_68a4_11ea_a31e_8c2937e6cdeerow2_col11 {
#             background-color:  #7bb795;
#             color:  #000000;
#         }    #T_4cb49520_68a4_11ea_a31e_8c2937e6cdeerow2_col12 {
#             background-color:  #e7f6ed;
#             color:  #000000;
#         }    #T_4cb49520_68a4_11ea_a31e_8c2937e6cdeerow2_col14 {
#             background-color:  #3c9363;
#             color:  #000000;
#         }    #T_4cb49520_68a4_11ea_a31e_8c2937e6cdeerow2_col15 {
#             background-color:  #d5ebdf;
#             color:  #000000;
#         }    #T_4cb49520_68a4_11ea_a31e_8c2937e6cdeerow3_col1 {
#             background-color:  #96c7ac;
#             color:  #000000;
#         }    #T_4cb49520_68a4_11ea_a31e_8c2937e6cdeerow3_col2 {
#             background-color:  #7eb998;
#             color:  #000000;
#         }    #T_4cb49520_68a4_11ea_a31e_8c2937e6cdeerow3_col3 {
#             background-color:  #d0e8da;
#             color:  #000000;
#         }    #T_4cb49520_68a4_11ea_a31e_8c2937e6cdeerow3_col5 {
#             background-color:  #75b491;
#             color:  #000000;
#         }    #T_4cb49520_68a4_11ea_a31e_8c2937e6cdeerow3_col6 {
#             background-color:  #75b491;
#             color:  #000000;
#         }    #T_4cb49520_68a4_11ea_a31e_8c2937e6cdeerow3_col7 {
#             background-color:  #55a277;
#             color:  #000000;
#         }    #T_4cb49520_68a4_11ea_a31e_8c2937e6cdeerow3_col8 {
#             background-color:  #ecf9f1;
#             color:  #000000;
#         }    #T_4cb49520_68a4_11ea_a31e_8c2937e6cdeerow3_col9 {
#             background-color:  #85bd9e;
#             color:  #000000;
#         }    #T_4cb49520_68a4_11ea_a31e_8c2937e6cdeerow3_col10 {
#             background-color:  #a4cfb7;
#             color:  #000000;
#         }    #T_4cb49520_68a4_11ea_a31e_8c2937e6cdeerow3_col11 {
#             background-color:  #b0d6c1;
#             color:  #000000;
#         }    #T_4cb49520_68a4_11ea_a31e_8c2937e6cdeerow3_col12 {
#             background-color:  #e7f6ee;
#             color:  #000000;
#         }    #T_4cb49520_68a4_11ea_a31e_8c2937e6cdeerow3_col14 {
#             background-color:  #4f9e72;
#             color:  #000000;
#         }    #T_4cb49520_68a4_11ea_a31e_8c2937e6cdeerow3_col15 {
#             background-color:  #a5d0b8;
#             color:  #000000;
#         }    #T_4cb49520_68a4_11ea_a31e_8c2937e6cdeerow4_col1 {
#             background-color:  #a8d2ba;
#             color:  #000000;
#         }    #T_4cb49520_68a4_11ea_a31e_8c2937e6cdeerow4_col2 {
#             background-color:  #8dc2a4;
#             color:  #000000;
#         }    #T_4cb49520_68a4_11ea_a31e_8c2937e6cdeerow4_col3 {
#             background-color:  #ecf9f1;
#             color:  #000000;
#         }    #T_4cb49520_68a4_11ea_a31e_8c2937e6cdeerow4_col5 {
#             background-color:  #ecf9f1;
#             color:  #000000;
#         }    #T_4cb49520_68a4_11ea_a31e_8c2937e6cdeerow4_col6 {
#             background-color:  #ecf9f1;
#             color:  #000000;
#         }    #T_4cb49520_68a4_11ea_a31e_8c2937e6cdeerow4_col7 {
#             background-color:  #75b491;
#             color:  #000000;
#         }    #T_4cb49520_68a4_11ea_a31e_8c2937e6cdeerow4_col8 {
#             background-color:  #d9eee2;
#             color:  #000000;
#         }    #T_4cb49520_68a4_11ea_a31e_8c2937e6cdeerow4_col9 {
#             background-color:  #93c5a9;

# %% [markdown]
# ## Chart Creation for Single Schedule Comparison
#
# Let's see how our best single optimized schedules compare with the previous NESCAC schedules in the following categories:
#
# - Total cost
# - Team home games
# - Team travel duration
# - Team overnights
#
# We use the following patterns and colors to highlight schedules in the charts below:
#
# > <div style="float:left"><img src="hard_data/best_schedule.png"></div> $\quad$ indicates the previous NESCAC volleyball conference schedule with the best schedule score
#
# > <div style="float:left"><img src="hard_data/best_result.png"></div> $\quad$ highlights the schedule with the best result in the charted category
#
# > <div style="float:left"><img src="hard_data/worst_result.png"></div> $\quad$ highlights the schedule with the worst result in the charted category
#
# ## Totals
#
# ### Total Cost

# %%
from src.configuration import *
from src.figures import *
# %matplotlib inline


print("Loading necessary information ...\n")
single_schedule_comparison_df = pd.read_pickle(SINGLE_SCHEDULE_COMPARISON_FILENAME)
single_schedule_comparison_df = single_schedule_comparison_df.iloc[selected_idxs].append(single_schedule_comparison_df[10:21])

print("Creating single schedule total cost comparison bar chart ...")
plot_filename = plot_and_save_horizontal_bar_chart_min_max_mean(
    analysis_df=single_schedule_comparison_df,
    column_name="Total Cost",
    min_preferred=True,
    fig_title="Total cost ($) comparison.",
    nescac_mean_line=False,
    plot_path=SINGLE_RESULTS_PLOT_PATH)

print("Saving single schedule total cost comparison bar chart ...")
print("... Saved as \"{}\"\n".format(plot_filename))

print("Process complete.\n")
# Out:
# Loading necessary information ...
#
# Creating single schedule total cost comparison bar chart ...
# Saving single schedule total cost comparison bar chart ...
# ... Saved as "results/single/figures/total_cost_($)_comparison.png"
#
# Process complete.

# %%
from src.configuration import *
from src.figures import *
# %matplotlib inline


print("Loading necessary information ...\n")
single_schedule_comparison_df = pd.read_pickle(SINGLE_SCHEDULE_COMPARISON_FILENAME)
single_schedule_comparison_df = single_schedule_comparison_df.iloc[selected_idxs].append(single_schedule_comparison_df[10:21]).reset_index(drop=True)
sched_id_0 = single_schedule_comparison_df.loc[0]['Abbreviated Schedule ID']
sched_id_1 = single_schedule_comparison_df.loc[1]['Abbreviated Schedule ID']

print("Creating single schedule total cost change comparison bar chart ...")
plot_filename = plot_and_save_horizontal_bar_charts_min_max_mean(
    analysis_df=single_schedule_comparison_df,
    column_names=("{} Total Cost Change".format(sched_id_0), "{} Total Cost Change".format(sched_id_1)),
    min_preferred_tuple=(True, True),
    fig_title="Total cost ($) change.",
    subplot_titles=("{}".format(sched_id_0), "{}".format(sched_id_1)),
    nescac_mean_line=True,
    optimized_schedule_lines=False,
    plot_path=SINGLE_RESULTS_PLOT_PATH)

print("Saving single schedule total cost change comparison bar chart ...")
print("... Saved as \"{}\"\n".format(plot_filename))

print("Process complete.\n")
# Out:
# Loading necessary information ...
#
# Creating single schedule total cost change comparison bar chart ...
# Saving single schedule total cost change comparison bar chart ...
# ... Saved as "results/single/figures/total_cost_($)_change.png"
#
# Process complete.

# %%
from src.configuration import *
from src.figures import *
# %matplotlib inline


print("Loading necessary information ...\n")
single_schedule_comparison_df = pd.read_pickle(SINGLE_SCHEDULE_COMPARISON_FILENAME)
single_schedule_comparison_df = single_schedule_comparison_df.iloc[selected_idxs].append(single_schedule_comparison_df[10:21]).reset_index(drop=True)
sched_id_0 = single_schedule_comparison_df.loc[0]['Abbreviated Schedule ID']
sched_id_1 = single_schedule_comparison_df.loc[1]['Abbreviated Schedule ID']

print("Creating single schedule total cost percent change comparison bar chart ...")
plot_filename = plot_and_save_horizontal_bar_charts_min_max_mean(
    analysis_df=single_schedule_comparison_df,
    column_names=("{} Total Cost Percent Change".format(sched_id_0), "{} Total Cost Percent Change".format(sched_id_1)),
    min_preferred_tuple=(True, True),
    fig_title="Total cost percent change.",
    subplot_titles=("{}".format(sched_id_0), "{}".format(sched_id_1)),
    nescac_mean_line=True,
    optimized_schedule_lines=False,
    plot_path=SINGLE_RESULTS_PLOT_PATH)

print("Saving single schedule total cost percent change comparison bar chart ...")
print("... Saved as \"{}\"\n".format(plot_filename))

print("Process complete.\n")
# Out:
# Loading necessary information ...
#
# Creating single schedule total cost percent change comparison bar chart ...
# Saving single schedule total cost percent change comparison bar chart ...
# ... Saved as "results/single/figures/total_cost_percent_change.png"
#
# Process complete.

# %% [markdown]
# ### Total Travel Duration

# %%
from src.configuration import *
from src.figures import *
# %matplotlib inline


print("Loading necessary information ...\n")
single_schedule_comparison_df = pd.read_pickle(SINGLE_SCHEDULE_COMPARISON_FILENAME)
single_schedule_comparison_df = single_schedule_comparison_df.iloc[selected_idxs].append(single_schedule_comparison_df[10:21]).reset_index(drop=True)

print("Creating single schedule total travel duration comparison bar chart ...")
plot_filename = plot_and_save_horizontal_bar_chart_min_max_mean(
    analysis_df=single_schedule_comparison_df,
    column_name="Total Duration in Hours",
    min_preferred=True,
    fig_title="Total travel duration in hours comparison.",
    nescac_mean_line=False,
    plot_path=SINGLE_RESULTS_PLOT_PATH)

print("Saving single schedule total travel duration comparison bar chart ...")
print("... Saved as \"{}\"\n".format(plot_filename))

print("Process complete.\n")
# Out:
# Loading necessary information ...
#
# Creating single schedule total travel duration comparison bar chart ...
# Saving single schedule total travel duration comparison bar chart ...
# ... Saved as "results/single/figures/total_travel_duration_in_hours_comparison.png"
#
# Process complete.

# %%
# from src.configuration import *
# from src.figures import *
# %matplotlib inline


# print("Loading necessary information ...\n")
# single_schedule_comparison_df = pd.read_pickle(SINGLE_SCHEDULE_COMPARISON_FILENAME)
# single_schedule_comparison_df = single_schedule_comparison_df.iloc[selected_idxs].append(single_schedule_comparison_df[10:21]).reset_index(drop=True)
# sched_id_0 = single_schedule_comparison_df.loc[0]['Abbreviated Schedule ID']
# sched_id_1 = single_schedule_comparison_df.loc[1]['Abbreviated Schedule ID']

# print("Creating single schedule total travel duration percent change comparison bar chart ...")
# plot_filename = plot_and_save_horizontal_bar_charts_min_max_mean(
#     analysis_df=single_schedule_comparison_df,
#     column_names=("{} Total Duration in Hours Percent Change".format(sched_id_0), "{} Total Duration in Hours Percent Change".format(sched_id_1)),
#     min_preferred_tuple=(True, True),
#     fig_title="Total travel duration in hours percent change.",
#     subplot_titles=("{}".format(sched_id_0), "{}".format(sched_id_1)),
#     nescac_mean_line=True,
#     optimized_schedule_lines=False,
#     plot_path=SINGLE_RESULTS_PLOT_PATH)

# print("Saving single schedule total travel duration percent change comparison bar chart ...")
# print("... Saved as \"{}\"\n".format(plot_filename))

# print("Process complete.\n")
# Out:
# Loading necessary information ...
#
# Creating single schedule total travel duration percent change comparison bar chart ...
# Saving single schedule total travel duration percent change comparison bar chart ...
# ... Saved as "results/single/figures/total_travel_duration_in_hours_percent_change.png"
#
# Process complete.

# %%
from src.configuration import *
from src.figures import *
# %matplotlib inline


print("Loading necessary information ...\n")
single_schedule_comparison_df = pd.read_pickle(SINGLE_SCHEDULE_COMPARISON_FILENAME)
single_schedule_comparison_df = single_schedule_comparison_df.iloc[selected_idxs].append(single_schedule_comparison_df[10:21]).reset_index(drop=True)
sched_id_0 = single_schedule_comparison_df.loc[0]['Abbreviated Schedule ID']
sched_id_1 = single_schedule_comparison_df.loc[1]['Abbreviated Schedule ID']

print("Creating single schedule total travel duration change comparison bar chart ...")
plot_filename = plot_and_save_horizontal_bar_charts_min_max_mean(
    analysis_df=single_schedule_comparison_df,
    column_names=("{} Total Duration in Hours Change".format(sched_id_0), "{} Total Duration in Hours Change".format(sched_id_1)),
    min_preferred_tuple=(True, True),
    fig_title="Total travel duration in hours change.",
    subplot_titles=("{}".format(sched_id_0), "{}".format(sched_id_1)),
    nescac_mean_line=True,
    optimized_schedule_lines=False,
    plot_path=SINGLE_RESULTS_PLOT_PATH)

print("Saving single schedule total travel duration change comparison bar chart ...")
print("... Saved as \"{}\"\n".format(plot_filename))

print("Process complete.\n")
# Out:
# Loading necessary information ...
#
# Creating single schedule total travel duration change comparison bar chart ...
# Saving single schedule total travel duration change comparison bar chart ...
# ... Saved as "results/single/figures/total_travel_duration_in_hours_change.png"
#
# Process complete.

# %%
# Assume 14 players/team ==> how many hours saved
int(14*52)
# Out:
# 728

# %%
# Assume 2 coaching staff/team ==> how many hours saved
int(2*52)
# Out:
# 104

# %% [markdown]
# ### Total Overnights

# %%
from src.configuration import *
from src.figures import *
# %matplotlib inline


print("Loading necessary information ...\n")
single_schedule_comparison_df = pd.read_pickle(SINGLE_SCHEDULE_COMPARISON_FILENAME)
single_schedule_comparison_df = single_schedule_comparison_df.iloc[selected_idxs].append(single_schedule_comparison_df[10:21]).reset_index(drop=True)

print("Creating single schedule total overnights comparison bar chart ...")
plot_filename = plot_and_save_horizontal_bar_chart_min_max_mean(
    analysis_df=single_schedule_comparison_df,
    column_name="Total Overnight",
    min_preferred=True,
    fig_title="Total overnights comparison.",
    nescac_mean_line=False,
    plot_path=SINGLE_RESULTS_PLOT_PATH)

print("Saving single schedule total overnights comparison bar chart ...")
print("... Saved as \"{}\"\n".format(plot_filename))

print("Process complete.\n")
# Out:
# Loading necessary information ...
#
# Creating single schedule total overnights comparison bar chart ...
# Saving single schedule total overnights comparison bar chart ...
# ... Saved as "results/single/figures/total_overnights_comparison.png"
#
# Process complete.

# %%
# from src.configuration import *
# from src.figures import *
# %matplotlib inline


# print("Loading necessary information ...\n")
# single_schedule_comparison_df = pd.read_pickle(SINGLE_SCHEDULE_COMPARISON_FILENAME)
# single_schedule_comparison_df = single_schedule_comparison_df.iloc[selected_idxs].append(single_schedule_comparison_df[10:21]).reset_index(drop=True)
# sched_id_0 = single_schedule_comparison_df.loc[0]['Abbreviated Schedule ID']
# sched_id_1 = single_schedule_comparison_df.loc[1]['Abbreviated Schedule ID']

# print("Creating single schedule total overnights percent change comparison bar chart ...")
# plot_filename = plot_and_save_horizontal_bar_charts_min_max_mean(
#     analysis_df=single_schedule_comparison_df,
#     column_names=("{} Total Overnight Percent Change".format(sched_id_0), "{} Total Overnight Percent Change".format(sched_id_1)),
#     min_preferred_tuple=(True, True),
#     fig_title="Total overnights percent change.",
#     subplot_titles=("{}".format(sched_id_0), "{}".format(sched_id_1)),
#     nescac_mean_line=True,
#     optimized_schedule_lines=False,
#     plot_path=SINGLE_RESULTS_PLOT_PATH)

# print("Saving single schedule total overnights percent change comparison bar chart ...")
# print("... Saved as \"{}\"\n".format(plot_filename))

# print("Process complete.\n")
# Out:
# Loading necessary information ...
#
# Creating single schedule total overnights percent change comparison bar chart ...
# Saving single schedule total overnights percent change comparison bar chart ...
# ... Saved as "results/single/figures/total_overnights_percent_change.png"
#
# Process complete.

# %%
from src.configuration import *
from src.figures import *
# %matplotlib inline


print("Loading necessary information ...\n")
single_schedule_comparison_df = pd.read_pickle(SINGLE_SCHEDULE_COMPARISON_FILENAME)
single_schedule_comparison_df = single_schedule_comparison_df.iloc[selected_idxs].append(single_schedule_comparison_df[10:21]).reset_index(drop=True)
sched_id_0 = single_schedule_comparison_df.loc[0]['Abbreviated Schedule ID']
sched_id_1 = single_schedule_comparison_df.loc[1]['Abbreviated Schedule ID']

print("Creating single schedule total overnights change comparison bar chart ...")
plot_filename = plot_and_save_horizontal_bar_charts_min_max_mean(
    analysis_df=single_schedule_comparison_df,
    column_names=("{} Total Overnight Change".format(sched_id_0), "{} Total Overnight Change".format(sched_id_1)),
    min_preferred_tuple=(True, True),
    fig_title="Total overnights change.",
    subplot_titles=("{}".format(sched_id_0), "{}".format(sched_id_1)),
    nescac_mean_line=True,
    optimized_schedule_lines=False,
    plot_path=SINGLE_RESULTS_PLOT_PATH)

print("Saving single schedule total overnights change comparison bar chart ...")
print("... Saved as \"{}\"\n".format(plot_filename))

print("Process complete.\n")
# Out:
# Loading necessary information ...
#
# Creating single schedule total overnights change comparison bar chart ...
# Saving single schedule total overnights change comparison bar chart ...
# ... Saved as "results/single/figures/total_overnights_change.png"
#
# Process complete.

# %%
# Assume 14 players/team + 2 coaching staff/team ==> how many overnights saved
int(16*8)
# Out:
# 128

# %% [markdown]
# ## Team Experience

# %% [markdown]
# ### Team Home Games

# %%
from src.configuration import *
from src.figures import *
# %matplotlib inline


print("Loading necessary information ...\n")
single_schedule_comparison_df = pd.read_pickle(SINGLE_SCHEDULE_COMPARISON_FILENAME)
single_schedule_comparison_df = single_schedule_comparison_df.iloc[selected_idxs].append(single_schedule_comparison_df[10:21]).reset_index(drop=True)

print("Creating team home game comparison bar chart ...")
# Create team home game minimum column
single_schedule_comparison_df['Team Home Game Minimum'] = single_schedule_comparison_df['Team Home Game (Min, Max, Rng)'].apply(lambda x: x[0])
plot_filename = plot_and_save_horizontal_bar_charts_min_max_mean(
    analysis_df=single_schedule_comparison_df,
    column_names=("Team Home Game Minimum", "Team Home Game Fairness Index"),
    min_preferred_tuple=(None, False),
    fig_title="Team home game comparison.",
    subplot_titles=("Minimum Values", "Fairness Index"), 
    nescac_mean_line=False,
    optimized_schedule_lines=True,
    plot_path=SINGLE_RESULTS_PLOT_PATH)

print("Saving team home game comparison bar chart ...")
print("... Saved as \"{}\"\n".format(plot_filename))

print("Process complete.\n")
# Out:
# Loading necessary information ...
#
# Creating team home game comparison bar chart ...
# Saving team home game comparison bar chart ...
# ... Saved as "results/single/figures/team_home_game_comparison.png"
#
# Process complete.

# %% [markdown]
# ### Team Travel Duration

# %%
from src.configuration import *
from src.figures import *
# %matplotlib inline


print("Loading necessary information ...\n")
single_schedule_comparison_df = pd.read_pickle(SINGLE_SCHEDULE_COMPARISON_FILENAME)
single_schedule_comparison_df = single_schedule_comparison_df.iloc[selected_idxs].append(single_schedule_comparison_df[10:21]).reset_index(drop=True)

print("Creating team duration in hours comparison bar chart ...")
plot_filename = plot_and_save_horizontal_bar_charts_min_max_mean(
    analysis_df=single_schedule_comparison_df,
    column_names=("Team Duration in Hours Average", "Team Duration in Hours Fairness Index"),
    min_preferred_tuple=(True, False),
    fig_title="Team duration in hours comparison.",
    subplot_titles=("Average Values", "Fairness Index"),
    nescac_mean_line=False,
    optimized_schedule_lines=True,    
    plot_path=SINGLE_RESULTS_PLOT_PATH)

print("Saving team duration in hours comparison bar chart ...")
print("... Saved as \"{}\"\n".format(plot_filename))

print("Process complete.\n")
# Out:
# Loading necessary information ...
#
# Creating team duration in hours comparison bar chart ...
# Saving team duration in hours comparison bar chart ...
# ... Saved as "results/single/figures/team_duration_in_hours_comparison.png"
#
# Process complete.

# %% [markdown]
# ### Team Overnights

# %%
from src.configuration import *
from src.figures import *
# %matplotlib inline


print("Loading necessary information ...\n")
single_schedule_comparison_df = pd.read_pickle(SINGLE_SCHEDULE_COMPARISON_FILENAME)
single_schedule_comparison_df = single_schedule_comparison_df.iloc[selected_idxs].append(single_schedule_comparison_df[10:21]).reset_index(drop=True)

print("Creating team overnight comparison bar chart ...")
plot_filename = plot_and_save_horizontal_bar_charts_min_max_mean(
    analysis_df=single_schedule_comparison_df,
    column_names=("Team Overnight Average", "Team Overnight Fairness Index"),
    min_preferred_tuple=(True, False),
    fig_title="Team overnight comparison.",
    subplot_titles=("Average Values", "Fairness Index"),   
    nescac_mean_line=False,
    optimized_schedule_lines=True,    
    plot_path=SINGLE_RESULTS_PLOT_PATH)

print("Saving team overnight comparison bar chart ...")
print("... Saved as \"{}\"\n".format(plot_filename))

print("Process complete.\n")
# Out:
# Loading necessary information ...
#
# Creating team overnight comparison bar chart ...
# Saving team overnight comparison bar chart ...
# ... Saved as "results/single/figures/team_overnight_comparison.png"
#
# Process complete.

# %% [markdown]
# ### Closer look @ team overnights --> distribution

# %%
from src.configuration import *
from src.figures import *
# %matplotlib inline


print("Loading necessary information ...\n")
single_schedule_comparison_df = pd.read_pickle(SINGLE_SCHEDULE_COMPARISON_FILENAME)
single_schedule_comparison_df = single_schedule_comparison_df.iloc[selected_idxs].append(single_schedule_comparison_df[10:21]).reset_index(drop=True)

display(single_schedule_comparison_df[[
    'Abbreviated Schedule ID',
    'Team Overnight Dict'
]].iloc[1:])

print("Creating team overnight swarplot ...")
plot_filename = plot_and_save_dict_column_team_swarmplot_chart(
    analysis_df=single_schedule_comparison_df.iloc[1:],
    dict_column_name="Team Overnight Dict",
    fig_title="Number of overnights per team.",
    venues_mapping_filename=VENUES_MAPPING_FILENAME, 
    plot_path=SINGLE_RESULTS_PLOT_PATH)

print("Saving team overnight swarmplot ...")
print("... Saved as \"{}\"\n".format(plot_filename))

print("Process complete.\n")
# Out:
# Loading necessary information ...
#    Abbreviated Schedule ID                                Team Overnight Dict
# 1                   s5_2_3  {0: 2, 1: 1, 2: 1, 3: 1, 4: 1, 5: 3, 6: 4, 7: ...
# 2                     2011  {0: 3, 1: 1, 2: 1, 3: 1, 4: 2, 5: 3, 6: 4, 7: ...
# 3                     2010  {0: 3, 1: 2, 2: 3, 3: 2, 4: 0, 5: 3, 6: 3, 7: ...
# 4                     2009  {0: 2, 1: 2, 2: 3, 3: 2, 4: 1, 5: 3, 6: 2, 7: ...
# 5                     2015  {0: 1, 1: 2, 2: 2, 3: 2, 4: 3, 5: 2, 6: 3, 7: ...
# 6                     2012  {0: 3, 1: 2, 2: 1, 3: 2, 4: 1, 5: 3, 6: 3, 7: ...
# 7                     2014  {0: 2, 1: 2, 2: 2, 3: 2, 4: 3, 5: 3, 6: 2, 7: ...
# 8                     2019  {0: 2, 1: 2, 2: 3, 3: 2, 4: 2, 5: 2, 6: 3, 7: ...
# 9                     2018  {0: 2, 1: 2, 2: 2, 3: 2, 4: 2, 5: 3, 6: 2, 7: ...
# 10                    2013  {0: 2, 1: 2, 2: 2, 3: 3, 4: 2, 5: 2, 6: 3, 7: ...
# 11                    2017  {0: 2, 1: 3, 2: 2, 3: 3, 4: 3, 5: 2, 6: 3, 7: ...
# 12                    2016  {0: 2, 1: 3, 2: 2, 3: 3, 4: 1, 5: 4, 6: 3, 7: ...
# Creating team overnight swarplot ...
# Saving team overnight swarmplot ...
# ... Saved as "results/single/figures/team_overnight_swarmplot.png"
#
# Process complete.

# %% [markdown]
# ### Team Overnight + Duration --> Percent Change Columns

# %%
# Calculate percent change columns

analysis_df = single_schedule_comparison_df.copy()

# Extract optimized schedules with correct scores
optimized_schedule_analysis_df = analysis_df[analysis_df['Schedule ID' + ''].str.contains('optimized')]

# Extract nescac schedules with correct scores
nescac_schedule_analysis_df = analysis_df[analysis_df['Schedule ID' + ''].str.contains('nescac')]

# Prevent setting with copy warning
nescac_schedule_analysis_df = nescac_schedule_analysis_df.copy()

# Add optimized change columns
for opt_idx, opt_row in optimized_schedule_analysis_df.iterrows():

    opt_abbrev_sched_id = opt_row['Abbreviated Schedule ID']

    for nes_idx, nes_row in nescac_schedule_analysis_df.iterrows():

        nescac_schedule_analysis_df.loc[nes_idx, "{} Team Duration in Hours Average Percent Change".format(opt_abbrev_sched_id)] = calculate_column_percent_change_optimized_nescac(opt_row, nes_row, 'Team Duration in Hours Average', '')

        nescac_schedule_analysis_df.loc[nes_idx, "{} Team Overnight Average Percent Change".format(opt_abbrev_sched_id)] = calculate_column_percent_change_optimized_nescac(opt_row, nes_row, 'Team Overnight Average', '')

# Recombine into one DataFrame
analysis_df = optimized_schedule_analysis_df.append(nescac_schedule_analysis_df)

single_schedule_comparison_df = analysis_df.copy()

display(single_schedule_comparison_df[single_schedule_comparison_df.columns[-4:]])
# Out:
#     s0_1_3 Team Duration in Hours Average Percent Change  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                           -2.604167
# 3                                           -5.555556
# 4                                           -9.661836
# 5                                          -19.742489
# 6                                          -15.000000
# 7                                          -19.396552
# 8                                          -19.396552
# 9                                          -17.982456
# 10                                         -17.621145
# 11                                         -19.396552
# 12                                         -22.083333
#
#     s0_1_3 Team Overnight Average Percent Change  \
# 0                                            NaN
# 1                                            NaN
# 2                                     -28.000000
# 3                                     -21.739130
# 4                                     -21.739130
# 5                                     -25.000000
# 6                                     -25.000000
# 7                                     -25.000000
# 8                                     -25.000000
# 9                                     -25.000000
# 10                                    -28.000000
# 11                                    -30.769231
# 12                                    -30.769231
#
#     s5_2_3 Team Duration in Hours Average Percent Change  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                           -1.041667
# 3                                           -4.040404
# 4                                           -8.212560
# 5                                          -18.454936
# 6                                          -13.636364
# 7                                          -18.103448
# 8                                          -18.103448
# 9                                          -16.666667
# 10                                         -16.299559
# 11                                         -18.103448
# 12                                         -20.833333
#
#     s5_2_3 Team Overnight Average Percent Change
# 0                                            NaN
# 1                                            NaN
# 2                                     -28.000000
# 3                                     -21.739130
# 4                                     -21.739130
# 5                                     -25.000000
# 6                                     -25.000000
# 7                                     -25.000000
# 8                                     -25.000000
# 9                                     -25.000000
# 10                                    -28.000000
# 11                                    -30.769231
# 12                                    -30.769231

# %%
print("Creating single schedule team duration in hours average percent change comparison bar chart ...")
plot_filename = plot_and_save_horizontal_bar_charts_min_max_mean(
    analysis_df=single_schedule_comparison_df,
    column_names=("{} Team Duration in Hours Average Percent Change".format(sched_id_0), "{} Team Duration in Hours Average Percent Change".format(sched_id_1)),
    min_preferred_tuple=(True, True),
    fig_title="Team duration in hours average percent change.",
    subplot_titles=("{}".format(sched_id_0), "{}".format(sched_id_1)),
    nescac_mean_line=True,
    optimized_schedule_lines=False,
    plot_path=SINGLE_RESULTS_PLOT_PATH)

print("Saving single schedule team duration in hours average percent change comparison bar chart ...")
print("... Saved as \"{}\"\n".format(plot_filename))

print("Process complete.\n")
# Out:
# Creating single schedule team duration in hours average percent change comparison bar chart ...
# Saving single schedule team duration in hours average percent change comparison bar chart ...
# ... Saved as "results/single/figures/team_duration_in_hours_average_percent_change.png"
#
# Process complete.

# %%
# closer look at values
display(single_schedule_comparison_df[['s0_1_3 Team Duration in Hours Average Percent Change', 's5_2_3 Team Duration in Hours Average Percent Change']])
# Out:
#     s0_1_3 Team Duration in Hours Average Percent Change  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                           -2.604167
# 3                                           -5.555556
# 4                                           -9.661836
# 5                                          -19.742489
# 6                                          -15.000000
# 7                                          -19.396552
# 8                                          -19.396552
# 9                                          -17.982456
# 10                                         -17.621145
# 11                                         -19.396552
# 12                                         -22.083333
#
#     s5_2_3 Team Duration in Hours Average Percent Change
# 0                                                 NaN
# 1                                                 NaN
# 2                                           -1.041667
# 3                                           -4.040404
# 4                                           -8.212560
# 5                                          -18.454936
# 6                                          -13.636364
# 7                                          -18.103448
# 8                                          -18.103448
# 9                                          -16.666667
# 10                                         -16.299559
# 11                                         -18.103448
# 12                                         -20.833333

# %%
print("Creating single schedule team overnight average percent change comparison bar chart ...")
plot_filename = plot_and_save_horizontal_bar_charts_min_max_mean(
    analysis_df=single_schedule_comparison_df,
    column_names=("{} Team Overnight Average Percent Change".format(sched_id_0), "{} Team Overnight Average Percent Change".format(sched_id_1)),
    min_preferred_tuple=(True, True),
    fig_title="Team overnight average percent change.",
    subplot_titles=("{}".format(sched_id_0), "{}".format(sched_id_1)),
    nescac_mean_line=True,
    optimized_schedule_lines=False,
    plot_path=SINGLE_RESULTS_PLOT_PATH)

print("Saving single schedule team overnight average percent change comparison bar chart ...")
print("... Saved as \"{}\"\n".format(plot_filename))

print("Process complete.\n")
# Out:
# Creating single schedule team overnight average percent change comparison bar chart ...
# Saving single schedule team overnight average percent change comparison bar chart ...
# ... Saved as "results/single/figures/team_overnight_average_percent_change.png"
#
# Process complete.

# %% [markdown]
# ## Score Metrics

# %%
from src.configuration import *
from src.figures import *
# %matplotlib inline


print("Loading necessary information ...\n")
single_schedule_comparison_df = pd.read_pickle(SINGLE_SCHEDULE_COMPARISON_FILENAME)
single_schedule_comparison_df = single_schedule_comparison_df.iloc[selected_idxs].append(single_schedule_comparison_df[10:21]).reset_index(drop=True)

print("Creating schedule score components comparison bar chart ...")
plot_filename = plot_and_save_horizontal_bar_charts_min_max_mean(
    analysis_df=single_schedule_comparison_df,
    column_names=("Total Cost", "Team Experience Score"),
    min_preferred_tuple=(True, True),
    fig_title="Schedule score components comparison.",
    subplot_titles=("Total Cost ($)", "Team Experience Score"),
    nescac_mean_line=False,
    optimized_schedule_lines=True,
    plot_path=SINGLE_RESULTS_PLOT_PATH)

print("Saving schedule score components comparison bar chart ...")
print("... Saved as \"{}\"\n".format(plot_filename))

print("Process complete.\n")
# Out:
# Loading necessary information ...
#
# Creating schedule score components comparison bar chart ...
# Saving schedule score components comparison bar chart ...
# ... Saved as "results/single/figures/schedule_score_components_comparison.png"
#
# Process complete.

# %%
from src.configuration import *
from src.figures import *
# %matplotlib inline


print("Loading necessary information ...\n")
single_schedule_comparison_df = pd.read_pickle(SINGLE_SCHEDULE_COMPARISON_FILENAME)
single_schedule_comparison_df = single_schedule_comparison_df.iloc[selected_idxs].append(single_schedule_comparison_df[10:21]).reset_index(drop=True)

print("Creating schedule score comparison bar chart ...")
plot_filename = plot_and_save_horizontal_bar_chart_min_max_mean(
    analysis_df=single_schedule_comparison_df,
    column_name="Schedule Score",
    min_preferred=True,
    fig_title="Schedule score comparison.",
    nescac_mean_line=False,
    plot_path=SINGLE_RESULTS_PLOT_PATH)

print("Saving schedule score comparison bar chart ...")
print("... Saved as \"{}\"\n".format(plot_filename))

print("Process complete.\n")
# Out:
# Loading necessary information ...
#
# Creating schedule score comparison bar chart ...
# Saving schedule score comparison bar chart ...
# ... Saved as "results/single/figures/schedule_score_comparison.png"
#
# Process complete.

# %% [markdown]
# ## Review Schedules

# %%
# schedules in optimized pair
columns = [
    'Abbreviated Schedule ID',
    'Schedule ID'
]

single_schedule_comparison_df = pd.read_pickle(SINGLE_SCHEDULE_COMPARISON_FILENAME)
_ = single_schedule_comparison_df = single_schedule_comparison_df.iloc[selected_idxs]

display(_[columns])
# Out:
#   Abbreviated Schedule ID                        Schedule ID
# 0                  s0_1_3  15_2335_optimized_team_schedule_0
# 5                  s5_2_3   5_2235_optimized_team_schedule_0

# %%
# review full schedule
# toggle and untoggle display lines to review full schedule or full schedule grouped by week
for idx, row in _.iterrows():
    
    filename = f"{row['Schedule ID'].replace('team_', '')}.csv"
    
    print("##########")
    print(f"# {row['Abbreviated Schedule ID']} #")
    print("##########")
    
    print(f"\n{filename}")
    
    schedule_df = pd.read_csv(f"results/single/optimized_schedules/{filename}", index_col=0)
#     display(schedule_df)

    # review schedule grouped by week
    for week, week_df in schedule_df.groupby('Week'):
        display(week_df)
# Out:
# ##########
# # s0_1_3 #
# ##########
#
# 15_2335_optimized_schedule_0.csv
#     Week Day (Str)  Time Slot               Team 1            Team 2  \
# 0      0      Fri.          0        Bates College   Trinity College
# 1      0      Fri.          1        Colby College   Amherst College
# 2      0      Sat.          2      Bowdoin College   Amherst College
# 3      0      Sat.          3      Bowdoin College   Trinity College
# 4      0      Sat.          4        Colby College   Trinity College
# 5      0      Sat.          5        Bates College   Amherst College
# 6      0      Fri.          0   Middlebury College  Hamilton College
# 7      0      Sat.          1   Middlebury College  Williams College
# 8      0      Sat.          2     Williams College  Hamilton College
# 9      0      Sat.          0  Connecticut College  Tufts University
# 10     0      Sat.          1  Wesleyan University  Tufts University
#
#                Location
# 0         Colby College
# 1         Colby College
# 2         Colby College
# 3         Colby College
# 4         Colby College
# 5         Colby College
# 6      Hamilton College
# 7      Hamilton College
# 8      Hamilton College
# 9   Wesleyan University
# 10  Wesleyan University
#     Week Day (Str)  Time Slot              Team 1               Team 2  \
# 11     1      Fri.          0       Bates College      Bowdoin College
# 12     1      Sat.          1       Colby College      Bowdoin College
# 13     1      Sat.          2       Bates College        Colby College
# 14     1      Sat.          0    Tufts University      Trinity College
# 15     1      Sat.          1    Tufts University      Amherst College
# 16     1      Fri.          0  Middlebury College  Connecticut College
# 17     1      Fri.          1    Williams College  Wesleyan University
# 18     1      Sat.          2    Williams College  Connecticut College
# 19     1      Sat.          3    Hamilton College  Wesleyan University
# 20     1      Sat.          4    Hamilton College  Connecticut College
# 21     1      Sat.          5  Middlebury College  Wesleyan University
#
#             Location
# 11   Bowdoin College
# 12   Bowdoin College
# 13   Bowdoin College
# 14  Tufts University
# 15  Tufts University
# 16  Williams College
# 17  Williams College
# 18  Williams College
# 19  Williams College
# 20  Williams College
# 21  Williams College
#     Week Day (Str)  Time Slot               Team 1               Team 2  \
# 22     2      Fri.          0      Trinity College     Williams College
# 23     2      Fri.          1      Amherst College     Hamilton College
# 24     2      Sat.          2      Amherst College     Williams College
# 25     2      Sat.          3      Trinity College   Middlebury College
# 26     2      Sat.          4      Trinity College     Hamilton College
# 27     2      Sat.          5      Amherst College   Middlebury College
# 28     2      Fri.          0        Bates College     Tufts University
# 29     2      Sat.          1        Colby College     Tufts University
# 30     2      Sat.          2      Bowdoin College     Tufts University
# 31     2      Sat.          0  Wesleyan University  Connecticut College
#
#                Location
# 22      Amherst College
# 23      Amherst College
# 24      Amherst College
# 25      Amherst College
# 26      Amherst College
# 27      Amherst College
# 28        Bates College
# 29        Bates College
# 30        Bates College
# 31  Wesleyan University
#     Week Day (Str)  Time Slot               Team 1            Team 2  \
# 32     3      Fri.          0  Wesleyan University     Bates College
# 33     3      Fri.          1  Connecticut College     Colby College
# 34     3      Sat.          2  Connecticut College     Bates College
# 35     3      Sat.          3  Wesleyan University     Colby College
# 36     3      Sat.          4  Connecticut College   Bowdoin College
# 37     3      Sat.          5  Wesleyan University   Bowdoin College
# 38     3      Sat.          0      Trinity College   Amherst College
# 39     3      Fri.          0     Hamilton College  Tufts University
# 40     3      Sat.          1     Williams College  Tufts University
# 41     3      Sat.          2   Middlebury College  Tufts University
#
#                Location
# 32  Connecticut College
# 33  Connecticut College
# 34  Connecticut College
# 35  Connecticut College
# 36  Connecticut College
# 37  Connecticut College
# 38      Trinity College
# 39     Williams College
# 40     Williams College
# 41     Williams College
#     Week Day (Str)  Time Slot              Team 1               Team 2  \
# 42     4      Fri.          0  Middlebury College        Bates College
# 43     4      Fri.          1    Hamilton College      Bowdoin College
# 44     4      Fri.          2    Williams College        Colby College
# 45     4      Sat.          3    Hamilton College        Bates College
# 46     4      Sat.          4    Hamilton College        Colby College
# 47     4      Sat.          5    Williams College        Bates College
# 48     4      Sat.          6    Williams College      Bowdoin College
# 49     4      Sat.          7  Middlebury College        Colby College
# 50     4      Sat.          8  Middlebury College      Bowdoin College
# 51     4      Fri.          0     Amherst College  Connecticut College
# 52     4      Fri.          1     Trinity College  Wesleyan University
# 53     4      Sat.          2     Trinity College  Connecticut College
# 54     4      Sat.          3     Amherst College  Wesleyan University
#
#               Location
# 42  Middlebury College
# 43  Middlebury College
# 44  Middlebury College
# 45  Middlebury College
# 46  Middlebury College
# 47  Middlebury College
# 48  Middlebury College
# 49  Middlebury College
# 50  Middlebury College
# 51     Trinity College
# 52     Trinity College
# 53     Trinity College
# 54     Trinity College
# ##########
# # s5_2_3 #
# ##########
#
# 5_2235_optimized_schedule_0.csv
#    Week Day (Str)  Time Slot            Team 1               Team 2  \
# 0     0      Fri.          0   Bowdoin College     Hamilton College
# 1     0      Fri.          1     Bates College   Middlebury College
# 2     0      Sat.          2   Bowdoin College   Middlebury College
# 3     0      Sat.          3     Bates College     Hamilton College
# 4     0      Sat.          4     Colby College     Hamilton College
# 5     0      Sat.          5     Colby College   Middlebury College
# 6     0      Sat.          0  Tufts University      Amherst College
# 7     0      Fri.          0  Williams College  Connecticut College
# 8     0      Sat.          1  Williams College  Wesleyan University
# 9     0      Sat.          2  Williams College      Trinity College
#
#            Location
# 0   Bowdoin College
# 1   Bowdoin College
# 2   Bowdoin College
# 3   Bowdoin College
# 4   Bowdoin College
# 5   Bowdoin College
# 6  Tufts University
# 7  Williams College
# 8  Williams College
# 9  Williams College
#     Week Day (Str)  Time Slot              Team 1               Team 2  \
# 10     1      Fri.          0    Tufts University  Wesleyan University
# 11     1      Fri.          1     Amherst College      Trinity College
# 12     1      Sat.          2     Amherst College  Connecticut College
# 13     1      Sat.          3    Tufts University      Trinity College
# 14     1      Sat.          4    Tufts University  Connecticut College
# 15     1      Sat.          5     Amherst College  Wesleyan University
# 16     1      Fri.          0     Bowdoin College     Williams College
# 17     1      Sat.          1       Bates College     Williams College
# 18     1      Sat.          2       Colby College     Williams College
# 19     1      Sat.          0  Middlebury College     Hamilton College
#
#             Location
# 10   Amherst College
# 11   Amherst College
# 12   Amherst College
# 13   Amherst College
# 14   Amherst College
# 15   Amherst College
# 16     Bates College
# 17     Bates College
# 18     Bates College
# 19  Hamilton College
#     Week Day (Str)  Time Slot               Team 1               Team 2  \
# 20     2      Fri.          0      Bowdoin College      Amherst College
# 21     2      Fri.          1        Colby College     Tufts University
# 22     2      Sat.          2        Bates College     Tufts University
# 23     2      Sat.          3      Bowdoin College     Tufts University
# 24     2      Sat.          4        Bates College      Amherst College
# 25     2      Sat.          5        Colby College      Amherst College
# 26     2      Fri.          0  Wesleyan University      Trinity College
# 27     2      Sat.          1  Connecticut College      Trinity College
# 28     2      Sat.          2  Wesleyan University  Connecticut College
# 29     2      Sat.          0     Hamilton College     Williams College
# 30     2      Sat.          1   Middlebury College     Williams College
#
#                Location
# 20        Bates College
# 21        Bates College
# 22        Bates College
# 23        Bates College
# 24        Bates College
# 25        Bates College
# 26  Connecticut College
# 27  Connecticut College
# 28  Connecticut College
# 29     Hamilton College
# 30     Hamilton College
#     Week Day (Str)  Time Slot               Team 1              Team 2  \
# 31     3      Fri.          0        Colby College       Bates College
# 32     3      Sat.          1      Bowdoin College       Bates College
# 33     3      Sat.          2      Bowdoin College       Colby College
# 34     3      Sat.          0     Tufts University    Williams College
# 35     3      Sat.          1      Amherst College    Williams College
# 36     3      Fri.          0      Trinity College  Middlebury College
# 37     3      Fri.          1  Connecticut College    Hamilton College
# 38     3      Sat.          2  Wesleyan University    Hamilton College
# 39     3      Sat.          3      Trinity College    Hamilton College
# 40     3      Sat.          4  Connecticut College  Middlebury College
# 41     3      Sat.          5  Wesleyan University  Middlebury College
#
#                Location
# 31        Colby College
# 32        Colby College
# 33        Colby College
# 34     Tufts University
# 35     Tufts University
# 36  Wesleyan University
# 37  Wesleyan University
# 38  Wesleyan University
# 39  Wesleyan University
# 40  Wesleyan University
# 41  Wesleyan University
#     Week Day (Str)  Time Slot               Team 1            Team 2  \
# 42     4      Fri.          0   Middlebury College   Amherst College
# 43     4      Fri.          1     Hamilton College  Tufts University
# 44     4      Sat.          2   Middlebury College  Tufts University
# 45     4      Sat.          3     Hamilton College   Amherst College
# 46     4      Fri.          0  Wesleyan University     Colby College
# 47     4      Fri.          1  Connecticut College   Bowdoin College
# 48     4      Fri.          2      Trinity College     Bates College
# 49     4      Sat.          3  Connecticut College     Colby College
# 50     4      Sat.          4  Wesleyan University   Bowdoin College
# 51     4      Sat.          5      Trinity College   Bowdoin College
# 52     4      Sat.          6  Wesleyan University     Bates College
# 53     4      Sat.          7      Trinity College     Colby College
# 54     4      Sat.          8  Connecticut College     Bates College
#
#               Location
# 42  Middlebury College
# 43  Middlebury College
# 44  Middlebury College
# 45  Middlebury College
# 46     Trinity College
# 47     Trinity College
# 48     Trinity College
# 49     Trinity College
# 50     Trinity College
# 51     Trinity College
# 52     Trinity College
# 53     Trinity College
# 54     Trinity College

# %%
# review team schedules
# toggle and untoggle display lines to review team schedules grouped by team or team and week
for idx, row in _.iterrows():
    
    filename = f"{row['Schedule ID']}.csv"
    
    print("##########")
    print(f"# {row['Abbreviated Schedule ID']} #")
    print("##########")
    
    print(f"\n{filename}\n")
    
    schedule_df = pd.read_csv(f"results/single/optimized_schedules/{filename}", index_col=0)
    for team_1,team_1_df in schedule_df.groupby('Team 1'):
        print(team_1)

#         # review team schedule grouped by team
#         display(team_1_df)

        # review team schedule grouped by team and week
        for week, week_df in team_1_df.groupby('Week'):
            display(week_df)
# Out:
# ##########
# # s0_1_3 #
# ##########
#
# 15_2335_optimized_team_schedule_0.csv
#
# Amherst College
#    Week Day (Str)  Time Slot           Team 1           Team 2       Location
# 0     0      Fri.          1  Amherst College    Colby College  Colby College
# 1     0      Sat.          2  Amherst College  Bowdoin College  Colby College
# 2     0      Sat.          5  Amherst College    Bates College  Colby College
#    Week Day (Str)  Time Slot           Team 1            Team 2  \
# 3     1      Sat.          1  Amherst College  Tufts University
#
#            Location
# 3  Tufts University
#    Week Day (Str)  Time Slot           Team 1              Team 2  \
# 4     2      Fri.          1  Amherst College    Hamilton College
# 5     2      Sat.          2  Amherst College    Williams College
# 6     2      Sat.          5  Amherst College  Middlebury College
#
#           Location
# 4  Amherst College
# 5  Amherst College
# 6  Amherst College
#    Week Day (Str)  Time Slot           Team 1           Team 2  \
# 7     3      Sat.          0  Amherst College  Trinity College
#
#           Location
# 7  Trinity College
#    Week Day (Str)  Time Slot           Team 1               Team 2  \
# 8     4      Fri.          0  Amherst College  Connecticut College
# 9     4      Sat.          3  Amherst College  Wesleyan University
#
#           Location
# 8  Trinity College
# 9  Trinity College
# Bates College
#     Week Day (Str)  Time Slot         Team 1           Team 2       Location
# 10     0      Fri.          0  Bates College  Trinity College  Colby College
# 11     0      Sat.          5  Bates College  Amherst College  Colby College
#     Week Day (Str)  Time Slot         Team 1           Team 2         Location
# 12     1      Fri.          0  Bates College  Bowdoin College  Bowdoin College
# 13     1      Sat.          2  Bates College    Colby College  Bowdoin College
#     Week Day (Str)  Time Slot         Team 1            Team 2       Location
# 14     2      Fri.          0  Bates College  Tufts University  Bates College
#     Week Day (Str)  Time Slot         Team 1               Team 2  \
# 15     3      Fri.          0  Bates College  Wesleyan University
# 16     3      Sat.          2  Bates College  Connecticut College
#
#                Location
# 15  Connecticut College
# 16  Connecticut College
#     Week Day (Str)  Time Slot         Team 1              Team 2  \
# 17     4      Fri.          0  Bates College  Middlebury College
# 18     4      Sat.          3  Bates College    Hamilton College
# 19     4      Sat.          5  Bates College    Williams College
#
#               Location
# 17  Middlebury College
# 18  Middlebury College
# 19  Middlebury College
# Bowdoin College
#     Week Day (Str)  Time Slot           Team 1           Team 2       Location
# 20     0      Sat.          2  Bowdoin College  Amherst College  Colby College
# 21     0      Sat.          3  Bowdoin College  Trinity College  Colby College
#     Week Day (Str)  Time Slot           Team 1         Team 2         Location
# 22     1      Fri.          0  Bowdoin College  Bates College  Bowdoin College
# 23     1      Sat.          1  Bowdoin College  Colby College  Bowdoin College
#     Week Day (Str)  Time Slot           Team 1            Team 2  \
# 24     2      Sat.          2  Bowdoin College  Tufts University
#
#          Location
# 24  Bates College
#     Week Day (Str)  Time Slot           Team 1               Team 2  \
# 25     3      Sat.          4  Bowdoin College  Connecticut College
# 26     3      Sat.          5  Bowdoin College  Wesleyan University
#
#                Location
# 25  Connecticut College
# 26  Connecticut College
#     Week Day (Str)  Time Slot           Team 1              Team 2  \
# 27     4      Fri.          1  Bowdoin College    Hamilton College
# 28     4      Sat.          6  Bowdoin College    Williams College
# 29     4      Sat.          8  Bowdoin College  Middlebury College
#
#               Location
# 27  Middlebury College
# 28  Middlebury College
# 29  Middlebury College
# Colby College
#     Week Day (Str)  Time Slot         Team 1           Team 2       Location
# 30     0      Fri.          1  Colby College  Amherst College  Colby College
# 31     0      Sat.          4  Colby College  Trinity College  Colby College
#     Week Day (Str)  Time Slot         Team 1           Team 2         Location
# 32     1      Sat.          1  Colby College  Bowdoin College  Bowdoin College
# 33     1      Sat.          2  Colby College    Bates College  Bowdoin College
#     Week Day (Str)  Time Slot         Team 1            Team 2       Location
# 34     2      Sat.          1  Colby College  Tufts University  Bates College
#     Week Day (Str)  Time Slot         Team 1               Team 2  \
# 35     3      Fri.          1  Colby College  Connecticut College
# 36     3      Sat.          3  Colby College  Wesleyan University
#
#                Location
# 35  Connecticut College
# 36  Connecticut College
#     Week Day (Str)  Time Slot         Team 1              Team 2  \
# 37     4      Fri.          2  Colby College    Williams College
# 38     4      Sat.          4  Colby College    Hamilton College
# 39     4      Sat.          7  Colby College  Middlebury College
#
#               Location
# 37  Middlebury College
# 38  Middlebury College
# 39  Middlebury College
# Connecticut College
#     Week Day (Str)  Time Slot               Team 1            Team 2  \
# 40     0      Sat.          0  Connecticut College  Tufts University
#
#                Location
# 40  Wesleyan University
#     Week Day (Str)  Time Slot               Team 1              Team 2  \
# 41     1      Fri.          0  Connecticut College  Middlebury College
# 42     1      Sat.          2  Connecticut College    Williams College
# 43     1      Sat.          4  Connecticut College    Hamilton College
#
#             Location
# 41  Williams College
# 42  Williams College
# 43  Williams College
#     Week Day (Str)  Time Slot               Team 1               Team 2  \
# 44     2      Sat.          0  Connecticut College  Wesleyan University
#
#                Location
# 44  Wesleyan University
#     Week Day (Str)  Time Slot               Team 1           Team 2  \
# 45     3      Fri.          1  Connecticut College    Colby College
# 46     3      Sat.          2  Connecticut College    Bates College
# 47     3      Sat.          4  Connecticut College  Bowdoin College
#
#                Location
# 45  Connecticut College
# 46  Connecticut College
# 47  Connecticut College
#     Week Day (Str)  Time Slot               Team 1           Team 2  \
# 48     4      Fri.          0  Connecticut College  Amherst College
# 49     4      Sat.          2  Connecticut College  Trinity College
#
#            Location
# 48  Trinity College
# 49  Trinity College
# Hamilton College
#     Week Day (Str)  Time Slot            Team 1              Team 2  \
# 50     0      Fri.          0  Hamilton College  Middlebury College
# 51     0      Sat.          2  Hamilton College    Williams College
#
#             Location
# 50  Hamilton College
# 51  Hamilton College
#     Week Day (Str)  Time Slot            Team 1               Team 2  \
# 52     1      Sat.          3  Hamilton College  Wesleyan University
# 53     1      Sat.          4  Hamilton College  Connecticut College
#
#             Location
# 52  Williams College
# 53  Williams College
#     Week Day (Str)  Time Slot            Team 1           Team 2  \
# 54     2      Fri.          1  Hamilton College  Amherst College
# 55     2      Sat.          4  Hamilton College  Trinity College
#
#            Location
# 54  Amherst College
# 55  Amherst College
#     Week Day (Str)  Time Slot            Team 1            Team 2  \
# 56     3      Fri.          0  Hamilton College  Tufts University
#
#             Location
# 56  Williams College
#     Week Day (Str)  Time Slot            Team 1           Team 2  \
# 57     4      Fri.          1  Hamilton College  Bowdoin College
# 58     4      Sat.          3  Hamilton College    Bates College
# 59     4      Sat.          4  Hamilton College    Colby College
#
#               Location
# 57  Middlebury College
# 58  Middlebury College
# 59  Middlebury College
# Middlebury College
#     Week Day (Str)  Time Slot              Team 1            Team 2  \
# 60     0      Fri.          0  Middlebury College  Hamilton College
# 61     0      Sat.          1  Middlebury College  Williams College
#
#             Location
# 60  Hamilton College
# 61  Hamilton College
#     Week Day (Str)  Time Slot              Team 1               Team 2  \
# 62     1      Fri.          0  Middlebury College  Connecticut College
# 63     1      Sat.          5  Middlebury College  Wesleyan University
#
#             Location
# 62  Williams College
# 63  Williams College
#     Week Day (Str)  Time Slot              Team 1           Team 2  \
# 64     2      Sat.          3  Middlebury College  Trinity College
# 65     2      Sat.          5  Middlebury College  Amherst College
#
#            Location
# 64  Amherst College
# 65  Amherst College
#     Week Day (Str)  Time Slot              Team 1            Team 2  \
# 66     3      Sat.          2  Middlebury College  Tufts University
#
#             Location
# 66  Williams College
#     Week Day (Str)  Time Slot              Team 1           Team 2  \
# 67     4      Fri.          0  Middlebury College    Bates College
# 68     4      Sat.          7  Middlebury College    Colby College
# 69     4      Sat.          8  Middlebury College  Bowdoin College
#
#               Location
# 67  Middlebury College
# 68  Middlebury College
# 69  Middlebury College
# Trinity College
#     Week Day (Str)  Time Slot           Team 1           Team 2       Location
# 70     0      Fri.          0  Trinity College    Bates College  Colby College
# 71     0      Sat.          3  Trinity College  Bowdoin College  Colby College
# 72     0      Sat.          4  Trinity College    Colby College  Colby College
#     Week Day (Str)  Time Slot           Team 1            Team 2  \
# 73     1      Sat.          0  Trinity College  Tufts University
#
#             Location
# 73  Tufts University
#     Week Day (Str)  Time Slot           Team 1              Team 2  \
# 74     2      Fri.          0  Trinity College    Williams College
# 75     2      Sat.          3  Trinity College  Middlebury College
# 76     2      Sat.          4  Trinity College    Hamilton College
#
#            Location
# 74  Amherst College
# 75  Amherst College
# 76  Amherst College
#     Week Day (Str)  Time Slot           Team 1           Team 2  \
# 77     3      Sat.          0  Trinity College  Amherst College
#
#            Location
# 77  Trinity College
#     Week Day (Str)  Time Slot           Team 1               Team 2  \
# 78     4      Fri.          1  Trinity College  Wesleyan University
# 79     4      Sat.          2  Trinity College  Connecticut College
#
#            Location
# 78  Trinity College
# 79  Trinity College
# Tufts University
#     Week Day (Str)  Time Slot            Team 1               Team 2  \
# 80     0      Sat.          0  Tufts University  Connecticut College
# 81     0      Sat.          1  Tufts University  Wesleyan University
#
#                Location
# 80  Wesleyan University
# 81  Wesleyan University
#     Week Day (Str)  Time Slot            Team 1           Team 2  \
# 82     1      Sat.          0  Tufts University  Trinity College
# 83     1      Sat.          1  Tufts University  Amherst College
#
#             Location
# 82  Tufts University
# 83  Tufts University
#     Week Day (Str)  Time Slot            Team 1           Team 2  \
# 84     2      Fri.          0  Tufts University    Bates College
# 85     2      Sat.          1  Tufts University    Colby College
# 86     2      Sat.          2  Tufts University  Bowdoin College
#
#          Location
# 84  Bates College
# 85  Bates College
# 86  Bates College
#     Week Day (Str)  Time Slot            Team 1              Team 2  \
# 87     3      Fri.          0  Tufts University    Hamilton College
# 88     3      Sat.          1  Tufts University    Williams College
# 89     3      Sat.          2  Tufts University  Middlebury College
#
#             Location
# 87  Williams College
# 88  Williams College
# 89  Williams College
# Wesleyan University
#     Week Day (Str)  Time Slot               Team 1            Team 2  \
# 90     0      Sat.          1  Wesleyan University  Tufts University
#
#                Location
# 90  Wesleyan University
#     Week Day (Str)  Time Slot               Team 1              Team 2  \
# 91     1      Fri.          1  Wesleyan University    Williams College
# 92     1      Sat.          3  Wesleyan University    Hamilton College
# 93     1      Sat.          5  Wesleyan University  Middlebury College
#
#             Location
# 91  Williams College
# 92  Williams College
# 93  Williams College
#     Week Day (Str)  Time Slot               Team 1               Team 2  \
# 94     2      Sat.          0  Wesleyan University  Connecticut College
#
#                Location
# 94  Wesleyan University
#     Week Day (Str)  Time Slot               Team 1           Team 2  \
# 95     3      Fri.          0  Wesleyan University    Bates College
# 96     3      Sat.          3  Wesleyan University    Colby College
# 97     3      Sat.          5  Wesleyan University  Bowdoin College
#
#                Location
# 95  Connecticut College
# 96  Connecticut College
# 97  Connecticut College
#     Week Day (Str)  Time Slot               Team 1           Team 2  \
# 98     4      Fri.          1  Wesleyan University  Trinity College
# 99     4      Sat.          3  Wesleyan University  Amherst College
#
#            Location
# 98  Trinity College
# 99  Trinity College
# Williams College
#      Week Day (Str)  Time Slot            Team 1              Team 2  \
# 100     0      Sat.          1  Williams College  Middlebury College
# 101     0      Sat.          2  Williams College    Hamilton College
#
#              Location
# 100  Hamilton College
# 101  Hamilton College
#      Week Day (Str)  Time Slot            Team 1               Team 2  \
# 102     1      Fri.          1  Williams College  Wesleyan University
# 103     1      Sat.          2  Williams College  Connecticut College
#
#              Location
# 102  Williams College
# 103  Williams College
#      Week Day (Str)  Time Slot            Team 1           Team 2  \
# 104     2      Fri.          0  Williams College  Trinity College
# 105     2      Sat.          2  Williams College  Amherst College
#
#             Location
# 104  Amherst College
# 105  Amherst College
#      Week Day (Str)  Time Slot            Team 1            Team 2  \
# 106     3      Sat.          1  Williams College  Tufts University
#
#              Location
# 106  Williams College
#      Week Day (Str)  Time Slot            Team 1           Team 2  \
# 107     4      Fri.          2  Williams College    Colby College
# 108     4      Sat.          5  Williams College    Bates College
# 109     4      Sat.          6  Williams College  Bowdoin College
#
#                Location
# 107  Middlebury College
# 108  Middlebury College
# 109  Middlebury College
# ##########
# # s5_2_3 #
# ##########
#
# 5_2235_optimized_team_schedule_0.csv
#
# Amherst College
#    Week Day (Str)  Time Slot           Team 1            Team 2  \
# 0     0      Sat.          0  Amherst College  Tufts University
#
#            Location
# 0  Tufts University
#    Week Day (Str)  Time Slot           Team 1               Team 2  \
# 1     1      Fri.          1  Amherst College      Trinity College
# 2     1      Sat.          2  Amherst College  Connecticut College
# 3     1      Sat.          5  Amherst College  Wesleyan University
#
#           Location
# 1  Amherst College
# 2  Amherst College
# 3  Amherst College
#    Week Day (Str)  Time Slot           Team 1           Team 2       Location
# 4     2      Fri.          0  Amherst College  Bowdoin College  Bates College
# 5     2      Sat.          4  Amherst College    Bates College  Bates College
# 6     2      Sat.          5  Amherst College    Colby College  Bates College
#    Week Day (Str)  Time Slot           Team 1            Team 2  \
# 7     3      Sat.          1  Amherst College  Williams College
#
#            Location
# 7  Tufts University
#    Week Day (Str)  Time Slot           Team 1              Team 2  \
# 8     4      Fri.          0  Amherst College  Middlebury College
# 9     4      Sat.          3  Amherst College    Hamilton College
#
#              Location
# 8  Middlebury College
# 9  Middlebury College
# Bates College
#     Week Day (Str)  Time Slot         Team 1              Team 2  \
# 10     0      Fri.          1  Bates College  Middlebury College
# 11     0      Sat.          3  Bates College    Hamilton College
#
#            Location
# 10  Bowdoin College
# 11  Bowdoin College
#     Week Day (Str)  Time Slot         Team 1            Team 2       Location
# 12     1      Sat.          1  Bates College  Williams College  Bates College
#     Week Day (Str)  Time Slot         Team 1            Team 2       Location
# 13     2      Sat.          2  Bates College  Tufts University  Bates College
# 14     2      Sat.          4  Bates College   Amherst College  Bates College
#     Week Day (Str)  Time Slot         Team 1           Team 2       Location
# 15     3      Fri.          0  Bates College    Colby College  Colby College
# 16     3      Sat.          1  Bates College  Bowdoin College  Colby College
#     Week Day (Str)  Time Slot         Team 1               Team 2  \
# 17     4      Fri.          2  Bates College      Trinity College
# 18     4      Sat.          6  Bates College  Wesleyan University
# 19     4      Sat.          8  Bates College  Connecticut College
#
#            Location
# 17  Trinity College
# 18  Trinity College
# 19  Trinity College
# Bowdoin College
#     Week Day (Str)  Time Slot           Team 1              Team 2  \
# 20     0      Fri.          0  Bowdoin College    Hamilton College
# 21     0      Sat.          2  Bowdoin College  Middlebury College
#
#            Location
# 20  Bowdoin College
# 21  Bowdoin College
#     Week Day (Str)  Time Slot           Team 1            Team 2  \
# 22     1      Fri.          0  Bowdoin College  Williams College
#
#          Location
# 22  Bates College
#     Week Day (Str)  Time Slot           Team 1            Team 2  \
# 23     2      Fri.          0  Bowdoin College   Amherst College
# 24     2      Sat.          3  Bowdoin College  Tufts University
#
#          Location
# 23  Bates College
# 24  Bates College
#     Week Day (Str)  Time Slot           Team 1         Team 2       Location
# 25     3      Sat.          1  Bowdoin College  Bates College  Colby College
# 26     3      Sat.          2  Bowdoin College  Colby College  Colby College
#     Week Day (Str)  Time Slot           Team 1               Team 2  \
# 27     4      Fri.          1  Bowdoin College  Connecticut College
# 28     4      Sat.          4  Bowdoin College  Wesleyan University
# 29     4      Sat.          5  Bowdoin College      Trinity College
#
#            Location
# 27  Trinity College
# 28  Trinity College
# 29  Trinity College
# Colby College
#     Week Day (Str)  Time Slot         Team 1              Team 2  \
# 30     0      Sat.          4  Colby College    Hamilton College
# 31     0      Sat.          5  Colby College  Middlebury College
#
#            Location
# 30  Bowdoin College
# 31  Bowdoin College
#     Week Day (Str)  Time Slot         Team 1            Team 2       Location
# 32     1      Sat.          2  Colby College  Williams College  Bates College
#     Week Day (Str)  Time Slot         Team 1            Team 2       Location
# 33     2      Fri.          1  Colby College  Tufts University  Bates College
# 34     2      Sat.          5  Colby College   Amherst College  Bates College
#     Week Day (Str)  Time Slot         Team 1           Team 2       Location
# 35     3      Fri.          0  Colby College    Bates College  Colby College
# 36     3      Sat.          2  Colby College  Bowdoin College  Colby College
#     Week Day (Str)  Time Slot         Team 1               Team 2  \
# 37     4      Fri.          0  Colby College  Wesleyan University
# 38     4      Sat.          3  Colby College  Connecticut College
# 39     4      Sat.          7  Colby College      Trinity College
#
#            Location
# 37  Trinity College
# 38  Trinity College
# 39  Trinity College
# Connecticut College
#     Week Day (Str)  Time Slot               Team 1            Team 2  \
# 40     0      Fri.          0  Connecticut College  Williams College
#
#             Location
# 40  Williams College
#     Week Day (Str)  Time Slot               Team 1            Team 2  \
# 41     1      Sat.          2  Connecticut College   Amherst College
# 42     1      Sat.          4  Connecticut College  Tufts University
#
#            Location
# 41  Amherst College
# 42  Amherst College
#     Week Day (Str)  Time Slot               Team 1               Team 2  \
# 43     2      Sat.          1  Connecticut College      Trinity College
# 44     2      Sat.          2  Connecticut College  Wesleyan University
#
#                Location
# 43  Connecticut College
# 44  Connecticut College
#     Week Day (Str)  Time Slot               Team 1              Team 2  \
# 45     3      Fri.          1  Connecticut College    Hamilton College
# 46     3      Sat.          4  Connecticut College  Middlebury College
#
#                Location
# 45  Wesleyan University
# 46  Wesleyan University
#     Week Day (Str)  Time Slot               Team 1           Team 2  \
# 47     4      Fri.          1  Connecticut College  Bowdoin College
# 48     4      Sat.          3  Connecticut College    Colby College
# 49     4      Sat.          8  Connecticut College    Bates College
#
#            Location
# 47  Trinity College
# 48  Trinity College
# 49  Trinity College
# Hamilton College
#     Week Day (Str)  Time Slot            Team 1           Team 2  \
# 50     0      Fri.          0  Hamilton College  Bowdoin College
# 51     0      Sat.          3  Hamilton College    Bates College
# 52     0      Sat.          4  Hamilton College    Colby College
#
#            Location
# 50  Bowdoin College
# 51  Bowdoin College
# 52  Bowdoin College
#     Week Day (Str)  Time Slot            Team 1              Team 2  \
# 53     1      Sat.          0  Hamilton College  Middlebury College
#
#             Location
# 53  Hamilton College
#     Week Day (Str)  Time Slot            Team 1            Team 2  \
# 54     2      Sat.          0  Hamilton College  Williams College
#
#             Location
# 54  Hamilton College
#     Week Day (Str)  Time Slot            Team 1               Team 2  \
# 55     3      Fri.          1  Hamilton College  Connecticut College
# 56     3      Sat.          2  Hamilton College  Wesleyan University
# 57     3      Sat.          3  Hamilton College      Trinity College
#
#                Location
# 55  Wesleyan University
# 56  Wesleyan University
# 57  Wesleyan University
#     Week Day (Str)  Time Slot            Team 1            Team 2  \
# 58     4      Fri.          1  Hamilton College  Tufts University
# 59     4      Sat.          3  Hamilton College   Amherst College
#
#               Location
# 58  Middlebury College
# 59  Middlebury College
# Middlebury College
#     Week Day (Str)  Time Slot              Team 1           Team 2  \
# 60     0      Fri.          1  Middlebury College    Bates College
# 61     0      Sat.          2  Middlebury College  Bowdoin College
# 62     0      Sat.          5  Middlebury College    Colby College
#
#            Location
# 60  Bowdoin College
# 61  Bowdoin College
# 62  Bowdoin College
#     Week Day (Str)  Time Slot              Team 1            Team 2  \
# 63     1      Sat.          0  Middlebury College  Hamilton College
#
#             Location
# 63  Hamilton College
#     Week Day (Str)  Time Slot              Team 1            Team 2  \
# 64     2      Sat.          1  Middlebury College  Williams College
#
#             Location
# 64  Hamilton College
#     Week Day (Str)  Time Slot              Team 1               Team 2  \
# 65     3      Fri.          0  Middlebury College      Trinity College
# 66     3      Sat.          4  Middlebury College  Connecticut College
# 67     3      Sat.          5  Middlebury College  Wesleyan University
#
#                Location
# 65  Wesleyan University
# 66  Wesleyan University
# 67  Wesleyan University
#     Week Day (Str)  Time Slot              Team 1            Team 2  \
# 68     4      Fri.          0  Middlebury College   Amherst College
# 69     4      Sat.          2  Middlebury College  Tufts University
#
#               Location
# 68  Middlebury College
# 69  Middlebury College
# Trinity College
#     Week Day (Str)  Time Slot           Team 1            Team 2  \
# 70     0      Sat.          2  Trinity College  Williams College
#
#             Location
# 70  Williams College
#     Week Day (Str)  Time Slot           Team 1            Team 2  \
# 71     1      Fri.          1  Trinity College   Amherst College
# 72     1      Sat.          3  Trinity College  Tufts University
#
#            Location
# 71  Amherst College
# 72  Amherst College
#     Week Day (Str)  Time Slot           Team 1               Team 2  \
# 73     2      Fri.          0  Trinity College  Wesleyan University
# 74     2      Sat.          1  Trinity College  Connecticut College
#
#                Location
# 73  Connecticut College
# 74  Connecticut College
#     Week Day (Str)  Time Slot           Team 1              Team 2  \
# 75     3      Fri.          0  Trinity College  Middlebury College
# 76     3      Sat.          3  Trinity College    Hamilton College
#
#                Location
# 75  Wesleyan University
# 76  Wesleyan University
#     Week Day (Str)  Time Slot           Team 1           Team 2  \
# 77     4      Fri.          2  Trinity College    Bates College
# 78     4      Sat.          5  Trinity College  Bowdoin College
# 79     4      Sat.          7  Trinity College    Colby College
#
#            Location
# 77  Trinity College
# 78  Trinity College
# 79  Trinity College
# Tufts University
#     Week Day (Str)  Time Slot            Team 1           Team 2  \
# 80     0      Sat.          0  Tufts University  Amherst College
#
#             Location
# 80  Tufts University
#     Week Day (Str)  Time Slot            Team 1               Team 2  \
# 81     1      Fri.          0  Tufts University  Wesleyan University
# 82     1      Sat.          3  Tufts University      Trinity College
# 83     1      Sat.          4  Tufts University  Connecticut College
#
#            Location
# 81  Amherst College
# 82  Amherst College
# 83  Amherst College
#     Week Day (Str)  Time Slot            Team 1           Team 2  \
# 84     2      Fri.          1  Tufts University    Colby College
# 85     2      Sat.          2  Tufts University    Bates College
# 86     2      Sat.          3  Tufts University  Bowdoin College
#
#          Location
# 84  Bates College
# 85  Bates College
# 86  Bates College
#     Week Day (Str)  Time Slot            Team 1            Team 2  \
# 87     3      Sat.          0  Tufts University  Williams College
#
#             Location
# 87  Tufts University
#     Week Day (Str)  Time Slot            Team 1              Team 2  \
# 88     4      Fri.          1  Tufts University    Hamilton College
# 89     4      Sat.          2  Tufts University  Middlebury College
#
#               Location
# 88  Middlebury College
# 89  Middlebury College
# Wesleyan University
#     Week Day (Str)  Time Slot               Team 1            Team 2  \
# 90     0      Sat.          1  Wesleyan University  Williams College
#
#             Location
# 90  Williams College
#     Week Day (Str)  Time Slot               Team 1            Team 2  \
# 91     1      Fri.          0  Wesleyan University  Tufts University
# 92     1      Sat.          5  Wesleyan University   Amherst College
#
#            Location
# 91  Amherst College
# 92  Amherst College
#     Week Day (Str)  Time Slot               Team 1               Team 2  \
# 93     2      Fri.          0  Wesleyan University      Trinity College
# 94     2      Sat.          2  Wesleyan University  Connecticut College
#
#                Location
# 93  Connecticut College
# 94  Connecticut College
#     Week Day (Str)  Time Slot               Team 1              Team 2  \
# 95     3      Sat.          2  Wesleyan University    Hamilton College
# 96     3      Sat.          5  Wesleyan University  Middlebury College
#
#                Location
# 95  Wesleyan University
# 96  Wesleyan University
#     Week Day (Str)  Time Slot               Team 1           Team 2  \
# 97     4      Fri.          0  Wesleyan University    Colby College
# 98     4      Sat.          4  Wesleyan University  Bowdoin College
# 99     4      Sat.          6  Wesleyan University    Bates College
#
#            Location
# 97  Trinity College
# 98  Trinity College
# 99  Trinity College
# Williams College
#      Week Day (Str)  Time Slot            Team 1               Team 2  \
# 100     0      Fri.          0  Williams College  Connecticut College
# 101     0      Sat.          1  Williams College  Wesleyan University
# 102     0      Sat.          2  Williams College      Trinity College
#
#              Location
# 100  Williams College
# 101  Williams College
# 102  Williams College
#      Week Day (Str)  Time Slot            Team 1           Team 2  \
# 103     1      Fri.          0  Williams College  Bowdoin College
# 104     1      Sat.          1  Williams College    Bates College
# 105     1      Sat.          2  Williams College    Colby College
#
#           Location
# 103  Bates College
# 104  Bates College
# 105  Bates College
#      Week Day (Str)  Time Slot            Team 1              Team 2  \
# 106     2      Sat.          0  Williams College    Hamilton College
# 107     2      Sat.          1  Williams College  Middlebury College
#
#              Location
# 106  Hamilton College
# 107  Hamilton College
#      Week Day (Str)  Time Slot            Team 1            Team 2  \
# 108     3      Sat.          0  Williams College  Tufts University
# 109     3      Sat.          1  Williams College   Amherst College
#
#              Location
# 108  Tufts University
# 109  Tufts University

# %% [markdown]
# # Check Schedule

# %%
# schedules in optimized pair
columns = [
    'Abbreviated Schedule ID',
    'Schedule ID'
]

optimized_schedule_analysis_df = pd.read_pickle(OPTIMIZED_SCHEDULE_ANALYSIS_FILENAME)
single_schedule_comparison_df = pd.read_pickle(SINGLE_SCHEDULE_COMPARISON_FILENAME)
single_schedule_comparison_df = single_schedule_comparison_df.iloc[selected_idxs]

name_to_id_mapping = create_venue_id_mapping_dicts_from_file(VENUES_MAPPING_FILENAME)[0]
venue_one_way_distance_matrix = pd.read_csv(DISTANCE_MATRIX_FILENAME, index_col=0)
venue_one_way_duration_matrix_hhmm = pd.read_csv(DURATION_MATRIX_HHMM_FILENAME, index_col=0)

display(single_schedule_comparison_df[columns])
# Out:
#   Abbreviated Schedule ID                        Schedule ID
# 0                  s0_1_3  15_2335_optimized_team_schedule_0
# 5                  s5_2_3   5_2235_optimized_team_schedule_0

# %%
# create list of optimized schedules
filenames = single_schedule_comparison_df['Schedule ID'].to_list()
filenames = [f"{fname}.csv" for fname in filenames]

filenames
# Out:
# ['15_2335_optimized_team_schedule_0.csv',
#  '5_2235_optimized_team_schedule_0.csv']

# %%
from src.configuration import WEEKEND_OVERNIGHT_THRESHOLD, DISTANCE_OVERNIGHT_THRESHOLD

print(f"WEEKEND_OVERNIGHT_THRESHOLD = {WEEKEND_OVERNIGHT_THRESHOLD}")
print("""
    \tMaximum number of miles to drive one-way without staying for an
    \tovernight between Friday and Saturday matches (recommended = 53
    \t==> max one-way distance with duration < 1 hour)
    """)
      
print(f"DISTANCE_OVERNIGHT_THRESHOLD = {DISTANCE_OVERNIGHT_THRESHOLD}")
print("""
    \tMaximum number of miles to drive one-way without staying for an
    \tovernight (recommended = 153 ==> max one-way distance with duration
    \t< 3 hours)
    """)


for filename in filenames:
    
    print("########################################")
    print(f"# {filename} #")
    print("########################################")

    schedule_df = pd.read_csv(f"results/single/optimized_schedules/{filename}", index_col=0)

    schedule_df['Home Game'] = schedule_df['Team 1'] == schedule_df['Location']
    schedule_df['Team 1 Name'] = schedule_df['Team 1']
    schedule_df['Location Name'] = schedule_df['Location']
    schedule_df['Team 1'] = schedule_df['Team 1'].map(name_to_id_mapping)
    schedule_df['Location'] = schedule_df['Location'].map(name_to_id_mapping)

    schedule_df['Team 1 Travel Distance (mi)'] = None
    schedule_df['Team 1 Travel Distance (hhmm)'] = None
    for idx, row in schedule_df.iterrows():
        schedule_df['Team 1 Travel Distance (mi)'][idx] = venue_one_way_distance_matrix.iloc[row['Team 1'], row['Location']]
        schedule_df['Team 1 Travel Distance (hhmm)'][idx] = venue_one_way_duration_matrix_hhmm.iloc[row['Team 1'], row['Location']]


    schedule_df['Distance Overnight'] = False
    schedule_df['Weekend Overnight'] = False
    for team_week, team_week_df in schedule_df.groupby(['Team 1', 'Week']):

        team_week_df = team_week_df.reset_index(drop=False)
        curr_team = team_week[0]

        # Iterate over team 1 matches for the week
        for idx, row in team_week_df.iterrows():
            current_match = team_week_df.loc[idx]
            schedule_df_idx = current_match['index']

            # Check for a distance overnight
            if is_distance_overnight(current_match, venue_one_way_distance_matrix, DISTANCE_OVERNIGHT_THRESHOLD):
                schedule_df['Distance Overnight'][schedule_df_idx] = True

            # Check for a weekend overnight
            if idx > 0:
                previous_match = team_week_df.loc[idx - 1]

                if is_weekend_overnight(previous_match, current_match, venue_one_way_distance_matrix, WEEKEND_OVERNIGHT_THRESHOLD):

                    # Count weekend overnight
                    schedule_df['Weekend Overnight'][schedule_df_idx] = True

                    # Remove distance overnight because have weekend overnight ==> already staying overnight
                    schedule_df['Distance Overnight'][schedule_df_idx] = False

                    break

    # Display results                
    columns = [
        'Week',
        'Day (Str)',
        'Time Slot',
        'Team 1 Name',
        'Team 2',
        'Location Name',
        'Home Game',
        'Team 1 Travel Distance (mi)',
        'Team 1 Travel Distance (hhmm)',
        'Distance Overnight',
        'Weekend Overnight'
    ]

    # for team_1_group_name, team_1_group in _.groupby('Team 1'):

    #         display(team_1_group[columns])
    #         print(single_schedule_comparison_df['Team Overnight Dict'][0][team_1_group_name])

    optimized_schedule_analysis_df = pd.read_pickle(OPTIMIZED_SCHEDULE_ANALYSIS_FILENAME)

    for team_1, team_1_df in schedule_df.groupby('Team 1'):

        print(f"TEAM {team_1}")
        _ = optimized_schedule_analysis_df[optimized_schedule_analysis_df['Schedule ID'] == filename[:-4]]
        print(f"   overnight = {_['Team Overnight Dict'].item()[team_1]}")
        print(f"   distance = {_['Team Distance Dict'].item()[team_1]}")

        display(team_1_df)

    #     for week, week_df in team_1_df.groupby('Week'):

    #         display(week_df[columns])
# Out:
# WEEKEND_OVERNIGHT_THRESHOLD = 53
#
#     	Maximum number of miles to drive one-way without staying for an
#     	overnight between Friday and Saturday matches (recommended = 53
#     	==> max one-way distance with duration < 1 hour)
#
# DISTANCE_OVERNIGHT_THRESHOLD = 153
#
#     	Maximum number of miles to drive one-way without staying for an
#     	overnight (recommended = 153 ==> max one-way distance with duration
#     	< 3 hours)
#
# ########################################
# # 15_2335_optimized_team_schedule_0.csv #
# ########################################
# /Users/hcederna/anaconda3/envs/schedule-optimization/lib/python3.7/site-packages/ipykernel_launcher.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hcederna/anaconda3/envs/schedule-optimization/lib/python3.7/site-packages/ipykernel_launcher.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hcederna/anaconda3/envs/schedule-optimization/lib/python3.7/site-packages/ipykernel_launcher.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hcederna/anaconda3/envs/schedule-optimization/lib/python3.7/site-packages/ipykernel_launcher.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hcederna/anaconda3/envs/schedule-optimization/lib/python3.7/site-packages/ipykernel_launcher.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# TEAM 0
#    overnight = 1
#    distance = 984
#    Week Day (Str)  Time Slot  Team 1               Team 2  Location  \
# 0     0      Fri.          1       0        Colby College         3
# 1     0      Sat.          2       0      Bowdoin College         3
# 2     0      Sat.          5       0        Bates College         3
# 3     1      Sat.          1       0     Tufts University         8
# 4     2      Fri.          1       0     Hamilton College         0
# 5     2      Sat.          2       0     Williams College         0
# 6     2      Sat.          5       0   Middlebury College         0
# 7     3      Sat.          0       0      Trinity College         7
# 8     4      Fri.          0       0  Connecticut College         7
# 9     4      Sat.          3       0  Wesleyan University         7
#
#    Home Game      Team 1 Name     Location Name Team 1 Travel Distance (mi)  \
# 0      False  Amherst College     Colby College                         246
# 1      False  Amherst College     Colby College                         246
# 2      False  Amherst College     Colby College                         246
# 3      False  Amherst College  Tufts University                          87
# 4       True  Amherst College   Amherst College                           0
# 5       True  Amherst College   Amherst College                           0
# 6       True  Amherst College   Amherst College                           0
# 7      False  Amherst College   Trinity College                          53
# 8      False  Amherst College   Trinity College                          53
# 9      False  Amherst College   Trinity College                          53
#
#   Team 1 Travel Distance (hhmm)  Distance Overnight  Weekend Overnight
# 0                          3:55                True              False
# 1                          3:55               False               True
# 2                          3:55               False              False
# 3                          1:45               False              False
# 4                          0:00               False              False
# 5                          0:00               False              False
# 6                          0:00               False              False
# 7                          1:01               False              False
# 8                          1:01               False              False
# 9                          1:01               False              False
# TEAM 1
#    overnight = 2
#    distance = 1282
#     Week Day (Str)  Time Slot  Team 1               Team 2  Location  \
# 10     0      Fri.          0       1      Trinity College         3
# 11     0      Sat.          5       1      Amherst College         3
# 12     1      Fri.          0       1      Bowdoin College         2
# 13     1      Sat.          2       1        Colby College         2
# 14     2      Fri.          0       1     Tufts University         1
# 15     3      Fri.          0       1  Wesleyan University         4
# 16     3      Sat.          2       1  Connecticut College         4
# 17     4      Fri.          0       1   Middlebury College         6
# 18     4      Sat.          3       1     Hamilton College         6
# 19     4      Sat.          5       1     Williams College         6
#
#     Home Game    Team 1 Name        Location Name Team 1 Travel Distance (mi)  \
# 10      False  Bates College        Colby College                          49
# 11      False  Bates College        Colby College                          49
# 12      False  Bates College      Bowdoin College                          21
# 13      False  Bates College      Bowdoin College                          21
# 14       True  Bates College        Bates College                           0
# 15      False  Bates College  Connecticut College                         240
# 16      False  Bates College  Connecticut College                         240
# 17      False  Bates College   Middlebury College                         261
# 18      False  Bates College   Middlebury College                         261
# 19      False  Bates College   Middlebury College                         261
#
#    Team 1 Travel Distance (hhmm)  Distance Overnight  Weekend Overnight
# 10                          0:51               False              False
# 11                          0:51               False              False
# 12                          0:39               False              False
# 13                          0:39               False              False
# 14                          0:00               False              False
# 15                          3:42                True              False
# 16                          3:42               False               True
# 17                          4:26                True              False
# 18                          4:26               False               True
# 19                          4:26               False              False
# TEAM 2
#    overnight = 2
#    distance = 1118
#     Week Day (Str)  Time Slot  Team 1               Team 2  Location  \
# 20     0      Sat.          2       2      Amherst College         3
# 21     0      Sat.          3       2      Trinity College         3
# 22     1      Fri.          0       2        Bates College         2
# 23     1      Sat.          1       2        Colby College         2
# 24     2      Sat.          2       2     Tufts University         1
# 25     3      Sat.          4       2  Connecticut College         4
# 26     3      Sat.          5       2  Wesleyan University         4
# 27     4      Fri.          1       2     Hamilton College         6
# 28     4      Sat.          6       2     Williams College         6
# 29     4      Sat.          8       2   Middlebury College         6
#
#     Home Game      Team 1 Name        Location Name  \
# 20      False  Bowdoin College        Colby College
# 21      False  Bowdoin College        Colby College
# 22       True  Bowdoin College      Bowdoin College
# 23       True  Bowdoin College      Bowdoin College
# 24      False  Bowdoin College        Bates College
# 25      False  Bowdoin College  Connecticut College
# 26      False  Bowdoin College  Connecticut College
# 27      False  Bowdoin College   Middlebury College
# 28      False  Bowdoin College   Middlebury College
# 29      False  Bowdoin College   Middlebury College
#
#    Team 1 Travel Distance (mi) Team 1 Travel Distance (hhmm)  \
# 20                          50                          0:52
# 21                          50                          0:52
# 22                           0                          0:00
# 23                           0                          0:00
# 24                          21                          0:39
# 25                         233                          3:38
# 26                         233                          3:38
# 27                         255                          4:22
# 28                         255                          4:22
# 29                         255                          4:22
#
#     Distance Overnight  Weekend Overnight
# 20               False              False
# 21               False              False
# 22               False              False
# 23               False              False
# 24               False              False
# 25                True              False
# 26                True              False
# 27                True              False
# 28               False               True
# 29               False              False
# TEAM 3
#    overnight = 2
#    distance = 1360
#     Week Day (Str)  Time Slot  Team 1               Team 2  Location  \
# 30     0      Fri.          1       3      Amherst College         3
# 31     0      Sat.          4       3      Trinity College         3
# 32     1      Sat.          1       3      Bowdoin College         2
# 33     1      Sat.          2       3        Bates College         2
# 34     2      Sat.          1       3     Tufts University         1
# 35     3      Fri.          1       3  Connecticut College         4
# 36     3      Sat.          3       3  Wesleyan University         4
# 37     4      Fri.          2       3     Williams College         6
# 38     4      Sat.          4       3     Hamilton College         6
# 39     4      Sat.          7       3   Middlebury College         6
#
#     Home Game    Team 1 Name        Location Name Team 1 Travel Distance (mi)  \
# 30       True  Colby College        Colby College                           0
# 31       True  Colby College        Colby College                           0
# 32      False  Colby College      Bowdoin College                          50
# 33      False  Colby College      Bowdoin College                          50
# 34      False  Colby College        Bates College                          49
# 35      False  Colby College  Connecticut College                         280
# 36      False  Colby College  Connecticut College                         280
# 37      False  Colby College   Middlebury College                         301
# 38      False  Colby College   Middlebury College                         301
# 39      False  Colby College   Middlebury College                         301
#
#    Team 1 Travel Distance (hhmm)  Distance Overnight  Weekend Overnight
# 30                          0:00               False              False
# 31                          0:00               False              False
# 32                          0:52               False              False
# 33                          0:52               False              False
# 34                          0:51               False              False
# 35                          4:13                True              False
# 36                          4:13               False               True
# 37                          4:57                True              False
# 38                          4:57               False               True
# 39                          4:57               False              False
# TEAM 4
#    overnight = 1
#    distance = 684
#     Week Day (Str)  Time Slot  Team 1               Team 2  Location  \
# 40     0      Sat.          0       4     Tufts University         9
# 41     1      Fri.          0       4   Middlebury College        10
# 42     1      Sat.          2       4     Williams College        10
# 43     1      Sat.          4       4     Hamilton College        10
# 44     2      Sat.          0       4  Wesleyan University         9
# 45     3      Fri.          1       4        Colby College         4
# 46     3      Sat.          2       4        Bates College         4
# 47     3      Sat.          4       4      Bowdoin College         4
# 48     4      Fri.          0       4      Amherst College         7
# 49     4      Sat.          2       4      Trinity College         7
#
#     Home Game          Team 1 Name        Location Name  \
# 40      False  Connecticut College  Wesleyan University
# 41      False  Connecticut College     Williams College
# 42      False  Connecticut College     Williams College
# 43      False  Connecticut College     Williams College
# 44      False  Connecticut College  Wesleyan University
# 45       True  Connecticut College  Connecticut College
# 46       True  Connecticut College  Connecticut College
# 47       True  Connecticut College  Connecticut College
# 48      False  Connecticut College      Trinity College
# 49      False  Connecticut College      Trinity College
#
#    Team 1 Travel Distance (mi) Team 1 Travel Distance (hhmm)  \
# 40                          40                          0:39
# 41                         158                          2:38
# 42                         158                          2:38
# 43                         158                          2:38
# 44                          40                          0:39
# 45                           0                          0:00
# 46                           0                          0:00
# 47                           0                          0:00
# 48                          52                          0:52
# 49                          52                          0:52
#
#     Distance Overnight  Weekend Overnight
# 40               False              False
# 41                True              False
# 42               False               True
# 43               False              False
# 44               False              False
# 45               False              False
# 46               False              False
# 47               False              False
# 48               False              False
# 49               False              False
# TEAM 5
#    overnight = 2
#    distance = 1328
#     Week Day (Str)  Time Slot  Team 1               Team 2  Location  \
# 50     0      Fri.          0       5   Middlebury College         5
# 51     0      Sat.          2       5     Williams College         5
# 52     1      Sat.          3       5  Wesleyan University        10
# 53     1      Sat.          4       5  Connecticut College        10
# 54     2      Fri.          1       5      Amherst College         0
# 55     2      Sat.          4       5      Trinity College         0
# 56     3      Fri.          0       5     Tufts University        10
# 57     4      Fri.          1       5      Bowdoin College         6
# 58     4      Sat.          3       5        Bates College         6
# 59     4      Sat.          4       5        Colby College         6
#
#     Home Game       Team 1 Name       Location Name  \
# 50       True  Hamilton College    Hamilton College
# 51       True  Hamilton College    Hamilton College
# 52      False  Hamilton College    Williams College
# 53      False  Hamilton College    Williams College
# 54      False  Hamilton College     Amherst College
# 55      False  Hamilton College     Amherst College
# 56      False  Hamilton College    Williams College
# 57      False  Hamilton College  Middlebury College
# 58      False  Hamilton College  Middlebury College
# 59      False  Hamilton College  Middlebury College
#
#    Team 1 Travel Distance (mi) Team 1 Travel Distance (hhmm)  \
# 50                           0                          0:00
# 51                           0                          0:00
# 52                         144                          2:33
# 53                         144                          2:33
# 54                         206                          3:18
# 55                         206                          3:18
# 56                         144                          2:33
# 57                         170                          3:29
# 58                         170                          3:29
# 59                         170                          3:29
#
#     Distance Overnight  Weekend Overnight
# 50               False              False
# 51               False              False
# 52               False              False
# 53               False              False
# 54                True              False
# 55               False               True
# 56               False              False
# 57                True              False
# 58               False               True
# 59               False              False
# TEAM 6
#    overnight = 2
#    distance = 1078
#     Week Day (Str)  Time Slot  Team 1               Team 2  Location  \
# 60     0      Fri.          0       6     Hamilton College         5
# 61     0      Sat.          1       6     Williams College         5
# 62     1      Fri.          0       6  Connecticut College        10
# 63     1      Sat.          5       6  Wesleyan University        10
# 64     2      Sat.          3       6      Trinity College         0
# 65     2      Sat.          5       6      Amherst College         0
# 66     3      Sat.          2       6     Tufts University        10
# 67     4      Fri.          0       6        Bates College         6
# 68     4      Sat.          7       6        Colby College         6
# 69     4      Sat.          8       6      Bowdoin College         6
#
#     Home Game         Team 1 Name       Location Name  \
# 60      False  Middlebury College    Hamilton College
# 61      False  Middlebury College    Hamilton College
# 62      False  Middlebury College    Williams College
# 63      False  Middlebury College    Williams College
# 64      False  Middlebury College     Amherst College
# 65      False  Middlebury College     Amherst College
# 66      False  Middlebury College    Williams College
# 67       True  Middlebury College  Middlebury College
# 68       True  Middlebury College  Middlebury College
# 69       True  Middlebury College  Middlebury College
#
#    Team 1 Travel Distance (mi) Team 1 Travel Distance (hhmm)  \
# 60                         170                          3:29
# 61                         170                          3:29
# 62                         108                          2:09
# 63                         108                          2:09
# 64                         153                          2:54
# 65                         153                          2:54
# 66                         108                          2:09
# 67                           0                          0:00
# 68                           0                          0:00
# 69                           0                          0:00
#
#     Distance Overnight  Weekend Overnight
# 60                True              False
# 61               False               True
# 62               False              False
# 63               False               True
# 64               False              False
# 65               False              False
# 66               False              False
# 67               False              False
# 68               False              False
# 69               False              False
# TEAM 7
#    overnight = 1
#    distance = 976
#     Week Day (Str)  Time Slot  Team 1               Team 2  Location  \
# 70     0      Fri.          0       7        Bates College         3
# 71     0      Sat.          3       7      Bowdoin College         3
# 72     0      Sat.          4       7        Colby College         3
# 73     1      Sat.          0       7     Tufts University         8
# 74     2      Fri.          0       7     Williams College         0
# 75     2      Sat.          3       7   Middlebury College         0
# 76     2      Sat.          4       7     Hamilton College         0
# 77     3      Sat.          0       7      Amherst College         7
# 78     4      Fri.          1       7  Wesleyan University         7
# 79     4      Sat.          2       7  Connecticut College         7
#
#     Home Game      Team 1 Name     Location Name Team 1 Travel Distance (mi)  \
# 70      False  Trinity College     Colby College                         274
# 71      False  Trinity College     Colby College                         274
# 72      False  Trinity College     Colby College                         274
# 73      False  Trinity College  Tufts University                         108
# 74      False  Trinity College   Amherst College                          53
# 75      False  Trinity College   Amherst College                          53
# 76      False  Trinity College   Amherst College                          53
# 77       True  Trinity College   Trinity College                           0
# 78       True  Trinity College   Trinity College                           0
# 79       True  Trinity College   Trinity College                           0
#
#    Team 1 Travel Distance (hhmm)  Distance Overnight  Weekend Overnight
# 70                          4:10                True              False
# 71                          4:10               False               True
# 72                          4:10               False              False
# 73                          1:46               False              False
# 74                          1:01               False              False
# 75                          1:01               False              False
# 76                          1:01               False              False
# 77                          0:00               False              False
# 78                          0:00               False              False
# 79                          0:00               False              False
# TEAM 8
#    overnight = 2
#    distance = 778
#     Week Day (Str)  Time Slot  Team 1               Team 2  Location  \
# 80     0      Sat.          0       8  Connecticut College         9
# 81     0      Sat.          1       8  Wesleyan University         9
# 82     1      Sat.          0       8      Trinity College         8
# 83     1      Sat.          1       8      Amherst College         8
# 84     2      Fri.          0       8        Bates College         1
# 85     2      Sat.          1       8        Colby College         1
# 86     2      Sat.          2       8      Bowdoin College         1
# 87     3      Fri.          0       8     Hamilton College        10
# 88     3      Sat.          1       8     Williams College        10
# 89     3      Sat.          2       8   Middlebury College        10
#
#     Home Game       Team 1 Name        Location Name  \
# 80      False  Tufts University  Wesleyan University
# 81      False  Tufts University  Wesleyan University
# 82       True  Tufts University     Tufts University
# 83       True  Tufts University     Tufts University
# 84      False  Tufts University        Bates College
# 85      False  Tufts University        Bates College
# 86      False  Tufts University        Bates College
# 87      False  Tufts University     Williams College
# 88      False  Tufts University     Williams College
# 89      False  Tufts University     Williams College
#
#    Team 1 Travel Distance (mi) Team 1 Travel Distance (hhmm)  \
# 80                         119                          1:58
# 81                         119                          1:58
# 82                           0                          0:00
# 83                           0                          0:00
# 84                         140                          2:14
# 85                         140                          2:14
# 86                         140                          2:14
# 87                         130                          2:43
# 88                         130                          2:43
# 89                         130                          2:43
#
#     Distance Overnight  Weekend Overnight
# 80               False              False
# 81               False              False
# 82               False              False
# 83               False              False
# 84               False              False
# 85               False               True
# 86               False              False
# 87               False              False
# 88               False               True
# 89               False              False
# TEAM 9
#    overnight = 1
#    distance = 476
#     Week Day (Str)  Time Slot  Team 1               Team 2  Location  \
# 90     0      Sat.          1       9     Tufts University         9
# 91     1      Fri.          1       9     Williams College        10
# 92     1      Sat.          3       9     Hamilton College        10
# 93     1      Sat.          5       9   Middlebury College        10
# 94     2      Sat.          0       9  Connecticut College         9
# 95     3      Fri.          0       9        Bates College         4
# 96     3      Sat.          3       9        Colby College         4
# 97     3      Sat.          5       9      Bowdoin College         4
# 98     4      Fri.          1       9      Trinity College         7
# 99     4      Sat.          3       9      Amherst College         7
#
#     Home Game          Team 1 Name        Location Name  \
# 90       True  Wesleyan University  Wesleyan University
# 91      False  Wesleyan University     Williams College
# 92      False  Wesleyan University     Williams College
# 93      False  Wesleyan University     Williams College
# 94       True  Wesleyan University  Wesleyan University
# 95      False  Wesleyan University  Connecticut College
# 96      False  Wesleyan University  Connecticut College
# 97      False  Wesleyan University  Connecticut College
# 98      False  Wesleyan University      Trinity College
# 99      False  Wesleyan University      Trinity College
#
#    Team 1 Travel Distance (mi) Team 1 Travel Distance (hhmm)  \
# 90                           0                          0:00
# 91                         126                          2:10
# 92                         126                          2:10
# 93                         126                          2:10
# 94                           0                          0:00
# 95                          40                          0:39
# 96                          40                          0:39
# 97                          40                          0:39
# 98                          16                          0:24
# 99                          16                          0:24
#
#     Distance Overnight  Weekend Overnight
# 90               False              False
# 91               False              False
# 92               False               True
# 93               False              False
# 94               False              False
# 95               False              False
# 96               False              False
# 97               False              False
# 98               False              False
# 99               False              False
# TEAM 10
#    overnight = 2
#    distance = 624
#      Week Day (Str)  Time Slot  Team 1               Team 2  Location  \
# 100     0      Sat.          1      10   Middlebury College         5
# 101     0      Sat.          2      10     Hamilton College         5
# 102     1      Fri.          1      10  Wesleyan University        10
# 103     1      Sat.          2      10  Connecticut College        10
# 104     2      Fri.          0      10      Trinity College         0
# 105     2      Sat.          2      10      Amherst College         0
# 106     3      Sat.          1      10     Tufts University        10
# 107     4      Fri.          2      10        Colby College         6
# 108     4      Sat.          5      10        Bates College         6
# 109     4      Sat.          6      10      Bowdoin College         6
#
#      Home Game       Team 1 Name       Location Name  \
# 100      False  Williams College    Hamilton College
# 101      False  Williams College    Hamilton College
# 102       True  Williams College    Williams College
# 103       True  Williams College    Williams College
# 104      False  Williams College     Amherst College
# 105      False  Williams College     Amherst College
# 106       True  Williams College    Williams College
# 107      False  Williams College  Middlebury College
# 108      False  Williams College  Middlebury College
# 109      False  Williams College  Middlebury College
#
#     Team 1 Travel Distance (mi) Team 1 Travel Distance (hhmm)  \
# 100                         144                          2:33
# 101                         144                          2:33
# 102                           0                          0:00
# 103                           0                          0:00
# 104                          60                          1:26
# 105                          60                          1:26
# 106                           0                          0:00
# 107                         108                          2:09
# 108                         108                          2:09
# 109                         108                          2:09
#
#      Distance Overnight  Weekend Overnight
# 100               False              False
# 101               False              False
# 102               False              False
# 103               False              False
# 104               False              False
# 105               False               True
# 106               False              False
# 107               False              False
# 108               False               True
# 109               False              False
# ########################################
# # 5_2235_optimized_team_schedule_0.csv #
# ########################################
# /Users/hcederna/anaconda3/envs/schedule-optimization/lib/python3.7/site-packages/ipykernel_launcher.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hcederna/anaconda3/envs/schedule-optimization/lib/python3.7/site-packages/ipykernel_launcher.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hcederna/anaconda3/envs/schedule-optimization/lib/python3.7/site-packages/ipykernel_launcher.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hcederna/anaconda3/envs/schedule-optimization/lib/python3.7/site-packages/ipykernel_launcher.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hcederna/anaconda3/envs/schedule-optimization/lib/python3.7/site-packages/ipykernel_launcher.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# TEAM 0
#    overnight = 2
#    distance = 1066
#    Week Day (Str)  Time Slot  Team 1               Team 2  Location  \
# 0     0      Sat.          0       0     Tufts University         8
# 1     1      Fri.          1       0      Trinity College         0
# 2     1      Sat.          2       0  Connecticut College         0
# 3     1      Sat.          5       0  Wesleyan University         0
# 4     2      Fri.          0       0      Bowdoin College         1
# 5     2      Sat.          4       0        Bates College         1
# 6     2      Sat.          5       0        Colby College         1
# 7     3      Sat.          1       0     Williams College         8
# 8     4      Fri.          0       0   Middlebury College         6
# 9     4      Sat.          3       0     Hamilton College         6
#
#    Home Game      Team 1 Name       Location Name Team 1 Travel Distance (mi)  \
# 0      False  Amherst College    Tufts University                          87
# 1       True  Amherst College     Amherst College                           0
# 2       True  Amherst College     Amherst College                           0
# 3       True  Amherst College     Amherst College                           0
# 4      False  Amherst College       Bates College                         206
# 5      False  Amherst College       Bates College                         206
# 6      False  Amherst College       Bates College                         206
# 7      False  Amherst College    Tufts University                          87
# 8      False  Amherst College  Middlebury College                         153
# 9      False  Amherst College  Middlebury College                         153
#
#   Team 1 Travel Distance (hhmm)  Distance Overnight  Weekend Overnight
# 0                          1:45               False              False
# 1                          0:00               False              False
# 2                          0:00               False              False
# 3                          0:00               False              False
# 4                          3:24                True              False
# 5                          3:24               False               True
# 6                          3:24               False              False
# 7                          1:45               False              False
# 8                          2:54               False              False
# 9                          2:54               False               True
# TEAM 1
#    overnight = 1
#    distance = 748
#     Week Day (Str)  Time Slot  Team 1               Team 2  Location  \
# 10     0      Fri.          1       1   Middlebury College         2
# 11     0      Sat.          3       1     Hamilton College         2
# 12     1      Sat.          1       1     Williams College         1
# 13     2      Sat.          2       1     Tufts University         1
# 14     2      Sat.          4       1      Amherst College         1
# 15     3      Fri.          0       1        Colby College         3
# 16     3      Sat.          1       1      Bowdoin College         3
# 17     4      Fri.          2       1      Trinity College         7
# 18     4      Sat.          6       1  Wesleyan University         7
# 19     4      Sat.          8       1  Connecticut College         7
#
#     Home Game    Team 1 Name    Location Name Team 1 Travel Distance (mi)  \
# 10      False  Bates College  Bowdoin College                          21
# 11      False  Bates College  Bowdoin College                          21
# 12       True  Bates College    Bates College                           0
# 13       True  Bates College    Bates College                           0
# 14       True  Bates College    Bates College                           0
# 15      False  Bates College    Colby College                          49
# 16      False  Bates College    Colby College                          49
# 17      False  Bates College  Trinity College                         234
# 18      False  Bates College  Trinity College                         234
# 19      False  Bates College  Trinity College                         234
#
#    Team 1 Travel Distance (hhmm)  Distance Overnight  Weekend Overnight
# 10                          0:39               False              False
# 11                          0:39               False              False
# 12                          0:00               False              False
# 13                          0:00               False              False
# 14                          0:00               False              False
# 15                          0:51               False              False
# 16                          0:51               False              False
# 17                          3:39                True              False
# 18                          3:39               False               True
# 19                          3:39               False              False
# TEAM 2
#    overnight = 1
#    distance = 680
#     Week Day (Str)  Time Slot  Team 1               Team 2  Location  \
# 20     0      Fri.          0       2     Hamilton College         2
# 21     0      Sat.          2       2   Middlebury College         2
# 22     1      Fri.          0       2     Williams College         1
# 23     2      Fri.          0       2      Amherst College         1
# 24     2      Sat.          3       2     Tufts University         1
# 25     3      Sat.          1       2        Bates College         3
# 26     3      Sat.          2       2        Colby College         3
# 27     4      Fri.          1       2  Connecticut College         7
# 28     4      Sat.          4       2  Wesleyan University         7
# 29     4      Sat.          5       2      Trinity College         7
#
#     Home Game      Team 1 Name    Location Name Team 1 Travel Distance (mi)  \
# 20       True  Bowdoin College  Bowdoin College                           0
# 21       True  Bowdoin College  Bowdoin College                           0
# 22      False  Bowdoin College    Bates College                          21
# 23      False  Bowdoin College    Bates College                          21
# 24      False  Bowdoin College    Bates College                          21
# 25      False  Bowdoin College    Colby College                          50
# 26      False  Bowdoin College    Colby College                          50
# 27      False  Bowdoin College  Trinity College                         227
# 28      False  Bowdoin College  Trinity College                         227
# 29      False  Bowdoin College  Trinity College                         227
#
#    Team 1 Travel Distance (hhmm)  Distance Overnight  Weekend Overnight
# 20                          0:00               False              False
# 21                          0:00               False              False
# 22                          0:39               False              False
# 23                          0:39               False              False
# 24                          0:39               False              False
# 25                          0:52               False              False
# 26                          0:52               False              False
# 27                          3:35                True              False
# 28                          3:35               False               True
# 29                          3:35               False              False
# TEAM 3
#    overnight = 1
#    distance = 942
#     Week Day (Str)  Time Slot  Team 1               Team 2  Location  \
# 30     0      Sat.          4       3     Hamilton College         2
# 31     0      Sat.          5       3   Middlebury College         2
# 32     1      Sat.          2       3     Williams College         1
# 33     2      Fri.          1       3     Tufts University         1
# 34     2      Sat.          5       3      Amherst College         1
# 35     3      Fri.          0       3        Bates College         3
# 36     3      Sat.          2       3      Bowdoin College         3
# 37     4      Fri.          0       3  Wesleyan University         7
# 38     4      Sat.          3       3  Connecticut College         7
# 39     4      Sat.          7       3      Trinity College         7
#
#     Home Game    Team 1 Name    Location Name Team 1 Travel Distance (mi)  \
# 30      False  Colby College  Bowdoin College                          50
# 31      False  Colby College  Bowdoin College                          50
# 32      False  Colby College    Bates College                          49
# 33      False  Colby College    Bates College                          49
# 34      False  Colby College    Bates College                          49
# 35       True  Colby College    Colby College                           0
# 36       True  Colby College    Colby College                           0
# 37      False  Colby College  Trinity College                         274
# 38      False  Colby College  Trinity College                         274
# 39      False  Colby College  Trinity College                         274
#
#    Team 1 Travel Distance (hhmm)  Distance Overnight  Weekend Overnight
# 30                          0:52               False              False
# 31                          0:52               False              False
# 32                          0:51               False              False
# 33                          0:51               False              False
# 34                          0:51               False              False
# 35                          0:00               False              False
# 36                          0:00               False              False
# 37                          4:10                True              False
# 38                          4:10               False               True
# 39                          4:10               False              False
# TEAM 4
#    overnight = 1
#    distance = 882
#     Week Day (Str)  Time Slot  Team 1               Team 2  Location  \
# 40     0      Fri.          0       4     Williams College        10
# 41     1      Sat.          2       4      Amherst College         0
# 42     1      Sat.          4       4     Tufts University         0
# 43     2      Sat.          1       4      Trinity College         4
# 44     2      Sat.          2       4  Wesleyan University         4
# 45     3      Fri.          1       4     Hamilton College         9
# 46     3      Sat.          4       4   Middlebury College         9
# 47     4      Fri.          1       4      Bowdoin College         7
# 48     4      Sat.          3       4        Colby College         7
# 49     4      Sat.          8       4        Bates College         7
#
#     Home Game          Team 1 Name        Location Name  \
# 40      False  Connecticut College     Williams College
# 41      False  Connecticut College      Amherst College
# 42      False  Connecticut College      Amherst College
# 43       True  Connecticut College  Connecticut College
# 44       True  Connecticut College  Connecticut College
# 45      False  Connecticut College  Wesleyan University
# 46      False  Connecticut College  Wesleyan University
# 47      False  Connecticut College      Trinity College
# 48      False  Connecticut College      Trinity College
# 49      False  Connecticut College      Trinity College
#
#    Team 1 Travel Distance (mi) Team 1 Travel Distance (hhmm)  \
# 40                         158                          2:38
# 41                          99                          1:40
# 42                          99                          1:40
# 43                           0                          0:00
# 44                           0                          0:00
# 45                          40                          0:39
# 46                          40                          0:39
# 47                          52                          0:52
# 48                          52                          0:52
# 49                          52                          0:52
#
#     Distance Overnight  Weekend Overnight
# 40                True              False
# 41               False              False
# 42               False              False
# 43               False              False
# 44               False              False
# 45               False              False
# 46               False              False
# 47               False              False
# 48               False              False
# 49               False              False
# TEAM 5
#    overnight = 3
#    distance = 1610
#     Week Day (Str)  Time Slot  Team 1               Team 2  Location  \
# 50     0      Fri.          0       5      Bowdoin College         2
# 51     0      Sat.          3       5        Bates College         2
# 52     0      Sat.          4       5        Colby College         2
# 53     1      Sat.          0       5   Middlebury College         5
# 54     2      Sat.          0       5     Williams College         5
# 55     3      Fri.          1       5  Connecticut College         9
# 56     3      Sat.          2       5  Wesleyan University         9
# 57     3      Sat.          3       5      Trinity College         9
# 58     4      Fri.          1       5     Tufts University         6
# 59     4      Sat.          3       5      Amherst College         6
#
#     Home Game       Team 1 Name        Location Name  \
# 50      False  Hamilton College      Bowdoin College
# 51      False  Hamilton College      Bowdoin College
# 52      False  Hamilton College      Bowdoin College
# 53       True  Hamilton College     Hamilton College
# 54       True  Hamilton College     Hamilton College
# 55      False  Hamilton College  Wesleyan University
# 56      False  Hamilton College  Wesleyan University
# 57      False  Hamilton College  Wesleyan University
# 58      False  Hamilton College   Middlebury College
# 59      False  Hamilton College   Middlebury College
#
#    Team 1 Travel Distance (mi) Team 1 Travel Distance (hhmm)  \
# 50                         400                          6:10
# 51                         400                          6:10
# 52                         400                          6:10
# 53                           0                          0:00
# 54                           0                          0:00
# 55                         235                          3:39
# 56                         235                          3:39
# 57                         235                          3:39
# 58                         170                          3:29
# 59                         170                          3:29
#
#     Distance Overnight  Weekend Overnight
# 50                True              False
# 51               False               True
# 52               False              False
# 53               False              False
# 54               False              False
# 55                True              False
# 56               False               True
# 57               False              False
# 58                True              False
# 59               False               True
# TEAM 6
#    overnight = 4
#    distance = 1616
#     Week Day (Str)  Time Slot  Team 1               Team 2  Location  \
# 60     0      Fri.          1       6        Bates College         2
# 61     0      Sat.          2       6      Bowdoin College         2
# 62     0      Sat.          5       6        Colby College         2
# 63     1      Sat.          0       6     Hamilton College         5
# 64     2      Sat.          1       6     Williams College         5
# 65     3      Fri.          0       6      Trinity College         9
# 66     3      Sat.          4       6  Connecticut College         9
# 67     3      Sat.          5       6  Wesleyan University         9
# 68     4      Fri.          0       6      Amherst College         6
# 69     4      Sat.          2       6     Tufts University         6
#
#     Home Game         Team 1 Name        Location Name  \
# 60      False  Middlebury College      Bowdoin College
# 61      False  Middlebury College      Bowdoin College
# 62      False  Middlebury College      Bowdoin College
# 63      False  Middlebury College     Hamilton College
# 64      False  Middlebury College     Hamilton College
# 65      False  Middlebury College  Wesleyan University
# 66      False  Middlebury College  Wesleyan University
# 67      False  Middlebury College  Wesleyan University
# 68       True  Middlebury College   Middlebury College
# 69       True  Middlebury College   Middlebury College
#
#    Team 1 Travel Distance (mi) Team 1 Travel Distance (hhmm)  \
# 60                         255                          4:22
# 61                         255                          4:22
# 62                         255                          4:22
# 63                         170                          3:29
# 64                         170                          3:29
# 65                         213                          3:45
# 66                         213                          3:45
# 67                         213                          3:45
# 68                           0                          0:00
# 69                           0                          0:00
#
#     Distance Overnight  Weekend Overnight
# 60                True              False
# 61               False               True
# 62               False              False
# 63                True              False
# 64                True              False
# 65                True              False
# 66               False               True
# 67               False              False
# 68               False              False
# 69               False              False
# TEAM 7
#    overnight = 0
#    distance = 706
#     Week Day (Str)  Time Slot  Team 1               Team 2  Location  \
# 70     0      Sat.          2       7     Williams College        10
# 71     1      Fri.          1       7      Amherst College         0
# 72     1      Sat.          3       7     Tufts University         0
# 73     2      Fri.          0       7  Wesleyan University         4
# 74     2      Sat.          1       7  Connecticut College         4
# 75     3      Fri.          0       7   Middlebury College         9
# 76     3      Sat.          3       7     Hamilton College         9
# 77     4      Fri.          2       7        Bates College         7
# 78     4      Sat.          5       7      Bowdoin College         7
# 79     4      Sat.          7       7        Colby College         7
#
#     Home Game      Team 1 Name        Location Name  \
# 70      False  Trinity College     Williams College
# 71      False  Trinity College      Amherst College
# 72      False  Trinity College      Amherst College
# 73      False  Trinity College  Connecticut College
# 74      False  Trinity College  Connecticut College
# 75      False  Trinity College  Wesleyan University
# 76      False  Trinity College  Wesleyan University
# 77       True  Trinity College      Trinity College
# 78       True  Trinity College      Trinity College
# 79       True  Trinity College      Trinity College
#
#    Team 1 Travel Distance (mi) Team 1 Travel Distance (hhmm)  \
# 70                         111                          1:57
# 71                          53                          1:01
# 72                          53                          1:01
# 73                          52                          0:52
# 74                          52                          0:52
# 75                          16                          0:24
# 76                          16                          0:24
# 77                           0                          0:00
# 78                           0                          0:00
# 79                           0                          0:00
#
#     Distance Overnight  Weekend Overnight
# 70               False              False
# 71               False              False
# 72               False              False
# 73               False              False
# 74               False              False
# 75               False              False
# 76               False              False
# 77               False              False
# 78               False              False
# 79               False              False
# TEAM 8
#    overnight = 3
#    distance = 820
#     Week Day (Str)  Time Slot  Team 1               Team 2  Location  \
# 80     0      Sat.          0       8      Amherst College         8
# 81     1      Fri.          0       8  Wesleyan University         0
# 82     1      Sat.          3       8      Trinity College         0
# 83     1      Sat.          4       8  Connecticut College         0
# 84     2      Fri.          1       8        Colby College         1
# 85     2      Sat.          2       8        Bates College         1
# 86     2      Sat.          3       8      Bowdoin College         1
# 87     3      Sat.          0       8     Williams College         8
# 88     4      Fri.          1       8     Hamilton College         6
# 89     4      Sat.          2       8   Middlebury College         6
#
#     Home Game       Team 1 Name       Location Name  \
# 80       True  Tufts University    Tufts University
# 81      False  Tufts University     Amherst College
# 82      False  Tufts University     Amherst College
# 83      False  Tufts University     Amherst College
# 84      False  Tufts University       Bates College
# 85      False  Tufts University       Bates College
# 86      False  Tufts University       Bates College
# 87       True  Tufts University    Tufts University
# 88      False  Tufts University  Middlebury College
# 89      False  Tufts University  Middlebury College
#
#    Team 1 Travel Distance (mi) Team 1 Travel Distance (hhmm)  \
# 80                           0                          0:00
# 81                          87                          1:45
# 82                          87                          1:45
# 83                          87                          1:45
# 84                         140                          2:14
# 85                         140                          2:14
# 86                         140                          2:14
# 87                           0                          0:00
# 88                         183                          3:14
# 89                         183                          3:14
#
#     Distance Overnight  Weekend Overnight
# 80               False              False
# 81               False              False
# 82               False               True
# 83               False              False
# 84               False              False
# 85               False               True
# 86               False              False
# 87               False              False
# 88                True              False
# 89               False               True
# TEAM 9
#    overnight = 1
#    distance = 610
#     Week Day (Str)  Time Slot  Team 1               Team 2  Location  \
# 90     0      Sat.          1       9     Williams College        10
# 91     1      Fri.          0       9     Tufts University         0
# 92     1      Sat.          5       9      Amherst College         0
# 93     2      Fri.          0       9      Trinity College         4
# 94     2      Sat.          2       9  Connecticut College         4
# 95     3      Sat.          2       9     Hamilton College         9
# 96     3      Sat.          5       9   Middlebury College         9
# 97     4      Fri.          0       9        Colby College         7
# 98     4      Sat.          4       9      Bowdoin College         7
# 99     4      Sat.          6       9        Bates College         7
#
#     Home Game          Team 1 Name        Location Name  \
# 90      False  Wesleyan University     Williams College
# 91      False  Wesleyan University      Amherst College
# 92      False  Wesleyan University      Amherst College
# 93      False  Wesleyan University  Connecticut College
# 94      False  Wesleyan University  Connecticut College
# 95       True  Wesleyan University  Wesleyan University
# 96       True  Wesleyan University  Wesleyan University
# 97      False  Wesleyan University      Trinity College
# 98      False  Wesleyan University      Trinity College
# 99      False  Wesleyan University      Trinity College
#
#    Team 1 Travel Distance (mi) Team 1 Travel Distance (hhmm)  \
# 90                         126                          2:10
# 91                          67                          1:14
# 92                          67                          1:14
# 93                          40                          0:39
# 94                          40                          0:39
# 95                           0                          0:00
# 96                           0                          0:00
# 97                          16                          0:24
# 98                          16                          0:24
# 99                          16                          0:24
#
#     Distance Overnight  Weekend Overnight
# 90               False              False
# 91               False              False
# 92               False               True
# 93               False              False
# 94               False              False
# 95               False              False
# 96               False              False
# 97               False              False
# 98               False              False
# 99               False              False
# TEAM 10
#    overnight = 1
#    distance = 1046
#      Week Day (Str)  Time Slot  Team 1               Team 2  Location  \
# 100     0      Fri.          0      10  Connecticut College        10
# 101     0      Sat.          1      10  Wesleyan University        10
# 102     0      Sat.          2      10      Trinity College        10
# 103     1      Fri.          0      10      Bowdoin College         1
# 104     1      Sat.          1      10        Bates College         1
# 105     1      Sat.          2      10        Colby College         1
# 106     2      Sat.          0      10     Hamilton College         5
# 107     2      Sat.          1      10   Middlebury College         5
# 108     3      Sat.          0      10     Tufts University         8
# 109     3      Sat.          1      10      Amherst College         8
#
#      Home Game       Team 1 Name     Location Name  \
# 100       True  Williams College  Williams College
# 101       True  Williams College  Williams College
# 102       True  Williams College  Williams College
# 103      False  Williams College     Bates College
# 104      False  Williams College     Bates College
# 105      False  Williams College     Bates College
# 106      False  Williams College  Hamilton College
# 107      False  Williams College  Hamilton College
# 108      False  Williams College  Tufts University
# 109      False  Williams College  Tufts University
#
#     Team 1 Travel Distance (mi) Team 1 Travel Distance (hhmm)  \
# 100                           0                          0:00
# 101                           0                          0:00
# 102                           0                          0:00
# 103                         249                          4:22
# 104                         249                          4:22
# 105                         249                          4:22
# 106                         144                          2:33
# 107                         144                          2:33
# 108                         130                          2:43
# 109                         130                          2:43
#
#      Distance Overnight  Weekend Overnight
# 100               False              False
# 101               False              False
# 102               False              False
# 103                True              False
# 104               False               True
# 105               False              False
# 106               False              False
# 107               False              False
# 108               False              False
# 109               False              False

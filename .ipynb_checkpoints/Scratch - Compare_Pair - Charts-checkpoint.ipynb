# %% [markdown]
# # Compare Optimized & Previous NESCAC Volleyball Conference Schedule Pairs - Chart Creation
#
# Let's compare the optimized schedule pairs with the previous NESCAC schedule pairs to see how we did.

# %%
from src.configuration import *
from src.analyze_schedule import *

print("Loading necessary information ...\n")
best_pair_optimized_schedule_analysis_df = pd.read_pickle(BEST_PAIR_OPTIMIZED_SCHEDULE_ANALYSIS_FILENAME)
pair_nescac_schedule_analysis_df = pd.read_pickle(PAIR_NESCAC_SCHEDULE_ANALYSIS_FILENAME)

print("Creating pair schedule comparison DataFrame ...\n")
pair_schedule_comparison_df = best_pair_optimized_schedule_analysis_df.append(pair_nescac_schedule_analysis_df)
pair_schedule_comparison_df = create_score_columns(
    analysis_df=pair_schedule_comparison_df, 
    score_total_cost_weight=SCHEDULE_SCORE_TOTAL_COST_WEIGHT)
pair_schedule_comparison_df = create_optimized_change_columns(pair_schedule_comparison_df)
pair_schedule_comparison_df = pair_schedule_comparison_df.sort_values('Pair/Quad Score', ascending=True).reset_index(drop=True)

print("Saving pair schedule comparison to pickle ...")
pair_schedule_comparison_df.to_pickle(PAIR_SCHEDULE_COMPARISON_FILENAME)
print("... Saved as \"{}\"".format(PAIR_SCHEDULE_COMPARISON_FILENAME))

print("Preview:")
display(pair_schedule_comparison_df.head())
print()
# Out:
# Loading necessary information ...
#
# Creating pair schedule comparison DataFrame ...
#
# Saving pair schedule comparison to pickle ...
# ... Saved as "results/pair/pair_schedule_comparison.pickle"
# Preview:
#    (Average) Schedule Score  (Average) Team Experience Score  \
# 0                 21.184784                        31.703908
# 1                 22.592830                        34.376195
# 2                 24.008565                        28.339588
# 3                 25.315768                        40.445232
# 4                 27.109124                        39.889669
#
#   (Average) Team Home Game (Min, Max, Rng)  \
# 0                          (1.0, 3.0, 2.0)
# 1                          (1.0, 3.0, 2.0)
# 2                          (1.5, 3.0, 1.5)
# 3                          (1.5, 3.0, 1.5)
# 4                          (1.5, 3.0, 1.5)
#
#    (Average) Team Home Game Fairness Index  (Average) Team Home Game Score  \
# 0                                91.697540                       49.430716
# 1                                91.697540                       49.430716
# 2                                94.567837                       16.627312
# 3                                91.647727                       50.000000
# 4                                91.647727                       50.000000
#
#    (Average) Team Duration in Hours Average  \
# 0                                 16.454545
# 1                                 16.545455
# 2                                 17.136364
# 3                                 16.500000
# 4                                 16.454545
#
#    (Average) Team Duration in Hours Fairness Index  \
# 0                                        88.909900
# 1                                        88.463053
# 2                                        91.085248
# 3                                        88.222554
# 4                                        88.123812
#
#    (Average) Team Duration in Hours Score  (Average) Team Overnight Average  \
# 0                               34.286601                          1.636364
# 1                               36.686526                          1.636364
# 2                               36.984888                          1.636364
# 3                               36.770976                          1.636364
# 4                               36.462954                          1.681818
#
#    (Average) Team Overnight Fairness Index  ...  \
# 0                                82.840909  ...
# 1                                80.133690  ...
# 2                                79.493802  ...
# 3                                70.771791  ...
# 4                                74.090402  ...
#
#    p7_2_3 Total Duration in Hours Change  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#    p7_2_3 Total Duration in Hours Percent Change  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#    p7_2_3 Total Overnight Change  p7_2_3 Total Overnight Percent Change  \
# 0                            NaN                                    NaN
# 1                            NaN                                    NaN
# 2                            NaN                                    NaN
# 3                            NaN                                    NaN
# 4                            NaN                                    NaN
#
#    p8_2_3 Total Cost Change  p8_2_3 Total Cost Percent Change  \
# 0                       NaN                               NaN
# 1                       NaN                               NaN
# 2                       NaN                               NaN
# 3                       NaN                               NaN
# 4                       NaN                               NaN
#
#    p8_2_3 Total Duration in Hours Change  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#    p8_2_3 Total Duration in Hours Percent Change  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#   p8_2_3 Total Overnight Change p8_2_3 Total Overnight Percent Change
# 0                           NaN                                   NaN
# 1                           NaN                                   NaN
# 2                           NaN                                   NaN
# 3                           NaN                                   NaN
# 4                           NaN                                   NaN
#
# [5 rows x 103 columns]

# %% [markdown]
# Let's take a closer look at the single schedule comparison between optimized and previous schedules.

# %%
from src.configuration import *
from src.figures import *


# Select two optimized schedule pairs to compare to the previous NESCAC schedule pairs
selected_idxs = [0, 2]

columns = [
    'Abbreviated Schedule ID',
#     'Schedule ID 0',
#     'Schedule ID 1',
#     'Schedule Indexes',
    'Pair/Quad Score',
    '(Sum) Total Cost',
    'Location Score',
    '(Average) Schedule Score',
    '(Average) Team Experience Score',
    'Team Different Location Average',
    'Team Different Location Fairness Index',
    'Team Different Location Score',
    'Team Unique Location Average',
    'Team Unique Location Fairness Index',
    'Team Unique Location Score',
#     '(Average) Team Experience Score',
    '(Average) Team Home Game (Min, Max, Rng)',
    '(Average) Team Home Game Fairness Index',
#     '(Average) Team Home Game Score',
    '(Average) Team Duration in Hours Average',
    '(Average) Team Duration in Hours Fairness Index',
#     '(Average) Team Duration in Hours Score',
    '(Average) Team Overnight Average',
    '(Average) Team Overnight Fairness Index',
#     '(Average) Team Overnight Score',
    '(Average) Test Success',
#     '(Sum) Total Distance',
    '(Sum) Total Duration in Hours',        
    '(Sum) Total Overnight', 
#     '(Sum) Total Distance Cost',
#     '(Sum) Total Overnight Cost',
]


print("Loading necessary information ...\n")
pair_schedule_comparison_df = pd.read_pickle(PAIR_SCHEDULE_COMPARISON_FILENAME)

# Comment/uncomment to see full DF or just selected indexes
pair_schedule_comparison_df = pair_schedule_comparison_df.iloc[selected_idxs][columns].append(pair_schedule_comparison_df[9:19][columns])

print("Applying color gradient to NESCAC schedule analysis DataFrame ...\n")
color_gradient_df = apply_color_gradient(pair_schedule_comparison_df, columns)

print("Displaying NESCAC schedule analysis DataFrame ...")
display(color_gradient_df)
# Out:
# Loading necessary information ...
#
# Applying color gradient to NESCAC schedule analysis DataFrame ...
#
# Displaying NESCAC schedule analysis DataFrame ...
# <style  type="text/css" >
#     #T_783bf6c2_6893_11ea_aa5c_8c2937e6cdeerow0_col1 {
#             background-color:  #2e8b57;
#             color:  #000000;
#         }    #T_783bf6c2_6893_11ea_aa5c_8c2937e6cdeerow0_col2 {
#             background-color:  #2e8b57;
#             color:  #000000;
#         }    #T_783bf6c2_6893_11ea_aa5c_8c2937e6cdeerow0_col3 {
#             background-color:  #cae5d6;
#             color:  #000000;
#         }    #T_783bf6c2_6893_11ea_aa5c_8c2937e6cdeerow0_col4 {
#             background-color:  #2e8b57;
#             color:  #000000;
#         }    #T_783bf6c2_6893_11ea_aa5c_8c2937e6cdeerow0_col5 {
#             background-color:  #429767;
#             color:  #000000;
#         }    #T_783bf6c2_6893_11ea_aa5c_8c2937e6cdeerow0_col6 {
#             background-color:  #ecf9f1;
#             color:  #000000;
#         }    #T_783bf6c2_6893_11ea_aa5c_8c2937e6cdeerow0_col7 {
#             background-color:  #75b491;
#             color:  #000000;
#         }    #T_783bf6c2_6893_11ea_aa5c_8c2937e6cdeerow0_col8 {
#             background-color:  #cbe6d7;
#             color:  #000000;
#         }    #T_783bf6c2_6893_11ea_aa5c_8c2937e6cdeerow0_col9 {
#             background-color:  #e9f7ef;
#             color:  #000000;
#         }    #T_783bf6c2_6893_11ea_aa5c_8c2937e6cdeerow0_col10 {
#             background-color:  #73b38f;
#             color:  #000000;
#         }    #T_783bf6c2_6893_11ea_aa5c_8c2937e6cdeerow0_col11 {
#             background-color:  #bddecb;
#             color:  #000000;
#         }    #T_783bf6c2_6893_11ea_aa5c_8c2937e6cdeerow0_col13 {
#             background-color:  #cae5d6;
#             color:  #000000;
#         }    #T_783bf6c2_6893_11ea_aa5c_8c2937e6cdeerow0_col14 {
#             background-color:  #2e8b57;
#             color:  #000000;
#         }    #T_783bf6c2_6893_11ea_aa5c_8c2937e6cdeerow0_col15 {
#             background-color:  #ecf9f1;
#             color:  #000000;
#         }    #T_783bf6c2_6893_11ea_aa5c_8c2937e6cdeerow0_col16 {
#             background-color:  #2e8b57;
#             color:  #000000;
#         }    #T_783bf6c2_6893_11ea_aa5c_8c2937e6cdeerow0_col17 {
#             background-color:  #c4e1d1;
#             color:  #000000;
#         }    #T_783bf6c2_6893_11ea_aa5c_8c2937e6cdeerow0_col19 {
#             background-color:  #2e8b57;
#             color:  #000000;
#         }    #T_783bf6c2_6893_11ea_aa5c_8c2937e6cdeerow0_col20 {
#             background-color:  #2e8b57;
#             color:  #000000;
#         }    #T_783bf6c2_6893_11ea_aa5c_8c2937e6cdeerow1_col1 {
#             background-color:  #348e5c;
#             color:  #000000;
#         }    #T_783bf6c2_6893_11ea_aa5c_8c2937e6cdeerow1_col2 {
#             background-color:  #38915f;
#             color:  #000000;
#         }    #T_783bf6c2_6893_11ea_aa5c_8c2937e6cdeerow1_col3 {
#             background-color:  #d6ece0;
#             color:  #000000;
#         }    #T_783bf6c2_6893_11ea_aa5c_8c2937e6cdeerow1_col4 {
#             background-color:  #37905e;
#             color:  #000000;
#         }    #T_783bf6c2_6893_11ea_aa5c_8c2937e6cdeerow1_col5 {
#             background-color:  #2e8b57;
#             color:  #000000;
#         }    #T_783bf6c2_6893_11ea_aa5c_8c2937e6cdeerow1_col6 {
#             background-color:  #ecf9f1;
#             color:  #000000;
#         }    #T_783bf6c2_6893_11ea_aa5c_8c2937e6cdeerow1_col7 {
#             background-color:  #b4d8c4;
#             color:  #000000;
#         }    #T_783bf6c2_6893_11ea_aa5c_8c2937e6cdeerow1_col8 {
#             background-color:  #e4f4eb;
#             color:  #000000;
#         }    #T_783bf6c2_6893_11ea_aa5c_8c2937e6cdeerow1_col9 {
#             background-color:  #e9f7ef;
#             color:  #000000;
#         }    #T_783bf6c2_6893_11ea_aa5c_8c2937e6cdeerow1_col10 {
#             background-color:  #73b38f;
#             color:  #000000;
#         }    #T_783bf6c2_6893_11ea_aa5c_8c2937e6cdeerow1_col11 {
#             background-color:  #bddecb;
#             color:  #000000;
#         }    #T_783bf6c2_6893_11ea_aa5c_8c2937e6cdeerow1_col13 {
#             background-color:  #81bb9b;
#             color:  #000000;
#         }    #T_783bf6c2_6893_11ea_aa5c_8c2937e6cdeerow1_col14 {
#             background-color:  #479a6c;
#             color:  #000000;
#         }    #T_783bf6c2_6893_11ea_aa5c_8c2937e6cdeerow1_col15 {
#             background-color:  #abd3bd;
#             color:  #000000;
#         }    #T_783bf6c2_6893_11ea_aa5c_8c2937e6cdeerow1_col16 {
#             background-color:  #2e8b57;
#             color:  #000000;
#         }    #T_783bf6c2_6893_11ea_aa5c_8c2937e6cdeerow1_col17 {
#             background-color:  #ecf9f1;
#             color:  #000000;
#         }    #T_783bf6c2_6893_11ea_aa5c_8c2937e6cdeerow1_col19 {
#             background-color:  #489a6c;
#             color:  #000000;
#         }    #T_783bf6c2_6893_11ea_aa5c_8c2937e6cdeerow1_col20 {
#             background-color:  #2e8b57;
#             color:  #000000;
#         }    #T_783bf6c2_6893_11ea_aa5c_8c2937e6cdeerow2_col1 {
#             background-color:  #a0cdb4;
#             color:  #000000;
#         }    #T_783bf6c2_6893_11ea_aa5c_8c2937e6cdeerow2_col2 {
#             background-color:  #8bc1a3;
#             color:  #000000;
#         }    #T_783bf6c2_6893_11ea_aa5c_8c2937e6cdeerow2_col3 {
#             background-color:  #ecf9f1;
#             color:  #000000;
#         }    #T_783bf6c2_6893_11ea_aa5c_8c2937e6cdeerow2_col4 {
#             background-color:  #3a9261;
#             color:  #000000;
#         }    #T_783bf6c2_6893_11ea_aa5c_8c2937e6cdeerow2_col5 {
#             background-color:  #93c5a9;
#             color:  #000000;
#         }    #T_783bf6c2_6893_11ea_aa5c_8c2937e6cdeerow2_col6 {
#             background-color:  #e2f3ea;
#             color:  #000000;
#         }    #T_783bf6c2_6893_11ea_aa5c_8c2937e6cdeerow2_col7 {
#             background-color:  #abd3bd;
#             color:  #000000;
#         }    #T_783bf6c2_6893_11ea_aa5c_8c2937e6cdeerow2_col8 {
#             background-color:  #d9eee2;
#             color:  #000000;
#         }    #T_783bf6c2_6893_11ea_aa5c_8c2937e6cdeerow2_col9 {
#             background-color:  #e6f5ed;
#             color:  #000000;
#         }    #T_783bf6c2_6893_11ea_aa5c_8c2937e6cdeerow2_col10 {
#             background-color:  #e6f5ed;
#             color:  #000000;
#         }    #T_783bf6c2_6893_11ea_aa5c_8c2937e6cdeerow2_col11 {
#             background-color:  #ecf9f1;
#             color:  #000000;
#         }    #T_783bf6c2_6893_11ea_aa5c_8c2937e6cdeerow2_col13 {
#             background-color:  #95c7ab;
#             color:  #000000;
#         }    #T_783bf6c2_6893_11ea_aa5c_8c2937e6cdeerow2_col14 {
#             background-color:  #5ea77e;
#             color:  #000000;
#         }    #T_783bf6c2_6893_11ea_aa5c_8c2937e6cdeerow2_col15 {
#             background-color:  #9bcaaf;
#             color:  #000000;
#         }    #T_783bf6c2_6893_11ea_aa5c_8c2937e6cdeerow2_col16 {
#             background-color:  #bcddcb;
#             color:  #000000;
#         }    #T_783bf6c2_6893_11ea_aa5c_8c2937e6cdeerow2_col17 {
#             background-color:  #dff1e7;
#             color:  #000000;
#         }    #T_783bf6c2_6893_11ea_aa5c_8c2937e6cdeerow2_col19 {
#             background-color:  #59a47a;
#             color:  #000000;
#         }    #T_783bf6c2_6893_11ea_aa5c_8c2937e6cdeerow2_col20 {
#             background-color:  #bddecb;
#             color:  #000000;
#         }    #T_783bf6c2_6893_11ea_aa5c_8c2937e6cdeerow3_col1 {
#             background-color:  #add4be;
#             color:  #000000;
#         }    #T_783bf6c2_6893_11ea_aa5c_8c2937e6cdeerow3_col2 {
#             background-color:  #8dc2a4;
#             color:  #000000;
#         }    #T_783bf6c2_6893_11ea_aa5c_8c2937e6cdeerow3_col3 {
#             background-color:  #ecf9f1;
#             color:  #000000;
#         }    #T_783bf6c2_6893_11ea_aa5c_8c2937e6cdeerow3_col4 {
#             background-color:  #46996a;
#             color:  #000000;
#         }    #T_783bf6c2_6893_11ea_aa5c_8c2937e6cdeerow3_col5 {
#             background-color:  #b3d8c3;
#             color:  #000000;
#         }    #T_783bf6c2_6893_11ea_aa5c_8c2937e6cdeerow3_col6 {
#             background-color:  #e7f6ee;

# %% [markdown]
# ## Chart Creation for Schedule Pairs Comparison
#
# Let's see how our best optimized schedule pairs compare with the previous NESCAC schedule pairs in the following categories:
#
# - Total cost
# - Team home games
# - Team travel duration
# - Team overnights
# - Team different locations
# - Team unique locations
#
# We use the following patterns and colors to highlight schedule pairs in the charts below:
#
# > <div style="float:left"><img src="hard_data/best_schedule.png"></div> $\quad$ indicates the previous NESCAC volleyball conference schedule pair with the best pair score
#
# > <div style="float:left"><img src="hard_data/best_result.png"></div> $\quad$ highlights the schedule pair with the best result in the charted category
#
# > <div style="float:left"><img src="hard_data/worst_result.png"></div> $\quad$ highlights the schedule pair with the worst result in the charted category
#
# ## Totals
#
# ### Total Cost

# %%
from src.configuration import *
from src.figures import *
# %matplotlib inline


print("Loading necessary information ...\n")
pair_schedule_comparison_df = pd.read_pickle(PAIR_SCHEDULE_COMPARISON_FILENAME)
pair_schedule_comparison_df = pair_schedule_comparison_df.iloc[selected_idxs][columns].append(pair_schedule_comparison_df[9:19])

print("Creating pair schedule total cost comparison bar chart ...")
plot_filename = plot_and_save_horizontal_bar_chart_min_max_mean(
    analysis_df=pair_schedule_comparison_df,
    column_name="(Sum) Total Cost",
    min_preferred=True,
    fig_title="Total cost ($) comparison.",
    nescac_mean_line=False,
    plot_path=PAIR_RESULTS_PLOT_PATH)

print("Saving pair schedule total cost comparison bar chart ...")
print("... Saved as \"{}\"\n".format(plot_filename))

print("Process complete.\n")
# Out:
# Loading necessary information ...
#
# Creating pair schedule total cost comparison bar chart ...
# Saving pair schedule total cost comparison bar chart ...
# ... Saved as "results/pair/figures/total_cost_($)_comparison.png"
#
# Process complete.

# %%
from src.configuration import *
from src.figures import *
# %matplotlib inline


print("Loading necessary information ...\n")
pair_schedule_comparison_df = pd.read_pickle(PAIR_SCHEDULE_COMPARISON_FILENAME)
pair_schedule_comparison_df = pair_schedule_comparison_df.iloc[selected_idxs][columns].append(pair_schedule_comparison_df[9:19]).reset_index(drop=True)
sched_id_0 = pair_schedule_comparison_df.loc[0]['Abbreviated Schedule ID']
sched_id_1 = pair_schedule_comparison_df.loc[1]['Abbreviated Schedule ID']

print("Creating pair schedule total cost change comparison bar chart ...")
plot_filename = plot_and_save_horizontal_bar_charts_min_max_mean(
    analysis_df=pair_schedule_comparison_df,
    column_names=("{} Total Cost Change".format(sched_id_0), "{} Total Cost Change".format(sched_id_1)),
    min_preferred_tuple=(True, True),
    fig_title="Total cost ($) change.",
    subplot_titles=("{}".format(sched_id_0), "{}".format(sched_id_1)),
    nescac_mean_line=True,
    optimized_schedule_lines=False,
    plot_path=PAIR_RESULTS_PLOT_PATH)

print("Saving pair schedule total cost change comparison bar chart ...")
print("... Saved as \"{}\"\n".format(plot_filename))

print("Process complete.\n")
# Out:
# Loading necessary information ...
#
# Creating pair schedule total cost change comparison bar chart ...
# Saving pair schedule total cost change comparison bar chart ...
# ... Saved as "results/pair/figures/total_cost_($)_change.png"
#
# Process complete.

# %%
from src.configuration import *
from src.figures import *
# %matplotlib inline


print("Loading necessary information ...\n")
pair_schedule_comparison_df = pd.read_pickle(PAIR_SCHEDULE_COMPARISON_FILENAME)
pair_schedule_comparison_df = pair_schedule_comparison_df.iloc[selected_idxs][columns].append(pair_schedule_comparison_df[9:19]).reset_index(drop=True)
sched_id_0 = pair_schedule_comparison_df.loc[0]['Abbreviated Schedule ID']
sched_id_1 = pair_schedule_comparison_df.loc[1]['Abbreviated Schedule ID']

print("Creating pair schedule total cost percent change comparison bar chart ...")
plot_filename = plot_and_save_horizontal_bar_charts_min_max_mean(
    analysis_df=pair_schedule_comparison_df,
    column_names=("{} Total Cost Percent Change".format(sched_id_0), "{} Total Cost Percent Change".format(sched_id_1)),
    min_preferred_tuple=(True, True),
    fig_title="Total cost percent change.",
    subplot_titles=("{}".format(sched_id_0), "{}".format(sched_id_1)),
    nescac_mean_line=True,
    optimized_schedule_lines=False,
    plot_path=PAIR_RESULTS_PLOT_PATH)

print("Saving pair schedule total cost percent change comparison bar chart ...")
print("... Saved as \"{}\"\n".format(plot_filename))

print("Process complete.\n")
# Out:
# Loading necessary information ...
#
# Creating pair schedule total cost percent change comparison bar chart ...
# Saving pair schedule total cost percent change comparison bar chart ...
# ... Saved as "results/pair/figures/total_cost_percent_change.png"
#
# Process complete.

# %% [markdown]
# ### Total Travel Duration

# %%
from src.configuration import *
from src.figures import *
# %matplotlib inline


print("Loading necessary information ...\n")
pair_schedule_comparison_df = pd.read_pickle(PAIR_SCHEDULE_COMPARISON_FILENAME)
pair_schedule_comparison_df = pair_schedule_comparison_df.iloc[selected_idxs][columns].append(pair_schedule_comparison_df[9:19]).reset_index(drop=True)

print("Creating pair schedule total travel duration comparison bar chart ...")
plot_filename = plot_and_save_horizontal_bar_chart_min_max_mean(
    analysis_df=pair_schedule_comparison_df,
    column_name="(Sum) Total Duration in Hours",
    min_preferred=True,
    fig_title="Total travel duration in hours comparison.",
    nescac_mean_line=False,
    plot_path=PAIR_RESULTS_PLOT_PATH)

print("Saving pair schedule total travel duration comparison bar chart ...")
print("... Saved as \"{}\"\n".format(plot_filename))

print("Process complete.\n")
# Out:
# Loading necessary information ...
#
# Creating pair schedule total travel duration comparison bar chart ...
# Saving pair schedule total travel duration comparison bar chart ...
# ... Saved as "results/pair/figures/total_travel_duration_in_hours_comparison.png"
#
# Process complete.

# %%
# from src.configuration import *
# from src.figures import *
# %matplotlib inline


# print("Loading necessary information ...\n")
# pair_schedule_comparison_df = pd.read_pickle(PAIR_SCHEDULE_COMPARISON_FILENAME)
# pair_schedule_comparison_df = pair_schedule_comparison_df.iloc[selected_idxs][columns].append(pair_schedule_comparison_df[9:19]).reset_index(drop=True)
# sched_id_0 = pair_schedule_comparison_df.loc[0]['Abbreviated Schedule ID']
# sched_id_1 = pair_schedule_comparison_df.loc[1]['Abbreviated Schedule ID']

# print("Creating pair schedule total travel duration percent change comparison bar chart ...")
# plot_filename = plot_and_save_horizontal_bar_charts_min_max_mean(
#     analysis_df=pair_schedule_comparison_df,
#     column_names=("{} Total Duration in Hours Percent Change".format(sched_id_0), "{} Total Duration in Hours Percent Change".format(sched_id_1)),
#     min_preferred_tuple=(True, True),
#     fig_title="Total travel duration in hours percent change.",
#     subplot_titles=("{}".format(sched_id_0), "{}".format(sched_id_1)),
#     nescac_mean_line=True,
#     optimized_schedule_lines=False,
#     plot_path=PAIR_RESULTS_PLOT_PATH)

# print("Saving pair schedule total travel duration percent change comparison bar chart ...")
# print("... Saved as \"{}\"\n".format(plot_filename))

# print("Process complete.\n")
# Out:
# Loading necessary information ...
#
# Creating pair schedule total travel duration percent change comparison bar chart ...
# Saving pair schedule total travel duration percent change comparison bar chart ...
# ... Saved as "results/pair/figures/total_travel_duration_in_hours_percent_change.png"
#
# Process complete.

# %%
from src.configuration import *
from src.figures import *
# %matplotlib inline


print("Loading necessary information ...\n")
pair_schedule_comparison_df = pd.read_pickle(PAIR_SCHEDULE_COMPARISON_FILENAME)
pair_schedule_comparison_df = pair_schedule_comparison_df.iloc[selected_idxs][columns].append(pair_schedule_comparison_df[9:19]).reset_index(drop=True)
sched_id_0 = pair_schedule_comparison_df.loc[0]['Abbreviated Schedule ID']
sched_id_1 = pair_schedule_comparison_df.loc[1]['Abbreviated Schedule ID']

print("Creating pair schedule total travel duration change comparison bar chart ...")
plot_filename = plot_and_save_horizontal_bar_charts_min_max_mean(
    analysis_df=pair_schedule_comparison_df,
    column_names=("{} Total Duration in Hours Change".format(sched_id_0), "{} Total Duration in Hours Change".format(sched_id_1)),
    min_preferred_tuple=(True, True),
    fig_title="Total travel duration in hours change.",
    subplot_titles=("{}".format(sched_id_0), "{}".format(sched_id_1)),
    nescac_mean_line=True,
    optimized_schedule_lines=False,
    plot_path=PAIR_RESULTS_PLOT_PATH)

print("Saving pair schedule total travel duration change comparison bar chart ...")
print("... Saved as \"{}\"\n".format(plot_filename))

print("Process complete.\n")
# Out:
# Loading necessary information ...
#
# Creating pair schedule total travel duration change comparison bar chart ...
# Saving pair schedule total travel duration change comparison bar chart ...
# ... Saved as "results/pair/figures/total_travel_duration_in_hours_change.png"
#
# Process complete.

# %%
# Assume 14 players/team ==> how many hours saved
int(14*109)
# Out:
# 1526

# %%
# Assume 2 coaching staff/team ==> how many hours saved
int(2*109)
# Out:
# 218

# %% [markdown]
# ### Total Overnights

# %%
from src.configuration import *
from src.figures import *
# %matplotlib inline


print("Loading necessary information ...\n")
pair_schedule_comparison_df = pd.read_pickle(PAIR_SCHEDULE_COMPARISON_FILENAME)
pair_schedule_comparison_df = pair_schedule_comparison_df.iloc[selected_idxs][columns].append(pair_schedule_comparison_df[9:19]).reset_index(drop=True)

print("Creating pair schedule total overnights comparison bar chart ...")
plot_filename = plot_and_save_horizontal_bar_chart_min_max_mean(
    analysis_df=pair_schedule_comparison_df,
    column_name="(Sum) Total Overnight",
    min_preferred=True,
    fig_title="Total overnights comparison.",
    nescac_mean_line=False,
    plot_path=PAIR_RESULTS_PLOT_PATH)

print("Saving pair schedule total overnights comparison bar chart ...")
print("... Saved as \"{}\"\n".format(plot_filename))

print("Process complete.\n")
# Out:
# Loading necessary information ...
#
# Creating pair schedule total overnights comparison bar chart ...
# Saving pair schedule total overnights comparison bar chart ...
# ... Saved as "results/pair/figures/total_overnights_comparison.png"
#
# Process complete.

# %%
# from src.configuration import *
# from src.figures import *
# %matplotlib inline


# print("Loading necessary information ...\n")
# pair_schedule_comparison_df = pd.read_pickle(PAIR_SCHEDULE_COMPARISON_FILENAME)
# pair_schedule_comparison_df = pair_schedule_comparison_df.iloc[selected_idxs][columns].append(pair_schedule_comparison_df[9:19]).reset_index(drop=True)
# sched_id_0 = pair_schedule_comparison_df.loc[0]['Abbreviated Schedule ID']
# sched_id_1 = pair_schedule_comparison_df.loc[1]['Abbreviated Schedule ID']

# print("Creating pair schedule total overnights percent change comparison bar chart ...")
# plot_filename = plot_and_save_horizontal_bar_charts_min_max_mean(
#     analysis_df=pair_schedule_comparison_df,
#     column_names=("{} Total Overnight Percent Change".format(sched_id_0), "{} Total Overnight Percent Change".format(sched_id_1)),
#     min_preferred_tuple=(True, True),
#     fig_title="Total overnights percent change.",
#     subplot_titles=("{}".format(sched_id_0), "{}".format(sched_id_1)),
#     nescac_mean_line=True,
#     optimized_schedule_lines=False,
#     plot_path=PAIR_RESULTS_PLOT_PATH)

# print("Saving pair schedule total overnights percent change comparison bar chart ...")
# print("... Saved as \"{}\"\n".format(plot_filename))

# print("Process complete.\n")
# Out:
# Loading necessary information ...
#
# Creating pair schedule total overnights percent change comparison bar chart ...
# Saving pair schedule total overnights percent change comparison bar chart ...
# ... Saved as "results/pair/figures/total_overnights_percent_change.png"
#
# Process complete.

# %%
from src.configuration import *
from src.figures import *
# %matplotlib inline


print("Loading necessary information ...\n")
pair_schedule_comparison_df = pd.read_pickle(PAIR_SCHEDULE_COMPARISON_FILENAME)
pair_schedule_comparison_df = pair_schedule_comparison_df.iloc[selected_idxs][columns].append(pair_schedule_comparison_df[9:19]).reset_index(drop=True)
sched_id_0 = pair_schedule_comparison_df.loc[0]['Abbreviated Schedule ID']
sched_id_1 = pair_schedule_comparison_df.loc[1]['Abbreviated Schedule ID']

print("Creating pair schedule total overnights change comparison bar chart ...")
plot_filename = plot_and_save_horizontal_bar_charts_min_max_mean(
    analysis_df=pair_schedule_comparison_df,
    column_names=("{} Total Overnight Change".format(sched_id_0), "{} Total Overnight Change".format(sched_id_1)),
    min_preferred_tuple=(True, True),
    fig_title="Total overnights change.",
    subplot_titles=("{}".format(sched_id_0), "{}".format(sched_id_1)),
    nescac_mean_line=True,
    optimized_schedule_lines=False,
    plot_path=PAIR_RESULTS_PLOT_PATH)

print("Saving pair schedule total overnights change comparison bar chart ...")
print("... Saved as \"{}\"\n".format(plot_filename))

print("Process complete.\n")
# Out:
# Loading necessary information ...
#
# Creating pair schedule total overnights change comparison bar chart ...
# Saving pair schedule total overnights change comparison bar chart ...
# ... Saved as "results/pair/figures/total_overnights_change.png"
#
# Process complete.

# %%
# Assume 14 players/team + 2 coaching staff/team ==> how many overnights saved
int(16*16)
# Out:
# 256

# %% [markdown]
# ## Team Experience

# %% [markdown]
# ### Team Home Games

# %%
from src.configuration import *
from src.figures import *
# %matplotlib inline


print("Loading necessary information ...\n")
pair_schedule_comparison_df = pd.read_pickle(PAIR_SCHEDULE_COMPARISON_FILENAME)
pair_schedule_comparison_df = pair_schedule_comparison_df.iloc[selected_idxs][columns].append(pair_schedule_comparison_df[9:19]).reset_index(drop=True)

print("Creating team home game comparison bar chart ...")
# Create team home game minimum column
pair_schedule_comparison_df['(Average) Team Home Game Minimum'] = pair_schedule_comparison_df['(Average) Team Home Game (Min, Max, Rng)'].apply(lambda x: x[0])
plot_filename = plot_and_save_horizontal_bar_charts_min_max_mean(
    analysis_df=pair_schedule_comparison_df,
    column_names=("(Average) Team Home Game Minimum", "(Average) Team Home Game Fairness Index"),
    min_preferred_tuple=(None, False),
    fig_title="Average team home game comparison.",
    subplot_titles=("Minimum Values", "Fairness Index"), 
    nescac_mean_line=False,
    optimized_schedule_lines=True,
    plot_path=PAIR_RESULTS_PLOT_PATH)


print("Saving team home game minimum and fairness index bar chart ...")
print("... Saved as \"{}\"\n".format(plot_filename))

print("Process complete.\n")
# Out:
# Loading necessary information ...
#
# Creating team home game comparison bar chart ...
# Saving team home game minimum and fairness index bar chart ...
# ... Saved as "results/pair/figures/average_team_home_game_comparison.png"
#
# Process complete.

# %% [markdown]
# ### Team Travel Duration

# %%
from src.configuration import *
from src.figures import *
# %matplotlib inline


print("Loading necessary information ...\n")
pair_schedule_comparison_df = pd.read_pickle(PAIR_SCHEDULE_COMPARISON_FILENAME)
pair_schedule_comparison_df = pair_schedule_comparison_df.iloc[selected_idxs][columns].append(pair_schedule_comparison_df[9:19]).reset_index(drop=True)

print("Creating team duration in hours comparison bar chart ...")
plot_filename = plot_and_save_horizontal_bar_charts_min_max_mean(
    analysis_df=pair_schedule_comparison_df,
    column_names=("(Average) Team Duration in Hours Average", "(Average) Team Duration in Hours Fairness Index"),
    min_preferred_tuple=(True, False),
    fig_title="Average team duration in hours comparison.",
    subplot_titles=("Average Values", "Fairness Index"),
    nescac_mean_line=False,
    optimized_schedule_lines=True,    
    plot_path=PAIR_RESULTS_PLOT_PATH)

print("Saving team duration in hours hours comparison bar chart ...")
print("... Saved as \"{}\"\n".format(plot_filename))

print("Process complete.\n")
# Out:
# Loading necessary information ...
#
# Creating team duration in hours comparison bar chart ...
# Saving team duration in hours hours comparison bar chart ...
# ... Saved as "results/pair/figures/average_team_duration_in_hours_comparison.png"
#
# Process complete.

# %% [markdown]
# ### Team Overnights

# %%
from src.configuration import *
from src.figures import *
# %matplotlib inline


print("Loading necessary information ...\n")
pair_schedule_comparison_df = pd.read_pickle(PAIR_SCHEDULE_COMPARISON_FILENAME)
pair_schedule_comparison_df = pair_schedule_comparison_df.iloc[selected_idxs][columns].append(pair_schedule_comparison_df[9:19]).reset_index(drop=True)

print("Creating team overnight comparison bar chart ...")
plot_filename = plot_and_save_horizontal_bar_charts_min_max_mean(
    analysis_df=pair_schedule_comparison_df,
    column_names=("(Average) Team Overnight Average", "(Average) Team Overnight Fairness Index"),
    min_preferred_tuple=(True, False),
    fig_title="Average team overnight comparison.",
    subplot_titles=("Average Values", "Fairness Index"),   
    nescac_mean_line=False,
    optimized_schedule_lines=True,    
    plot_path=PAIR_RESULTS_PLOT_PATH)

print("Saving team overnight average and fairness index bar chart ...")
print("... Saved as \"{}\"\n".format(plot_filename))

print("Process complete.\n")
# Out:
# Loading necessary information ...
#
# Creating team overnight comparison bar chart ...
# Saving team overnight average and fairness index bar chart ...
# ... Saved as "results/pair/figures/average_team_overnight_comparison.png"
#
# Process complete.

# %% [markdown]
# ### Team Overnight + Duration --> Percent Change Columns

# %%
# Calculate percent change columns

analysis_df = pair_schedule_comparison_df.copy()

analysis_df['Schedule ID 0'] = analysis_df['Schedule ID 0'].fillna('')

# Extract nescac schedules with correct scores
nescac_schedule_analysis_df = analysis_df[analysis_df['Schedule ID 0'].str.contains('nescac')]

# Extract optimized schedules with correct scores
optimized_schedule_analysis_df = analysis_df[~analysis_df['Schedule ID 0'].str.contains('nescac')]

# Prevent setting with copy warning
nescac_schedule_analysis_df = nescac_schedule_analysis_df.copy()

# Add optimized change columns
for opt_idx, opt_row in optimized_schedule_analysis_df.iterrows():

    opt_abbrev_sched_id = opt_row['Abbreviated Schedule ID']

    for nes_idx, nes_row in nescac_schedule_analysis_df.iterrows():

        nescac_schedule_analysis_df.loc[nes_idx, "{} (Average) Team Duration in Hours Average Percent Change".format(opt_abbrev_sched_id)] = calculate_column_percent_change_optimized_nescac(opt_row, nes_row, 'Team Duration in Hours Average', '(Average) ')

        nescac_schedule_analysis_df.loc[nes_idx, "{} (Average) Team Overnight Average Percent Change".format(opt_abbrev_sched_id)] = calculate_column_percent_change_optimized_nescac(opt_row, nes_row, 'Team Overnight Average', '(Average) ')

# Recombine into one DataFrame
analysis_df = optimized_schedule_analysis_df.append(nescac_schedule_analysis_df)

pair_schedule_comparison_df = analysis_df.copy()

display(pair_schedule_comparison_df[pair_schedule_comparison_df.columns[-8:]])
# Out:
#     p8_2_3 Total Duration in Hours Change  \
# 0                                     NaN
# 1                                     NaN
# 2                                    -8.0
# 3                                   -23.0
# 4                                   -81.0
# 5                                   -31.0
# 6                                   -82.0
# 7                                   -85.0
# 8                                   -80.0
# 9                                   -67.0
# 10                                  -92.0
# 11                                  -91.0
#
#     p8_2_3 Total Duration in Hours Percent Change  \
# 0                                             NaN
# 1                                             NaN
# 2                                       -2.056555
# 3                                       -5.693069
# 4                                      -17.532468
# 5                                       -7.524272
# 6                                      -17.710583
# 7                                      -18.240343
# 8                                      -17.353579
# 9                                      -14.955357
# 10                                     -19.450317
# 11                                     -19.279661
#
#     p8_2_3 Total Overnight Change  p8_2_3 Total Overnight Percent Change  \
# 0                             NaN                                    NaN
# 1                             NaN                                    NaN
# 2                           -10.0                             -20.833333
# 3                            -8.0                             -17.391304
# 4                           -12.0                             -24.000000
# 5                           -11.0                             -22.448980
# 6                           -10.0                             -20.833333
# 7                           -10.0                             -20.833333
# 8                           -11.0                             -22.448980
# 9                           -11.0                             -22.448980
# 10                          -12.0                             -24.000000
# 11                          -14.0                             -26.923077
#
#     p0_1_3 (Average) Team Duration in Hours Average Percent Change  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                           -7.179487
# 3                                          -10.617284
# 4                                          -21.304348
# 5                                          -12.135922
# 6                                          -21.304348
# 7                                          -22.150538
# 8                                          -21.132898
# 9                                          -19.015660
# 10                                         -23.467230
# 11                                         -23.305085
#
#     p0_1_3 (Average) Team Overnight Average Percent Change  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                          -25.000000
# 3                                          -21.739130
# 4                                          -28.000000
# 5                                          -26.530612
# 6                                          -25.000000
# 7                                          -25.000000
# 8                                          -26.530612
# 9                                          -26.530612
# 10                                         -28.000000
# 11                                         -30.769231
#
#     p4_1.5_3 (Average) Team Duration in Hours Average Percent Change  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                           -3.333333
# 3                                           -6.913580
# 4                                          -18.043478
# 5                                           -8.495146
# 6                                          -18.043478
# 7                                          -18.924731
# 8                                          -17.864924
# 9                                          -15.659955
# 10                                         -20.295983
# 11                                         -20.127119
#
#     p4_1.5_3 (Average) Team Overnight Average Percent Change
# 0                                                 NaN
# 1                                                 NaN
# 2                                          -25.000000
# 3                                          -21.739130
# 4                                          -28.000000
# 5                                          -26.530612
# 6                                          -25.000000
# 7                                          -25.000000
# 8                                          -26.530612
# 9                                          -26.530612
# 10                                         -28.000000
# 11                                         -30.769231

# %%
print("Creating pair schedule team duration in hours average percent change comparison bar chart ...")
plot_filename = plot_and_save_horizontal_bar_charts_min_max_mean(
    analysis_df=pair_schedule_comparison_df,
    column_names=("{} (Average) Team Duration in Hours Average Percent Change".format(sched_id_0), "{} (Average) Team Duration in Hours Average Percent Change".format(sched_id_1)),
    min_preferred_tuple=(True, True),
    fig_title="Team duration in hours average percent change.",
    subplot_titles=("{}".format(sched_id_0), "{}".format(sched_id_1)),
    nescac_mean_line=True,
    optimized_schedule_lines=False,
    plot_path=PAIR_RESULTS_PLOT_PATH)

print("Saving pair schedule team duration in hours average percent change comparison bar chart ...")
print("... Saved as \"{}\"\n".format(plot_filename))

print("Process complete.\n")
# Out:
# Creating pair schedule team duration in hours average percent change comparison bar chart ...
# Saving pair schedule team duration in hours average percent change comparison bar chart ...
# ... Saved as "results/pair/figures/team_duration_in_hours_average_percent_change.png"
#
# Process complete.

# %%
print("Creating pair schedule team overnight average percent change comparison bar chart ...")
plot_filename = plot_and_save_horizontal_bar_charts_min_max_mean(
    analysis_df=pair_schedule_comparison_df,
    column_names=("{} (Average) Team Overnight Average Percent Change".format(sched_id_0), "{} (Average) Team Overnight Average Percent Change".format(sched_id_1)),
    min_preferred_tuple=(True, True),
    fig_title="Team overnight average percent change.",
    subplot_titles=("{}".format(sched_id_0), "{}".format(sched_id_1)),
    nescac_mean_line=True,
    optimized_schedule_lines=False,
    plot_path=PAIR_RESULTS_PLOT_PATH)

print("Saving pair schedule team overnight average percent change comparison bar chart ...")
print("... Saved as \"{}\"\n".format(plot_filename))

print("Process complete.\n")
# Out:
# Creating pair schedule team overnight average percent change comparison bar chart ...
# Saving pair schedule team overnight average percent change comparison bar chart ...
# ... Saved as "results/pair/figures/team_overnight_average_percent_change.png"
#
# Process complete.

# %% [markdown]
# ## Team Location Experience

# %% [markdown]
# ### Team Different Locations

# %%
from src.configuration import *
from src.figures import *
# %matplotlib inline


print("Loading necessary information ...\n")
pair_schedule_comparison_df = pd.read_pickle(PAIR_SCHEDULE_COMPARISON_FILENAME)
pair_schedule_comparison_df = pair_schedule_comparison_df.iloc[selected_idxs][columns].append(pair_schedule_comparison_df[9:19]).reset_index(drop=True)

print("Creating team different location comparison bar chart ...")
plot_filename = plot_and_save_horizontal_bar_charts_min_max_mean(
    analysis_df=pair_schedule_comparison_df,
    column_names=("Team Different Location Average", "Team Different Location Fairness Index"),
    min_preferred_tuple=(True, False),
    fig_title="Team different location comparison.",
    subplot_titles=("Average Values", "Fairness Index"),   
    nescac_mean_line=False,
    optimized_schedule_lines=True,    
    plot_path=PAIR_RESULTS_PLOT_PATH)

print("Saving team different location average and fairness index bar chart ...")
print("... Saved as \"{}\"\n".format(plot_filename))

print("Process complete.\n")
# Out:
# Loading necessary information ...
#
# Creating team different location comparison bar chart ...
# Saving team different location average and fairness index bar chart ...
# ... Saved as "results/pair/figures/team_different_location_comparison.png"
#
# Process complete.

# %% [markdown]
# ### Closer look @ team different location --> number

# %%
from src.configuration import *
from src.figures import *
# %matplotlib inline


print("Loading necessary information ...\n")
pair_schedule_comparison_df = pd.read_pickle(PAIR_SCHEDULE_COMPARISON_FILENAME)
pair_schedule_comparison_df = pair_schedule_comparison_df.iloc[selected_idxs].append(pair_schedule_comparison_df[9:19]).reset_index(drop=True)

# display(pair_schedule_comparison_df[[
#     'Abbreviated Schedule ID',
#     'Team Different Location Dict'
# ]])

# strip list from dict values
pair_schedule_comparison_df['Team Different Location Dict'] = pair_schedule_comparison_df['Team Different Location Dict'].map(lambda x: {k: v[0] for k, v in x.items()})

display(pair_schedule_comparison_df[[
    'Abbreviated Schedule ID',
    'Team Different Location Dict'
]])

print("Creating team different location swarplot ...")
plot_filename = plot_and_save_dict_column_team_swarmplot_chart(
    analysis_df=pair_schedule_comparison_df,
    dict_column_name="Team Different Location Dict",
    fig_title="Number of different locations per team.",
    venues_mapping_filename=VENUES_MAPPING_FILENAME, 
    plot_path=PAIR_RESULTS_PLOT_PATH)

print("Saving team different location swarmplot ...")
print("... Saved as \"{}\"\n".format(plot_filename))

print("Process complete.\n")
# Out:
# Loading necessary information ...
#    Abbreviated Schedule ID                       Team Different Location Dict
# 0                   p0_1_3  {0: 5, 1: 3, 2: 3, 3: 3, 4: 2, 5: 4, 6: 3, 7: ...
# 1                 p4_1.5_3  {0: 4, 1: 3, 2: 3, 3: 3, 4: 1, 5: 4, 6: 4, 7: ...
# 2                  2010_11  {0: 5, 1: 2, 2: 5, 3: 2, 4: 4, 5: 2, 6: 5, 7: ...
# 3                  2009_10  {0: 4, 1: 6, 2: 3, 3: 6, 4: 2, 5: 2, 6: 4, 7: ...
# 4                  2017_18  {0: 10, 1: 10, 2: 10, 3: 10, 4: 10, 5: 10, 6: ...
# 5                  2011_12  {0: 5, 1: 5, 2: 1, 3: 4, 4: 2, 5: 7, 6: 5, 7: ...
# 6                  2018_19  {0: 6, 1: 4, 2: 8, 3: 4, 4: 6, 5: 6, 6: 6, 7: ...
# 7                  2014_15  {0: 6, 1: 10, 2: 2, 3: 6, 4: 5, 5: 5, 6: 5, 7:...
# 8                  2013_14  {0: 6, 1: 5, 2: 2, 3: 3, 4: 6, 5: 5, 6: 5, 7: ...
# 9                  2012_13  {0: 8, 1: 5, 2: 2, 3: 5, 4: 4, 5: 4, 6: 2, 7: ...
# 10                 2015_16  {0: 6, 1: 2, 2: 7, 3: 2, 4: 6, 5: 2, 6: 2, 7: ...
# 11                 2016_17  {0: 6, 1: 4, 2: 5, 3: 4, 4: 8, 5: 6, 6: 9, 7: ...
# Creating team different location swarplot ...
# Saving team different location swarmplot ...
# ... Saved as "results/pair/figures/team_different location_swarmplot.png"
#
# Process complete.

# %% [markdown]
# ### Team Unique Locations

# %%
from src.configuration import *
from src.figures import *
# %matplotlib inline


print("Loading necessary information ...\n")
pair_schedule_comparison_df = pd.read_pickle(PAIR_SCHEDULE_COMPARISON_FILENAME)
pair_schedule_comparison_df = pair_schedule_comparison_df.iloc[selected_idxs][columns].append(pair_schedule_comparison_df[9:19]).reset_index(drop=True)

print("Creating team unique location comparison bar chart ...")
plot_filename = plot_and_save_horizontal_bar_charts_min_max_mean(
    analysis_df=pair_schedule_comparison_df,
    column_names=("Team Unique Location Average", "Team Unique Location Fairness Index"),
    min_preferred_tuple=(True, False),
    fig_title="Team unique location comparison.",
    subplot_titles=("Average Values", "Fairness Index"),   
    nescac_mean_line=False,
    optimized_schedule_lines=True,    
    plot_path=PAIR_RESULTS_PLOT_PATH)

print("Saving team unique location average and fairness index bar chart ...")
print("... Saved as \"{}\"\n".format(plot_filename))

print("Process complete.\n")
# Out:
# Loading necessary information ...
#
# Creating team unique location comparison bar chart ...
# Saving team unique location average and fairness index bar chart ...
# ... Saved as "results/pair/figures/team_unique_location_comparison.png"
#
# Process complete.

# %% [markdown]
# ### Closer look @ team unique location --> number + distribution

# %%
from src.configuration import *
from src.figures import *
# %matplotlib inline


print("Loading necessary information ...\n")
pair_schedule_comparison_df = pd.read_pickle(PAIR_SCHEDULE_COMPARISON_FILENAME)
pair_schedule_comparison_df = pair_schedule_comparison_df.iloc[selected_idxs].append(pair_schedule_comparison_df[9:19]).reset_index(drop=True)

display(pair_schedule_comparison_df[[
    'Abbreviated Schedule ID',
    'Team Unique Location Dict'
]])

print("Creating team unique location swarplot ...")
plot_filename = plot_and_save_dict_column_team_swarmplot_chart(
    analysis_df=pair_schedule_comparison_df,
    dict_column_name="Team Unique Location Dict",
    fig_title="Number of unique locations per team.",
    venues_mapping_filename=VENUES_MAPPING_FILENAME, 
    plot_path=PAIR_RESULTS_PLOT_PATH)

print("Saving team unique location swarmplot ...")
print("... Saved as \"{}\"\n".format(plot_filename))

print("Process complete.\n")
# Out:
# Loading necessary information ...
#    Abbreviated Schedule ID                          Team Unique Location Dict
# 0                   p0_1_3  {0: 7, 1: 6, 2: 6, 3: 6, 4: 5, 5: 6, 6: 6, 7: ...
# 1                 p4_1.5_3  {0: 6, 1: 6, 2: 6, 3: 6, 4: 5, 5: 6, 6: 6, 7: ...
# 2                  2010_11  {0: 7, 1: 5, 2: 7, 3: 5, 4: 6, 5: 5, 6: 7, 7: ...
# 3                  2009_10  {0: 6, 1: 7, 2: 6, 3: 7, 4: 5, 5: 5, 6: 6, 7: ...
# 4                  2017_18  {0: 11, 1: 11, 2: 11, 3: 11, 4: 11, 5: 11, 6: ...
# 5                  2011_12  {0: 8, 1: 7, 2: 5, 3: 7, 4: 6, 5: 9, 6: 8, 7: ...
# 6                  2018_19  {0: 9, 1: 7, 2: 11, 3: 8, 4: 8, 5: 9, 6: 9, 7:...
# 7                  2014_15  {0: 9, 1: 11, 2: 7, 3: 9, 4: 9, 5: 8, 6: 8, 7:...
# 8                  2013_14  {0: 9, 1: 9, 2: 7, 3: 8, 4: 9, 5: 8, 6: 8, 7: ...
# 9                  2012_13  {0: 10, 1: 8, 2: 7, 3: 9, 4: 8, 5: 8, 6: 7, 7:...
# 10                 2015_16  {0: 9, 1: 7, 2: 10, 3: 7, 4: 9, 5: 7, 6: 7, 7:...
# 11                 2016_17  {0: 9, 1: 9, 2: 8, 3: 8, 4: 10, 5: 9, 6: 11, 7...
# Creating team unique location swarplot ...
# Saving team unique location swarmplot ...
# ... Saved as "results/pair/figures/team_unique location_swarmplot.png"
#
# Process complete.

# %% [markdown]
# ### Team Different + Unique Location --> Percent Change Columns

# %%
# Calculate percent change columns

analysis_df = pair_schedule_comparison_df.copy()

analysis_df['Schedule ID 0'] = analysis_df['Schedule ID 0'].fillna('')

# Extract nescac schedules with correct scores
nescac_schedule_analysis_df = analysis_df[analysis_df['Schedule ID 0'].str.contains('nescac')]

# Extract optimized schedules with correct scores
optimized_schedule_analysis_df = analysis_df[~analysis_df['Schedule ID 0'].str.contains('nescac')]

# Prevent setting with copy warning
nescac_schedule_analysis_df = nescac_schedule_analysis_df.copy()

# Add optimized change columns
for opt_idx, opt_row in optimized_schedule_analysis_df.iterrows():

    opt_abbrev_sched_id = opt_row['Abbreviated Schedule ID']

    for nes_idx, nes_row in nescac_schedule_analysis_df.iterrows():

        nescac_schedule_analysis_df.loc[nes_idx, "{} Team Different Location Average Percent Change".format(opt_abbrev_sched_id)] = calculate_column_percent_change_optimized_nescac(opt_row, nes_row, 'Team Different Location Average', '')

        nescac_schedule_analysis_df.loc[nes_idx, "{} Team Unique Location Average Percent Change".format(opt_abbrev_sched_id)] = calculate_column_percent_change_optimized_nescac(opt_row, nes_row, 'Team Unique Location Average', '')

# Recombine into one DataFrame
analysis_df = optimized_schedule_analysis_df.append(nescac_schedule_analysis_df)

pair_schedule_comparison_df = analysis_df.copy()

display(pair_schedule_comparison_df[pair_schedule_comparison_df.columns[-8:]])
# Out:
#     p8_2_3 Total Duration in Hours Change  \
# 0                                     NaN
# 1                                     NaN
# 2                                    -8.0
# 3                                   -23.0
# 4                                   -81.0
# 5                                   -31.0
# 6                                   -82.0
# 7                                   -85.0
# 8                                   -80.0
# 9                                   -67.0
# 10                                  -92.0
# 11                                  -91.0
#
#     p8_2_3 Total Duration in Hours Percent Change  \
# 0                                             NaN
# 1                                             NaN
# 2                                       -2.056555
# 3                                       -5.693069
# 4                                      -17.532468
# 5                                       -7.524272
# 6                                      -17.710583
# 7                                      -18.240343
# 8                                      -17.353579
# 9                                      -14.955357
# 10                                     -19.450317
# 11                                     -19.279661
#
#     p8_2_3 Total Overnight Change  p8_2_3 Total Overnight Percent Change  \
# 0                             NaN                                    NaN
# 1                             NaN                                    NaN
# 2                           -10.0                             -20.833333
# 3                            -8.0                             -17.391304
# 4                           -12.0                             -24.000000
# 5                           -11.0                             -22.448980
# 6                           -10.0                             -20.833333
# 7                           -10.0                             -20.833333
# 8                           -11.0                             -22.448980
# 9                           -11.0                             -22.448980
# 10                          -12.0                             -24.000000
# 11                          -14.0                             -26.923077
#
#     p0_1_3 Team Different Location Average Percent Change  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                          -10.000000
# 3                                           -5.263158
# 4                                          -67.272727
# 5                                          -25.000000
# 6                                          -47.058824
# 7                                          -33.333333
# 8                                          -25.000000
# 9                                          -18.181818
# 10                                         -28.000000
# 11                                         -41.935484
#
#     p0_1_3 Team Unique Location Average Percent Change  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                           -1.515152
# 3                                            1.562500
# 4                                          -46.280992
# 5                                          -18.750000
# 6                                          -35.000000
# 7                                          -30.107527
# 8                                          -27.777778
# 9                                          -26.136364
# 10                                         -28.571429
# 11                                         -32.989691
#
#     p4_1.5_3 Team Different Location Average Percent Change  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                          -10.000000
# 3                                           -5.263158
# 4                                          -67.272727
# 5                                          -25.000000
# 6                                          -47.058824
# 7                                          -33.333333
# 8                                          -25.000000
# 9                                          -18.181818
# 10                                         -28.000000
# 11                                         -41.935484
#
#     p4_1.5_3 Team Unique Location Average Percent Change
# 0                                                 NaN
# 1                                                 NaN
# 2                                           -1.515152
# 3                                            1.562500
# 4                                          -46.280992
# 5                                          -18.750000
# 6                                          -35.000000
# 7                                          -30.107527
# 8                                          -27.777778
# 9                                          -26.136364
# 10                                         -28.571429
# 11                                         -32.989691

# %%
sched_id_0 = pair_schedule_comparison_df.loc[0]['Abbreviated Schedule ID']
sched_id_1 = pair_schedule_comparison_df.loc[1]['Abbreviated Schedule ID']

print("Creating pair schedule team different location average percent change comparison bar chart ...")
plot_filename = plot_and_save_horizontal_bar_charts_min_max_mean(
    analysis_df=pair_schedule_comparison_df,
    column_names=("{} Team Different Location Average Percent Change".format(sched_id_0), "{} Team Different Location Average Percent Change".format(sched_id_1)),
    min_preferred_tuple=(True, True),
    fig_title="Team different location average percent change.",
    subplot_titles=("{}".format(sched_id_0), "{}".format(sched_id_1)),
    nescac_mean_line=True,
    optimized_schedule_lines=False,
    plot_path=PAIR_RESULTS_PLOT_PATH)

print("Saving pair schedule team different location average percent change comparison bar chart ...")
print("... Saved as \"{}\"\n".format(plot_filename))

print("Process complete.\n")
# Out:
# Creating pair schedule team different location average percent change comparison bar chart ...
# Saving pair schedule team different location average percent change comparison bar chart ...
# ... Saved as "results/pair/figures/team_different_location_average_percent_change.png"
#
# Process complete.

# %%
# Closer look at values
pair_schedule_comparison_df[[
    'Abbreviated Schedule ID',
    f'{sched_id_0} Team Different Location Average Percent Change',
    f'{sched_id_1} Team Different Location Average Percent Change',
]]
# Out:
#    Abbreviated Schedule ID  \
# 0                   p0_1_3
# 1                 p4_1.5_3
# 2                  2010_11
# 3                  2009_10
# 4                  2017_18
# 5                  2011_12
# 6                  2018_19
# 7                  2014_15
# 8                  2013_14
# 9                  2012_13
# 10                 2015_16
# 11                 2016_17
#
#     p0_1_3 Team Different Location Average Percent Change  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                          -10.000000
# 3                                           -5.263158
# 4                                          -67.272727
# 5                                          -25.000000
# 6                                          -47.058824
# 7                                          -33.333333
# 8                                          -25.000000
# 9                                          -18.181818
# 10                                         -28.000000
# 11                                         -41.935484
#
#     p4_1.5_3 Team Different Location Average Percent Change
# 0                                                 NaN
# 1                                                 NaN
# 2                                          -10.000000
# 3                                           -5.263158
# 4                                          -67.272727
# 5                                          -25.000000
# 6                                          -47.058824
# 7                                          -33.333333
# 8                                          -25.000000
# 9                                          -18.181818
# 10                                         -28.000000
# 11                                         -41.935484

# %%
sched_id_0 = pair_schedule_comparison_df.loc[0]['Abbreviated Schedule ID']
sched_id_1 = pair_schedule_comparison_df.loc[1]['Abbreviated Schedule ID']

print("Creating pair schedule team unique location average percent change comparison bar chart ...")
plot_filename = plot_and_save_horizontal_bar_charts_min_max_mean(
    analysis_df=pair_schedule_comparison_df,
    column_names=("{} Team Unique Location Average Percent Change".format(sched_id_0), "{} Team Unique Location Average Percent Change".format(sched_id_1)),
    min_preferred_tuple=(True, True),
    fig_title="Team unique location average percent change.",
    subplot_titles=("{}".format(sched_id_0), "{}".format(sched_id_1)),
    nescac_mean_line=True,
    optimized_schedule_lines=False,
    plot_path=PAIR_RESULTS_PLOT_PATH)

print("Saving pair schedule team unique location average percent change comparison bar chart ...")
print("... Saved as \"{}\"\n".format(plot_filename))

print("Process complete.\n")
# Out:
# Creating pair schedule team unique location average percent change comparison bar chart ...
# Saving pair schedule team unique location average percent change comparison bar chart ...
# ... Saved as "results/pair/figures/team_unique_location_average_percent_change.png"
#
# Process complete.

# %%
# Closer look at values
pair_schedule_comparison_df[[
    'Abbreviated Schedule ID',
    f'{sched_id_0} Team Unique Location Average Percent Change',
    f'{sched_id_1} Team Unique Location Average Percent Change',
]]
# Out:
#    Abbreviated Schedule ID  \
# 0                   p0_1_3
# 1                 p4_1.5_3
# 2                  2010_11
# 3                  2009_10
# 4                  2017_18
# 5                  2011_12
# 6                  2018_19
# 7                  2014_15
# 8                  2013_14
# 9                  2012_13
# 10                 2015_16
# 11                 2016_17
#
#     p0_1_3 Team Unique Location Average Percent Change  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                           -1.515152
# 3                                            1.562500
# 4                                          -46.280992
# 5                                          -18.750000
# 6                                          -35.000000
# 7                                          -30.107527
# 8                                          -27.777778
# 9                                          -26.136364
# 10                                         -28.571429
# 11                                         -32.989691
#
#     p4_1.5_3 Team Unique Location Average Percent Change
# 0                                                 NaN
# 1                                                 NaN
# 2                                           -1.515152
# 3                                            1.562500
# 4                                          -46.280992
# 5                                          -18.750000
# 6                                          -35.000000
# 7                                          -30.107527
# 8                                          -27.777778
# 9                                          -26.136364
# 10                                         -28.571429
# 11                                         -32.989691

# %% [markdown]
# ## Score Metrics

# %%
from src.configuration import *
from src.figures import *
# %matplotlib inline


print("Loading necessary information ...\n")
pair_schedule_comparison_df = pd.read_pickle(PAIR_SCHEDULE_COMPARISON_FILENAME)
pair_schedule_comparison_df = pair_schedule_comparison_df.iloc[selected_idxs].append(pair_schedule_comparison_df[9:19]).reset_index(drop=True)

print("Creating schedule score components comparison bar chart ...")
plot_filename = plot_and_save_horizontal_bar_charts_min_max_mean(
    analysis_df=pair_schedule_comparison_df,
    column_names=("(Average) Team Experience Score", "Location Score"),
    min_preferred_tuple=(True, True),
    fig_title="Pair score components comparison.",
    subplot_titles=("Team Experience Score", "Location Score"),
    nescac_mean_line=False,
    optimized_schedule_lines=True,
    plot_path=PAIR_RESULTS_PLOT_PATH)

print("Saving schedule score components comparison bar chart ...")
print("... Saved as \"{}\"\n".format(plot_filename))

print("Process complete.\n")
# Out:
# Loading necessary information ...
#
# Creating schedule score components comparison bar chart ...
# Saving schedule score components comparison bar chart ...
# ... Saved as "results/pair/figures/pair_score_components_comparison.png"
#
# Process complete.

# %%
from src.configuration import *
from src.figures import *
# %matplotlib inline


print("Loading necessary information ...\n")
pair_schedule_comparison_df = pd.read_pickle(PAIR_SCHEDULE_COMPARISON_FILENAME)
pair_schedule_comparison_df = pair_schedule_comparison_df.iloc[selected_idxs].append(pair_schedule_comparison_df[9:19]).reset_index(drop=True)

print("Creating pair schedule score comparison bar chart ...")
plot_filename = plot_and_save_horizontal_bar_chart_min_max_mean(
    analysis_df=pair_schedule_comparison_df,
    column_name="Pair/Quad Score",
    min_preferred=True,
    fig_title="Pair schedule score comparison.",
    nescac_mean_line=False,
    plot_path=PAIR_RESULTS_PLOT_PATH)

print("Saving pair schedule score comparison bar chart ...")
print("... Saved as \"{}\"\n".format(plot_filename))

print("Process complete.\n")
# Out:
# Loading necessary information ...
#
# Creating pair schedule score comparison bar chart ...
# Saving pair schedule score comparison bar chart ...
# ... Saved as "results/pair/figures/pair_schedule_score_comparison.png"
#
# Process complete.

# %% [markdown]
# ## Review Schedules

# %%
# schedules in optimized pair
columns = [
    'Abbreviated Schedule ID',
    'Schedule ID 0',
    'Schedule ID 1',
]

pair_schedule_comparison_df = pd.read_pickle(PAIR_SCHEDULE_COMPARISON_FILENAME)
pair_schedule_comparison_df = pair_schedule_comparison_df.iloc[selected_idxs]

display(pair_schedule_comparison_df[columns])
# Out:
#   Abbreviated Schedule ID                      Schedule ID 0  \
# 0                  p0_1_3  15_2335_optimized_team_schedule_0
# 2                p4_1.5_3  15_2335_optimized_team_schedule_0
#
#                       Schedule ID 1
# 0  3_2215_optimized_team_schedule_1
# 2  5_2235_optimized_team_schedule_0

# %%
# Adjust idx value to review schedules
# idx = 0 --> p0_1_3 schedule pair
# idx = 1 --> p4_1.5_3 schedule pair
idx = 0

pair_schedule_comparison_df = pd.read_pickle(PAIR_SCHEDULE_COMPARISON_FILENAME)
pair_schedule_comparison_df = pair_schedule_comparison_df.iloc[selected_idxs]
_ = pair_schedule_comparison_df.iloc[idx]
display(_[columns])
# Out:
# Abbreviated Schedule ID                               p0_1_3
# Schedule ID 0              15_2335_optimized_team_schedule_0
# Schedule ID 1               3_2215_optimized_team_schedule_1
# Name: 0, dtype: object

# %%
# review full schedule
# toggle and untoggle display lines to review full schedule or full schedule grouped by week
for col_name, schedule in _[columns].items():
    if "Abbreviated" not in col_name:
        
        print('##############')
        print('# SCHEDULE ' + col_name[-1] + ' #')
        print('##############')

        schedule_df = pd.read_csv(f"results/pair/optimized_schedules/{schedule.replace('team_', '')}.csv", index_col=0)
        
#         display(schedule_df)

        # review schedule grouped by week
        for week, week_df in schedule_df.groupby('Week'):
            display(week_df)
# Out:
# ##############
# # SCHEDULE 0 #
# ##############
#     Week Day (Str)  Time Slot               Team 1            Team 2  \
# 0      0      Fri.          0        Bates College   Trinity College
# 1      0      Fri.          1        Colby College   Amherst College
# 2      0      Sat.          2      Bowdoin College   Amherst College
# 3      0      Sat.          3      Bowdoin College   Trinity College
# 4      0      Sat.          4        Colby College   Trinity College
# 5      0      Sat.          5        Bates College   Amherst College
# 6      0      Fri.          0   Middlebury College  Hamilton College
# 7      0      Sat.          1   Middlebury College  Williams College
# 8      0      Sat.          2     Williams College  Hamilton College
# 9      0      Sat.          0  Connecticut College  Tufts University
# 10     0      Sat.          1  Wesleyan University  Tufts University
#
#                Location
# 0         Colby College
# 1         Colby College
# 2         Colby College
# 3         Colby College
# 4         Colby College
# 5         Colby College
# 6      Hamilton College
# 7      Hamilton College
# 8      Hamilton College
# 9   Wesleyan University
# 10  Wesleyan University
#     Week Day (Str)  Time Slot              Team 1               Team 2  \
# 11     1      Fri.          0       Bates College      Bowdoin College
# 12     1      Sat.          1       Colby College      Bowdoin College
# 13     1      Sat.          2       Bates College        Colby College
# 14     1      Sat.          0    Tufts University      Trinity College
# 15     1      Sat.          1    Tufts University      Amherst College
# 16     1      Fri.          0  Middlebury College  Connecticut College
# 17     1      Fri.          1    Williams College  Wesleyan University
# 18     1      Sat.          2    Williams College  Connecticut College
# 19     1      Sat.          3    Hamilton College  Wesleyan University
# 20     1      Sat.          4    Hamilton College  Connecticut College
# 21     1      Sat.          5  Middlebury College  Wesleyan University
#
#             Location
# 11   Bowdoin College
# 12   Bowdoin College
# 13   Bowdoin College
# 14  Tufts University
# 15  Tufts University
# 16  Williams College
# 17  Williams College
# 18  Williams College
# 19  Williams College
# 20  Williams College
# 21  Williams College
#     Week Day (Str)  Time Slot               Team 1               Team 2  \
# 22     2      Fri.          0      Trinity College     Williams College
# 23     2      Fri.          1      Amherst College     Hamilton College
# 24     2      Sat.          2      Amherst College     Williams College
# 25     2      Sat.          3      Trinity College   Middlebury College
# 26     2      Sat.          4      Trinity College     Hamilton College
# 27     2      Sat.          5      Amherst College   Middlebury College
# 28     2      Fri.          0        Bates College     Tufts University
# 29     2      Sat.          1        Colby College     Tufts University
# 30     2      Sat.          2      Bowdoin College     Tufts University
# 31     2      Sat.          0  Wesleyan University  Connecticut College
#
#                Location
# 22      Amherst College
# 23      Amherst College
# 24      Amherst College
# 25      Amherst College
# 26      Amherst College
# 27      Amherst College
# 28        Bates College
# 29        Bates College
# 30        Bates College
# 31  Wesleyan University
#     Week Day (Str)  Time Slot               Team 1            Team 2  \
# 32     3      Fri.          0  Wesleyan University     Bates College
# 33     3      Fri.          1  Connecticut College     Colby College
# 34     3      Sat.          2  Connecticut College     Bates College
# 35     3      Sat.          3  Wesleyan University     Colby College
# 36     3      Sat.          4  Connecticut College   Bowdoin College
# 37     3      Sat.          5  Wesleyan University   Bowdoin College
# 38     3      Sat.          0      Trinity College   Amherst College
# 39     3      Fri.          0     Hamilton College  Tufts University
# 40     3      Sat.          1     Williams College  Tufts University
# 41     3      Sat.          2   Middlebury College  Tufts University
#
#                Location
# 32  Connecticut College
# 33  Connecticut College
# 34  Connecticut College
# 35  Connecticut College
# 36  Connecticut College
# 37  Connecticut College
# 38      Trinity College
# 39     Williams College
# 40     Williams College
# 41     Williams College
#     Week Day (Str)  Time Slot              Team 1               Team 2  \
# 42     4      Fri.          0  Middlebury College        Bates College
# 43     4      Fri.          1    Hamilton College      Bowdoin College
# 44     4      Fri.          2    Williams College        Colby College
# 45     4      Sat.          3    Hamilton College        Bates College
# 46     4      Sat.          4    Hamilton College        Colby College
# 47     4      Sat.          5    Williams College        Bates College
# 48     4      Sat.          6    Williams College      Bowdoin College
# 49     4      Sat.          7  Middlebury College        Colby College
# 50     4      Sat.          8  Middlebury College      Bowdoin College
# 51     4      Fri.          0     Amherst College  Connecticut College
# 52     4      Fri.          1     Trinity College  Wesleyan University
# 53     4      Sat.          2     Trinity College  Connecticut College
# 54     4      Sat.          3     Amherst College  Wesleyan University
#
#               Location
# 42  Middlebury College
# 43  Middlebury College
# 44  Middlebury College
# 45  Middlebury College
# 46  Middlebury College
# 47  Middlebury College
# 48  Middlebury College
# 49  Middlebury College
# 50  Middlebury College
# 51     Trinity College
# 52     Trinity College
# 53     Trinity College
# 54     Trinity College
# ##############
# # SCHEDULE 1 #
# ##############
#     Week Day (Str)  Time Slot               Team 1               Team 2  \
# 0      0      Fri.          0      Bowdoin College     Williams College
# 1      0      Fri.          1        Bates College   Middlebury College
# 2      0      Fri.          2        Colby College      Amherst College
# 3      0      Sat.          3        Colby College   Middlebury College
# 4      0      Sat.          4      Bowdoin College   Middlebury College
# 5      0      Sat.          5        Colby College     Williams College
# 6      0      Sat.          6        Bates College     Williams College
# 7      0      Sat.          7        Bates College      Amherst College
# 8      0      Sat.          8      Bowdoin College      Amherst College
# 9      0      Fri.          0  Connecticut College  Wesleyan University
# 10     0      Sat.          1  Connecticut College      Trinity College
# 11     0      Sat.          2  Wesleyan University      Trinity College
# 12     0      Sat.          0     Hamilton College     Tufts University
#
#                Location
# 0       Bowdoin College
# 1       Bowdoin College
# 2       Bowdoin College
# 3       Bowdoin College
# 4       Bowdoin College
# 5       Bowdoin College
# 6       Bowdoin College
# 7       Bowdoin College
# 8       Bowdoin College
# 9   Connecticut College
# 10  Connecticut College
# 11  Connecticut College
# 12     Hamilton College
#     Week Day (Str)  Time Slot               Team 1              Team 2  \
# 13     1      Fri.          0  Connecticut College     Bowdoin College
# 14     1      Fri.          1  Wesleyan University       Colby College
# 15     1      Fri.          2      Trinity College       Bates College
# 16     1      Sat.          3  Wesleyan University     Bowdoin College
# 17     1      Sat.          4  Connecticut College       Bates College
# 18     1      Sat.          5  Connecticut College       Colby College
# 19     1      Sat.          6      Trinity College       Colby College
# 20     1      Sat.          7      Trinity College     Bowdoin College
# 21     1      Sat.          8  Wesleyan University       Bates College
# 22     1      Fri.          0     Tufts University  Middlebury College
# 23     1      Sat.          1     Tufts University    Williams College
# 24     1      Sat.          2     Tufts University     Amherst College
#
#             Location
# 13   Trinity College
# 14   Trinity College
# 15   Trinity College
# 16   Trinity College
# 17   Trinity College
# 18   Trinity College
# 19   Trinity College
# 20   Trinity College
# 21   Trinity College
# 22  Tufts University
# 23  Tufts University
# 24  Tufts University
#     Week Day (Str)  Time Slot               Team 1            Team 2  \
# 25     2      Fri.          0      Bowdoin College     Bates College
# 26     2      Sat.          1        Bates College     Colby College
# 27     2      Sat.          2      Bowdoin College     Colby College
# 28     2      Fri.          0     Williams College  Hamilton College
# 29     2      Sat.          1      Amherst College  Hamilton College
# 30     2      Sat.          2   Middlebury College  Hamilton College
# 31     2      Fri.          0      Trinity College  Tufts University
# 32     2      Sat.          1  Connecticut College  Tufts University
# 33     2      Sat.          2  Wesleyan University  Tufts University
#
#                Location
# 25        Bates College
# 26        Bates College
# 27        Bates College
# 28   Middlebury College
# 29   Middlebury College
# 30   Middlebury College
# 31  Wesleyan University
# 32  Wesleyan University
# 33  Wesleyan University
#     Week Day (Str)  Time Slot               Team 1              Team 2  \
# 34     3      Fri.          0        Colby College    Tufts University
# 35     3      Sat.          1        Bates College    Tufts University
# 36     3      Sat.          2      Bowdoin College    Tufts University
# 37     3      Fri.          0      Trinity College    Hamilton College
# 38     3      Sat.          1  Connecticut College    Hamilton College
# 39     3      Sat.          2  Wesleyan University    Hamilton College
# 40     3      Fri.          0     Williams College     Amherst College
# 41     3      Sat.          1      Amherst College  Middlebury College
# 42     3      Sat.          2     Williams College  Middlebury College
#
#                Location
# 34        Colby College
# 35        Colby College
# 36        Colby College
# 37  Wesleyan University
# 38  Wesleyan University
# 39  Wesleyan University
# 40     Williams College
# 41     Williams College
# 42     Williams College
#     Week Day (Str)  Time Slot              Team 1               Team 2  \
# 43     4      Fri.          0    Williams College  Connecticut College
# 44     4      Fri.          1  Middlebury College  Wesleyan University
# 45     4      Fri.          2     Amherst College      Trinity College
# 46     4      Sat.          3  Middlebury College  Connecticut College
# 47     4      Sat.          4     Amherst College  Connecticut College
# 48     4      Sat.          5    Williams College  Wesleyan University
# 49     4      Sat.          6    Williams College      Trinity College
# 50     4      Sat.          7     Amherst College  Wesleyan University
# 51     4      Sat.          8  Middlebury College      Trinity College
# 52     4      Fri.          0       Bates College     Hamilton College
# 53     4      Sat.          1     Bowdoin College     Hamilton College
# 54     4      Sat.          2       Colby College     Hamilton College
#
#            Location
# 43  Amherst College
# 44  Amherst College
# 45  Amherst College
# 46  Amherst College
# 47  Amherst College
# 48  Amherst College
# 49  Amherst College
# 50  Amherst College
# 51  Amherst College
# 52    Colby College
# 53    Colby College
# 54    Colby College

# %%
# review team schedules
# toggle and untoggle display lines to review team schedules grouped by team or team and week
for col_name, schedule in _[columns].items():
    if "Abbreviated" not in col_name:
        
        print('##############')
        print('# SCHEDULE ' + col_name[-1] + ' #')
        print('##############')

        schedule_df = pd.read_csv(f"results/pair/optimized_schedules/{schedule}.csv", index_col=0)
    
        for team_1,team_1_df in schedule_df.groupby('Team 1'):
            print(team_1)
            
#             # review team schedule grouped by team
#             display(team_1_df)
            
            # review team schedule grouped by team and week
            for week, week_df in team_1_df.groupby('Week'):
                display(week_df)
# Out:
# ##############
# # SCHEDULE 0 #
# ##############
# Amherst College
#    Week Day (Str)  Time Slot           Team 1           Team 2       Location
# 0     0      Fri.          1  Amherst College    Colby College  Colby College
# 1     0      Sat.          2  Amherst College  Bowdoin College  Colby College
# 2     0      Sat.          5  Amherst College    Bates College  Colby College
#    Week Day (Str)  Time Slot           Team 1            Team 2  \
# 3     1      Sat.          1  Amherst College  Tufts University
#
#            Location
# 3  Tufts University
#    Week Day (Str)  Time Slot           Team 1              Team 2  \
# 4     2      Fri.          1  Amherst College    Hamilton College
# 5     2      Sat.          2  Amherst College    Williams College
# 6     2      Sat.          5  Amherst College  Middlebury College
#
#           Location
# 4  Amherst College
# 5  Amherst College
# 6  Amherst College
#    Week Day (Str)  Time Slot           Team 1           Team 2  \
# 7     3      Sat.          0  Amherst College  Trinity College
#
#           Location
# 7  Trinity College
#    Week Day (Str)  Time Slot           Team 1               Team 2  \
# 8     4      Fri.          0  Amherst College  Connecticut College
# 9     4      Sat.          3  Amherst College  Wesleyan University
#
#           Location
# 8  Trinity College
# 9  Trinity College
# Bates College
#     Week Day (Str)  Time Slot         Team 1           Team 2       Location
# 10     0      Fri.          0  Bates College  Trinity College  Colby College
# 11     0      Sat.          5  Bates College  Amherst College  Colby College
#     Week Day (Str)  Time Slot         Team 1           Team 2         Location
# 12     1      Fri.          0  Bates College  Bowdoin College  Bowdoin College
# 13     1      Sat.          2  Bates College    Colby College  Bowdoin College
#     Week Day (Str)  Time Slot         Team 1            Team 2       Location
# 14     2      Fri.          0  Bates College  Tufts University  Bates College
#     Week Day (Str)  Time Slot         Team 1               Team 2  \
# 15     3      Fri.          0  Bates College  Wesleyan University
# 16     3      Sat.          2  Bates College  Connecticut College
#
#                Location
# 15  Connecticut College
# 16  Connecticut College
#     Week Day (Str)  Time Slot         Team 1              Team 2  \
# 17     4      Fri.          0  Bates College  Middlebury College
# 18     4      Sat.          3  Bates College    Hamilton College
# 19     4      Sat.          5  Bates College    Williams College
#
#               Location
# 17  Middlebury College
# 18  Middlebury College
# 19  Middlebury College
# Bowdoin College
#     Week Day (Str)  Time Slot           Team 1           Team 2       Location
# 20     0      Sat.          2  Bowdoin College  Amherst College  Colby College
# 21     0      Sat.          3  Bowdoin College  Trinity College  Colby College
#     Week Day (Str)  Time Slot           Team 1         Team 2         Location
# 22     1      Fri.          0  Bowdoin College  Bates College  Bowdoin College
# 23     1      Sat.          1  Bowdoin College  Colby College  Bowdoin College
#     Week Day (Str)  Time Slot           Team 1            Team 2  \
# 24     2      Sat.          2  Bowdoin College  Tufts University
#
#          Location
# 24  Bates College
#     Week Day (Str)  Time Slot           Team 1               Team 2  \
# 25     3      Sat.          4  Bowdoin College  Connecticut College
# 26     3      Sat.          5  Bowdoin College  Wesleyan University
#
#                Location
# 25  Connecticut College
# 26  Connecticut College
#     Week Day (Str)  Time Slot           Team 1              Team 2  \
# 27     4      Fri.          1  Bowdoin College    Hamilton College
# 28     4      Sat.          6  Bowdoin College    Williams College
# 29     4      Sat.          8  Bowdoin College  Middlebury College
#
#               Location
# 27  Middlebury College
# 28  Middlebury College
# 29  Middlebury College
# Colby College
#     Week Day (Str)  Time Slot         Team 1           Team 2       Location
# 30     0      Fri.          1  Colby College  Amherst College  Colby College
# 31     0      Sat.          4  Colby College  Trinity College  Colby College
#     Week Day (Str)  Time Slot         Team 1           Team 2         Location
# 32     1      Sat.          1  Colby College  Bowdoin College  Bowdoin College
# 33     1      Sat.          2  Colby College    Bates College  Bowdoin College
#     Week Day (Str)  Time Slot         Team 1            Team 2       Location
# 34     2      Sat.          1  Colby College  Tufts University  Bates College
#     Week Day (Str)  Time Slot         Team 1               Team 2  \
# 35     3      Fri.          1  Colby College  Connecticut College
# 36     3      Sat.          3  Colby College  Wesleyan University
#
#                Location
# 35  Connecticut College
# 36  Connecticut College
#     Week Day (Str)  Time Slot         Team 1              Team 2  \
# 37     4      Fri.          2  Colby College    Williams College
# 38     4      Sat.          4  Colby College    Hamilton College
# 39     4      Sat.          7  Colby College  Middlebury College
#
#               Location
# 37  Middlebury College
# 38  Middlebury College
# 39  Middlebury College
# Connecticut College
#     Week Day (Str)  Time Slot               Team 1            Team 2  \
# 40     0      Sat.          0  Connecticut College  Tufts University
#
#                Location
# 40  Wesleyan University
#     Week Day (Str)  Time Slot               Team 1              Team 2  \
# 41     1      Fri.          0  Connecticut College  Middlebury College
# 42     1      Sat.          2  Connecticut College    Williams College
# 43     1      Sat.          4  Connecticut College    Hamilton College
#
#             Location
# 41  Williams College
# 42  Williams College
# 43  Williams College
#     Week Day (Str)  Time Slot               Team 1               Team 2  \
# 44     2      Sat.          0  Connecticut College  Wesleyan University
#
#                Location
# 44  Wesleyan University
#     Week Day (Str)  Time Slot               Team 1           Team 2  \
# 45     3      Fri.          1  Connecticut College    Colby College
# 46     3      Sat.          2  Connecticut College    Bates College
# 47     3      Sat.          4  Connecticut College  Bowdoin College
#
#                Location
# 45  Connecticut College
# 46  Connecticut College
# 47  Connecticut College
#     Week Day (Str)  Time Slot               Team 1           Team 2  \
# 48     4      Fri.          0  Connecticut College  Amherst College
# 49     4      Sat.          2  Connecticut College  Trinity College
#
#            Location
# 48  Trinity College
# 49  Trinity College
# Hamilton College
#     Week Day (Str)  Time Slot            Team 1              Team 2  \
# 50     0      Fri.          0  Hamilton College  Middlebury College
# 51     0      Sat.          2  Hamilton College    Williams College
#
#             Location
# 50  Hamilton College
# 51  Hamilton College
#     Week Day (Str)  Time Slot            Team 1               Team 2  \
# 52     1      Sat.          3  Hamilton College  Wesleyan University
# 53     1      Sat.          4  Hamilton College  Connecticut College
#
#             Location
# 52  Williams College
# 53  Williams College
#     Week Day (Str)  Time Slot            Team 1           Team 2  \
# 54     2      Fri.          1  Hamilton College  Amherst College
# 55     2      Sat.          4  Hamilton College  Trinity College
#
#            Location
# 54  Amherst College
# 55  Amherst College
#     Week Day (Str)  Time Slot            Team 1            Team 2  \
# 56     3      Fri.          0  Hamilton College  Tufts University
#
#             Location
# 56  Williams College
#     Week Day (Str)  Time Slot            Team 1           Team 2  \
# 57     4      Fri.          1  Hamilton College  Bowdoin College
# 58     4      Sat.          3  Hamilton College    Bates College
# 59     4      Sat.          4  Hamilton College    Colby College
#
#               Location
# 57  Middlebury College
# 58  Middlebury College
# 59  Middlebury College
# Middlebury College
#     Week Day (Str)  Time Slot              Team 1            Team 2  \
# 60     0      Fri.          0  Middlebury College  Hamilton College
# 61     0      Sat.          1  Middlebury College  Williams College
#
#             Location
# 60  Hamilton College
# 61  Hamilton College
#     Week Day (Str)  Time Slot              Team 1               Team 2  \
# 62     1      Fri.          0  Middlebury College  Connecticut College
# 63     1      Sat.          5  Middlebury College  Wesleyan University
#
#             Location
# 62  Williams College
# 63  Williams College
#     Week Day (Str)  Time Slot              Team 1           Team 2  \
# 64     2      Sat.          3  Middlebury College  Trinity College
# 65     2      Sat.          5  Middlebury College  Amherst College
#
#            Location
# 64  Amherst College
# 65  Amherst College
#     Week Day (Str)  Time Slot              Team 1            Team 2  \
# 66     3      Sat.          2  Middlebury College  Tufts University
#
#             Location
# 66  Williams College
#     Week Day (Str)  Time Slot              Team 1           Team 2  \
# 67     4      Fri.          0  Middlebury College    Bates College
# 68     4      Sat.          7  Middlebury College    Colby College
# 69     4      Sat.          8  Middlebury College  Bowdoin College
#
#               Location
# 67  Middlebury College
# 68  Middlebury College
# 69  Middlebury College
# Trinity College
#     Week Day (Str)  Time Slot           Team 1           Team 2       Location
# 70     0      Fri.          0  Trinity College    Bates College  Colby College
# 71     0      Sat.          3  Trinity College  Bowdoin College  Colby College
# 72     0      Sat.          4  Trinity College    Colby College  Colby College
#     Week Day (Str)  Time Slot           Team 1            Team 2  \
# 73     1      Sat.          0  Trinity College  Tufts University
#
#             Location
# 73  Tufts University
#     Week Day (Str)  Time Slot           Team 1              Team 2  \
# 74     2      Fri.          0  Trinity College    Williams College
# 75     2      Sat.          3  Trinity College  Middlebury College
# 76     2      Sat.          4  Trinity College    Hamilton College
#
#            Location
# 74  Amherst College
# 75  Amherst College
# 76  Amherst College
#     Week Day (Str)  Time Slot           Team 1           Team 2  \
# 77     3      Sat.          0  Trinity College  Amherst College
#
#            Location
# 77  Trinity College
#     Week Day (Str)  Time Slot           Team 1               Team 2  \
# 78     4      Fri.          1  Trinity College  Wesleyan University
# 79     4      Sat.          2  Trinity College  Connecticut College
#
#            Location
# 78  Trinity College
# 79  Trinity College
# Tufts University
#     Week Day (Str)  Time Slot            Team 1               Team 2  \
# 80     0      Sat.          0  Tufts University  Connecticut College
# 81     0      Sat.          1  Tufts University  Wesleyan University
#
#                Location
# 80  Wesleyan University
# 81  Wesleyan University
#     Week Day (Str)  Time Slot            Team 1           Team 2  \
# 82     1      Sat.          0  Tufts University  Trinity College
# 83     1      Sat.          1  Tufts University  Amherst College
#
#             Location
# 82  Tufts University
# 83  Tufts University
#     Week Day (Str)  Time Slot            Team 1           Team 2  \
# 84     2      Fri.          0  Tufts University    Bates College
# 85     2      Sat.          1  Tufts University    Colby College
# 86     2      Sat.          2  Tufts University  Bowdoin College
#
#          Location
# 84  Bates College
# 85  Bates College
# 86  Bates College
#     Week Day (Str)  Time Slot            Team 1              Team 2  \
# 87     3      Fri.          0  Tufts University    Hamilton College
# 88     3      Sat.          1  Tufts University    Williams College
# 89     3      Sat.          2  Tufts University  Middlebury College
#
#             Location
# 87  Williams College
# 88  Williams College
# 89  Williams College
# Wesleyan University
#     Week Day (Str)  Time Slot               Team 1            Team 2  \
# 90     0      Sat.          1  Wesleyan University  Tufts University
#
#                Location
# 90  Wesleyan University
#     Week Day (Str)  Time Slot               Team 1              Team 2  \
# 91     1      Fri.          1  Wesleyan University    Williams College
# 92     1      Sat.          3  Wesleyan University    Hamilton College
# 93     1      Sat.          5  Wesleyan University  Middlebury College
#
#             Location
# 91  Williams College
# 92  Williams College
# 93  Williams College
#     Week Day (Str)  Time Slot               Team 1               Team 2  \
# 94     2      Sat.          0  Wesleyan University  Connecticut College
#
#                Location
# 94  Wesleyan University
#     Week Day (Str)  Time Slot               Team 1           Team 2  \
# 95     3      Fri.          0  Wesleyan University    Bates College
# 96     3      Sat.          3  Wesleyan University    Colby College
# 97     3      Sat.          5  Wesleyan University  Bowdoin College
#
#                Location
# 95  Connecticut College
# 96  Connecticut College
# 97  Connecticut College
#     Week Day (Str)  Time Slot               Team 1           Team 2  \
# 98     4      Fri.          1  Wesleyan University  Trinity College
# 99     4      Sat.          3  Wesleyan University  Amherst College
#
#            Location
# 98  Trinity College
# 99  Trinity College
# Williams College
#      Week Day (Str)  Time Slot            Team 1              Team 2  \
# 100     0      Sat.          1  Williams College  Middlebury College
# 101     0      Sat.          2  Williams College    Hamilton College
#
#              Location
# 100  Hamilton College
# 101  Hamilton College
#      Week Day (Str)  Time Slot            Team 1               Team 2  \
# 102     1      Fri.          1  Williams College  Wesleyan University
# 103     1      Sat.          2  Williams College  Connecticut College
#
#              Location
# 102  Williams College
# 103  Williams College
#      Week Day (Str)  Time Slot            Team 1           Team 2  \
# 104     2      Fri.          0  Williams College  Trinity College
# 105     2      Sat.          2  Williams College  Amherst College
#
#             Location
# 104  Amherst College
# 105  Amherst College
#      Week Day (Str)  Time Slot            Team 1            Team 2  \
# 106     3      Sat.          1  Williams College  Tufts University
#
#              Location
# 106  Williams College
#      Week Day (Str)  Time Slot            Team 1           Team 2  \
# 107     4      Fri.          2  Williams College    Colby College
# 108     4      Sat.          5  Williams College    Bates College
# 109     4      Sat.          6  Williams College  Bowdoin College
#
#                Location
# 107  Middlebury College
# 108  Middlebury College
# 109  Middlebury College
# ##############
# # SCHEDULE 1 #
# ##############
# Amherst College
#    Week Day (Str)  Time Slot           Team 1           Team 2  \
# 0     0      Fri.          2  Amherst College    Colby College
# 1     0      Sat.          7  Amherst College    Bates College
# 2     0      Sat.          8  Amherst College  Bowdoin College
#
#           Location
# 0  Bowdoin College
# 1  Bowdoin College
# 2  Bowdoin College
#    Week Day (Str)  Time Slot           Team 1            Team 2  \
# 3     1      Sat.          2  Amherst College  Tufts University
#
#            Location
# 3  Tufts University
#    Week Day (Str)  Time Slot           Team 1            Team 2  \
# 4     2      Sat.          1  Amherst College  Hamilton College
#
#              Location
# 4  Middlebury College
#    Week Day (Str)  Time Slot           Team 1              Team 2  \
# 5     3      Fri.          0  Amherst College    Williams College
# 6     3      Sat.          1  Amherst College  Middlebury College
#
#            Location
# 5  Williams College
# 6  Williams College
#    Week Day (Str)  Time Slot           Team 1               Team 2  \
# 7     4      Fri.          2  Amherst College      Trinity College
# 8     4      Sat.          4  Amherst College  Connecticut College
# 9     4      Sat.          7  Amherst College  Wesleyan University
#
#           Location
# 7  Amherst College
# 8  Amherst College
# 9  Amherst College
# Bates College
#     Week Day (Str)  Time Slot         Team 1              Team 2  \
# 10     0      Fri.          1  Bates College  Middlebury College
# 11     0      Sat.          6  Bates College    Williams College
# 12     0      Sat.          7  Bates College     Amherst College
#
#            Location
# 10  Bowdoin College
# 11  Bowdoin College
# 12  Bowdoin College
#     Week Day (Str)  Time Slot         Team 1               Team 2  \
# 13     1      Fri.          2  Bates College      Trinity College
# 14     1      Sat.          4  Bates College  Connecticut College
# 15     1      Sat.          8  Bates College  Wesleyan University
#
#            Location
# 13  Trinity College
# 14  Trinity College
# 15  Trinity College
#     Week Day (Str)  Time Slot         Team 1           Team 2       Location
# 16     2      Fri.          0  Bates College  Bowdoin College  Bates College
# 17     2      Sat.          1  Bates College    Colby College  Bates College
#     Week Day (Str)  Time Slot         Team 1            Team 2       Location
# 18     3      Sat.          1  Bates College  Tufts University  Colby College
#     Week Day (Str)  Time Slot         Team 1            Team 2       Location
# 19     4      Fri.          0  Bates College  Hamilton College  Colby College
# Bowdoin College
#     Week Day (Str)  Time Slot           Team 1              Team 2  \
# 20     0      Fri.          0  Bowdoin College    Williams College
# 21     0      Sat.          4  Bowdoin College  Middlebury College
# 22     0      Sat.          8  Bowdoin College     Amherst College
#
#            Location
# 20  Bowdoin College
# 21  Bowdoin College
# 22  Bowdoin College
#     Week Day (Str)  Time Slot           Team 1               Team 2  \
# 23     1      Fri.          0  Bowdoin College  Connecticut College
# 24     1      Sat.          3  Bowdoin College  Wesleyan University
# 25     1      Sat.          7  Bowdoin College      Trinity College
#
#            Location
# 23  Trinity College
# 24  Trinity College
# 25  Trinity College
#     Week Day (Str)  Time Slot           Team 1         Team 2       Location
# 26     2      Fri.          0  Bowdoin College  Bates College  Bates College
# 27     2      Sat.          2  Bowdoin College  Colby College  Bates College
#     Week Day (Str)  Time Slot           Team 1            Team 2  \
# 28     3      Sat.          2  Bowdoin College  Tufts University
#
#          Location
# 28  Colby College
#     Week Day (Str)  Time Slot           Team 1            Team 2  \
# 29     4      Sat.          1  Bowdoin College  Hamilton College
#
#          Location
# 29  Colby College
# Colby College
#     Week Day (Str)  Time Slot         Team 1              Team 2  \
# 30     0      Fri.          2  Colby College     Amherst College
# 31     0      Sat.          3  Colby College  Middlebury College
# 32     0      Sat.          5  Colby College    Williams College
#
#            Location
# 30  Bowdoin College
# 31  Bowdoin College
# 32  Bowdoin College
#     Week Day (Str)  Time Slot         Team 1               Team 2  \
# 33     1      Fri.          1  Colby College  Wesleyan University
# 34     1      Sat.          5  Colby College  Connecticut College
# 35     1      Sat.          6  Colby College      Trinity College
#
#            Location
# 33  Trinity College
# 34  Trinity College
# 35  Trinity College
#     Week Day (Str)  Time Slot         Team 1           Team 2       Location
# 36     2      Sat.          1  Colby College    Bates College  Bates College
# 37     2      Sat.          2  Colby College  Bowdoin College  Bates College
#     Week Day (Str)  Time Slot         Team 1            Team 2       Location
# 38     3      Fri.          0  Colby College  Tufts University  Colby College
#     Week Day (Str)  Time Slot         Team 1            Team 2       Location
# 39     4      Sat.          2  Colby College  Hamilton College  Colby College
# Connecticut College
#     Week Day (Str)  Time Slot               Team 1               Team 2  \
# 40     0      Fri.          0  Connecticut College  Wesleyan University
# 41     0      Sat.          1  Connecticut College      Trinity College
#
#                Location
# 40  Connecticut College
# 41  Connecticut College
#     Week Day (Str)  Time Slot               Team 1           Team 2  \
# 42     1      Fri.          0  Connecticut College  Bowdoin College
# 43     1      Sat.          4  Connecticut College    Bates College
# 44     1      Sat.          5  Connecticut College    Colby College
#
#            Location
# 42  Trinity College
# 43  Trinity College
# 44  Trinity College
#     Week Day (Str)  Time Slot               Team 1            Team 2  \
# 45     2      Sat.          1  Connecticut College  Tufts University
#
#                Location
# 45  Wesleyan University
#     Week Day (Str)  Time Slot               Team 1            Team 2  \
# 46     3      Sat.          1  Connecticut College  Hamilton College
#
#                Location
# 46  Wesleyan University
#     Week Day (Str)  Time Slot               Team 1              Team 2  \
# 47     4      Fri.          0  Connecticut College    Williams College
# 48     4      Sat.          3  Connecticut College  Middlebury College
# 49     4      Sat.          4  Connecticut College     Amherst College
#
#            Location
# 47  Amherst College
# 48  Amherst College
# 49  Amherst College
# Hamilton College
#     Week Day (Str)  Time Slot            Team 1            Team 2  \
# 50     0      Sat.          0  Hamilton College  Tufts University
#
#             Location
# 50  Hamilton College
#     Week Day (Str)  Time Slot            Team 1              Team 2  \
# 51     2      Fri.          0  Hamilton College    Williams College
# 52     2      Sat.          1  Hamilton College     Amherst College
# 53     2      Sat.          2  Hamilton College  Middlebury College
#
#               Location
# 51  Middlebury College
# 52  Middlebury College
# 53  Middlebury College
#     Week Day (Str)  Time Slot            Team 1               Team 2  \
# 54     3      Fri.          0  Hamilton College      Trinity College
# 55     3      Sat.          1  Hamilton College  Connecticut College
# 56     3      Sat.          2  Hamilton College  Wesleyan University
#
#                Location
# 54  Wesleyan University
# 55  Wesleyan University
# 56  Wesleyan University
#     Week Day (Str)  Time Slot            Team 1           Team 2  \
# 57     4      Fri.          0  Hamilton College    Bates College
# 58     4      Sat.          1  Hamilton College  Bowdoin College
# 59     4      Sat.          2  Hamilton College    Colby College
#
#          Location
# 57  Colby College
# 58  Colby College
# 59  Colby College
# Middlebury College
#     Week Day (Str)  Time Slot              Team 1           Team 2  \
# 60     0      Fri.          1  Middlebury College    Bates College
# 61     0      Sat.          3  Middlebury College    Colby College
# 62     0      Sat.          4  Middlebury College  Bowdoin College
#
#            Location
# 60  Bowdoin College
# 61  Bowdoin College
# 62  Bowdoin College
#     Week Day (Str)  Time Slot              Team 1            Team 2  \
# 63     1      Fri.          0  Middlebury College  Tufts University
#
#             Location
# 63  Tufts University
#     Week Day (Str)  Time Slot              Team 1            Team 2  \
# 64     2      Sat.          2  Middlebury College  Hamilton College
#
#               Location
# 64  Middlebury College
#     Week Day (Str)  Time Slot              Team 1            Team 2  \
# 65     3      Sat.          1  Middlebury College   Amherst College
# 66     3      Sat.          2  Middlebury College  Williams College
#
#             Location
# 65  Williams College
# 66  Williams College
#     Week Day (Str)  Time Slot              Team 1               Team 2  \
# 67     4      Fri.          1  Middlebury College  Wesleyan University
# 68     4      Sat.          3  Middlebury College  Connecticut College
# 69     4      Sat.          8  Middlebury College      Trinity College
#
#            Location
# 67  Amherst College
# 68  Amherst College
# 69  Amherst College
# Trinity College
#     Week Day (Str)  Time Slot           Team 1               Team 2  \
# 70     0      Sat.          1  Trinity College  Connecticut College
# 71     0      Sat.          2  Trinity College  Wesleyan University
#
#                Location
# 70  Connecticut College
# 71  Connecticut College
#     Week Day (Str)  Time Slot           Team 1           Team 2  \
# 72     1      Fri.          2  Trinity College    Bates College
# 73     1      Sat.          6  Trinity College    Colby College
# 74     1      Sat.          7  Trinity College  Bowdoin College
#
#            Location
# 72  Trinity College
# 73  Trinity College
# 74  Trinity College
#     Week Day (Str)  Time Slot           Team 1            Team 2  \
# 75     2      Fri.          0  Trinity College  Tufts University
#
#                Location
# 75  Wesleyan University
#     Week Day (Str)  Time Slot           Team 1            Team 2  \
# 76     3      Fri.          0  Trinity College  Hamilton College
#
#                Location
# 76  Wesleyan University
#     Week Day (Str)  Time Slot           Team 1              Team 2  \
# 77     4      Fri.          2  Trinity College     Amherst College
# 78     4      Sat.          6  Trinity College    Williams College
# 79     4      Sat.          8  Trinity College  Middlebury College
#
#            Location
# 77  Amherst College
# 78  Amherst College
# 79  Amherst College
# Tufts University
#     Week Day (Str)  Time Slot            Team 1            Team 2  \
# 80     0      Sat.          0  Tufts University  Hamilton College
#
#             Location
# 80  Hamilton College
#     Week Day (Str)  Time Slot            Team 1              Team 2  \
# 81     1      Fri.          0  Tufts University  Middlebury College
# 82     1      Sat.          1  Tufts University    Williams College
# 83     1      Sat.          2  Tufts University     Amherst College
#
#             Location
# 81  Tufts University
# 82  Tufts University
# 83  Tufts University
#     Week Day (Str)  Time Slot            Team 1               Team 2  \
# 84     2      Fri.          0  Tufts University      Trinity College
# 85     2      Sat.          1  Tufts University  Connecticut College
# 86     2      Sat.          2  Tufts University  Wesleyan University
#
#                Location
# 84  Wesleyan University
# 85  Wesleyan University
# 86  Wesleyan University
#     Week Day (Str)  Time Slot            Team 1           Team 2  \
# 87     3      Fri.          0  Tufts University    Colby College
# 88     3      Sat.          1  Tufts University    Bates College
# 89     3      Sat.          2  Tufts University  Bowdoin College
#
#          Location
# 87  Colby College
# 88  Colby College
# 89  Colby College
# Wesleyan University
#     Week Day (Str)  Time Slot               Team 1               Team 2  \
# 90     0      Fri.          0  Wesleyan University  Connecticut College
# 91     0      Sat.          2  Wesleyan University      Trinity College
#
#                Location
# 90  Connecticut College
# 91  Connecticut College
#     Week Day (Str)  Time Slot               Team 1           Team 2  \
# 92     1      Fri.          1  Wesleyan University    Colby College
# 93     1      Sat.          3  Wesleyan University  Bowdoin College
# 94     1      Sat.          8  Wesleyan University    Bates College
#
#            Location
# 92  Trinity College
# 93  Trinity College
# 94  Trinity College
#     Week Day (Str)  Time Slot               Team 1            Team 2  \
# 95     2      Sat.          2  Wesleyan University  Tufts University
#
#                Location
# 95  Wesleyan University
#     Week Day (Str)  Time Slot               Team 1            Team 2  \
# 96     3      Sat.          2  Wesleyan University  Hamilton College
#
#                Location
# 96  Wesleyan University
#     Week Day (Str)  Time Slot               Team 1              Team 2  \
# 97     4      Fri.          1  Wesleyan University  Middlebury College
# 98     4      Sat.          5  Wesleyan University    Williams College
# 99     4      Sat.          7  Wesleyan University     Amherst College
#
#            Location
# 97  Amherst College
# 98  Amherst College
# 99  Amherst College
# Williams College
#      Week Day (Str)  Time Slot            Team 1           Team 2  \
# 100     0      Fri.          0  Williams College  Bowdoin College
# 101     0      Sat.          5  Williams College    Colby College
# 102     0      Sat.          6  Williams College    Bates College
#
#             Location
# 100  Bowdoin College
# 101  Bowdoin College
# 102  Bowdoin College
#      Week Day (Str)  Time Slot            Team 1            Team 2  \
# 103     1      Sat.          1  Williams College  Tufts University
#
#              Location
# 103  Tufts University
#      Week Day (Str)  Time Slot            Team 1            Team 2  \
# 104     2      Fri.          0  Williams College  Hamilton College
#
#                Location
# 104  Middlebury College
#      Week Day (Str)  Time Slot            Team 1              Team 2  \
# 105     3      Fri.          0  Williams College     Amherst College
# 106     3      Sat.          2  Williams College  Middlebury College
#
#              Location
# 105  Williams College
# 106  Williams College
#      Week Day (Str)  Time Slot            Team 1               Team 2  \
# 107     4      Fri.          0  Williams College  Connecticut College
# 108     4      Sat.          5  Williams College  Wesleyan University
# 109     4      Sat.          6  Williams College      Trinity College
#
#             Location
# 107  Amherst College
# 108  Amherst College
# 109  Amherst College

# %% [markdown]
# ## Check Schedules

# %%
# schedules in optimized pair
columns = [
    'Abbreviated Schedule ID',
    'Schedule ID 0',
    'Schedule ID 1',
]

optimized_schedule_analysis_df = pd.read_pickle(OPTIMIZED_SCHEDULE_ANALYSIS_FILENAME)
pair_schedule_comparison_df = pd.read_pickle(PAIR_SCHEDULE_COMPARISON_FILENAME)
pair_schedule_comparison_df = pair_schedule_comparison_df.iloc[selected_idxs]

name_to_id_mapping = create_venue_id_mapping_dicts_from_file(VENUES_MAPPING_FILENAME)[0]
venue_one_way_distance_matrix = pd.read_csv(DISTANCE_MATRIX_FILENAME, index_col=0)
venue_one_way_duration_matrix_hhmm = pd.read_csv(DURATION_MATRIX_HHMM_FILENAME, index_col=0)

display(pair_schedule_comparison_df[columns])
# Out:
#   Abbreviated Schedule ID                      Schedule ID 0  \
# 0                  p0_1_3  15_2335_optimized_team_schedule_0
# 2                p4_1.5_3  15_2335_optimized_team_schedule_0
#
#                       Schedule ID 1
# 0  3_2215_optimized_team_schedule_1
# 2  5_2235_optimized_team_schedule_0

# %%
# create list of schedules included in our schedule pairs
filenames = []
for idx in [0, 1]:
    for col_name, schedule in pair_schedule_comparison_df[columns].iloc[idx].items():
        if "Abbreviated" not in col_name:
            filenames.append(f"{schedule}.csv")
            
filenames
# Out:
# ['15_2335_optimized_team_schedule_0.csv',
#  '3_2215_optimized_team_schedule_1.csv',
#  '15_2335_optimized_team_schedule_0.csv',
#  '5_2235_optimized_team_schedule_0.csv']

# %%
from src.configuration import WEEKEND_OVERNIGHT_THRESHOLD, DISTANCE_OVERNIGHT_THRESHOLD

print(f"WEEKEND_OVERNIGHT_THRESHOLD = {WEEKEND_OVERNIGHT_THRESHOLD}")
print("""
    \tMaximum number of miles to drive one-way without staying for an
    \tovernight between Friday and Saturday matches (recommended = 53
    \t==> max one-way distance with duration < 1 hour)
    """)
      
print(f"DISTANCE_OVERNIGHT_THRESHOLD = {DISTANCE_OVERNIGHT_THRESHOLD}")
print("""
    \tMaximum number of miles to drive one-way without staying for an
    \tovernight (recommended = 153 ==> max one-way distance with duration
    \t< 3 hours)
    """)


for filename in filenames[:2]:
    
    print("########################################")
    print(f"# {filename} #")
    print("########################################")

    schedule_df = pd.read_csv(f"results/pair/optimized_schedules/{filename}", index_col=0)

    schedule_df['Home Game'] = schedule_df['Team 1'] == schedule_df['Location']
    schedule_df['Team 1 Name'] = schedule_df['Team 1']
    schedule_df['Location Name'] = schedule_df['Location']
    schedule_df['Team 1'] = schedule_df['Team 1'].map(name_to_id_mapping)
    schedule_df['Location'] = schedule_df['Location'].map(name_to_id_mapping)

    schedule_df['Team 1 Travel Distance (mi)'] = None
    schedule_df['Team 1 Travel Distance (hhmm)'] = None
    for idx, row in schedule_df.iterrows():
        schedule_df['Team 1 Travel Distance (mi)'][idx] = venue_one_way_distance_matrix.iloc[row['Team 1'], row['Location']]
        schedule_df['Team 1 Travel Distance (hhmm)'][idx] = venue_one_way_duration_matrix_hhmm.iloc[row['Team 1'], row['Location']]


    schedule_df['Distance Overnight'] = False
    schedule_df['Weekend Overnight'] = False
    for team_week, team_week_df in schedule_df.groupby(['Team 1', 'Week']):

        team_week_df = team_week_df.reset_index(drop=False)
        curr_team = team_week[0]

        # Iterate over team 1 matches for the week
        for idx, row in team_week_df.iterrows():
            current_match = team_week_df.loc[idx]
            schedule_df_idx = current_match['index']

            # Check for a distance overnight
            if is_distance_overnight(current_match, venue_one_way_distance_matrix, DISTANCE_OVERNIGHT_THRESHOLD):
                schedule_df['Distance Overnight'][schedule_df_idx] = True

            # Check for a weekend overnight
            if idx > 0:
                previous_match = team_week_df.loc[idx - 1]

                if is_weekend_overnight(previous_match, current_match, venue_one_way_distance_matrix, WEEKEND_OVERNIGHT_THRESHOLD):

                    # Count weekend overnight
                    schedule_df['Weekend Overnight'][schedule_df_idx] = True

                    # Remove distance overnight because have weekend overnight ==> already staying overnight
                    schedule_df['Distance Overnight'][schedule_df_idx] = False

                    break

    # Display results                
    columns = [
        'Week',
        'Day (Str)',
        'Time Slot',
        'Team 1 Name',
        'Team 2',
        'Location Name',
        'Home Game',
        'Team 1 Travel Distance (mi)',
        'Team 1 Travel Distance (hhmm)',
        'Distance Overnight',
        'Weekend Overnight'
    ]

    # for team_1_group_name, team_1_group in _.groupby('Team 1'):

    #         display(team_1_group[columns])
    #         print(single_schedule_comparison_df['Team Overnight Dict'][0][team_1_group_name])

    optimized_schedule_analysis_df = pd.read_pickle(OPTIMIZED_SCHEDULE_ANALYSIS_FILENAME)

    for team_1, team_1_df in schedule_df.groupby('Team 1'):

        print(f"TEAM {team_1}")
        _ = optimized_schedule_analysis_df[optimized_schedule_analysis_df['Schedule ID'] == filename[:-4]]
        print(f"   overnight = {_['Team Overnight Dict'].item()[team_1]}")
        print(f"   distance = {_['Team Distance Dict'].item()[team_1]}")

        display(team_1_df)

    #     for week, week_df in team_1_df.groupby('Week'):

    #         display(week_df[columns])
# Out:
# WEEKEND_OVERNIGHT_THRESHOLD = 53
#
#     	Maximum number of miles to drive one-way without staying for an
#     	overnight between Friday and Saturday matches (recommended = 53
#     	==> max one-way distance with duration < 1 hour)
#
# DISTANCE_OVERNIGHT_THRESHOLD = 153
#
#     	Maximum number of miles to drive one-way without staying for an
#     	overnight (recommended = 153 ==> max one-way distance with duration
#     	< 3 hours)
#
# ########################################
# # 15_2335_optimized_team_schedule_0.csv #
# ########################################
# /Users/hcederna/anaconda3/envs/schedule-optimization/lib/python3.7/site-packages/ipykernel_launcher.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hcederna/anaconda3/envs/schedule-optimization/lib/python3.7/site-packages/ipykernel_launcher.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hcederna/anaconda3/envs/schedule-optimization/lib/python3.7/site-packages/ipykernel_launcher.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hcederna/anaconda3/envs/schedule-optimization/lib/python3.7/site-packages/ipykernel_launcher.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hcederna/anaconda3/envs/schedule-optimization/lib/python3.7/site-packages/ipykernel_launcher.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# TEAM 0
#    overnight = 1
#    distance = 984
#    Week Day (Str)  Time Slot  Team 1               Team 2  Location  \
# 0     0      Fri.          1       0        Colby College         3
# 1     0      Sat.          2       0      Bowdoin College         3
# 2     0      Sat.          5       0        Bates College         3
# 3     1      Sat.          1       0     Tufts University         8
# 4     2      Fri.          1       0     Hamilton College         0
# 5     2      Sat.          2       0     Williams College         0
# 6     2      Sat.          5       0   Middlebury College         0
# 7     3      Sat.          0       0      Trinity College         7
# 8     4      Fri.          0       0  Connecticut College         7
# 9     4      Sat.          3       0  Wesleyan University         7
#
#    Home Game      Team 1 Name     Location Name Team 1 Travel Distance (mi)  \
# 0      False  Amherst College     Colby College                         246
# 1      False  Amherst College     Colby College                         246
# 2      False  Amherst College     Colby College                         246
# 3      False  Amherst College  Tufts University                          87
# 4       True  Amherst College   Amherst College                           0
# 5       True  Amherst College   Amherst College                           0
# 6       True  Amherst College   Amherst College                           0
# 7      False  Amherst College   Trinity College                          53
# 8      False  Amherst College   Trinity College                          53
# 9      False  Amherst College   Trinity College                          53
#
#   Team 1 Travel Distance (hhmm)  Distance Overnight  Weekend Overnight
# 0                          3:55                True              False
# 1                          3:55               False               True
# 2                          3:55               False              False
# 3                          1:45               False              False
# 4                          0:00               False              False
# 5                          0:00               False              False
# 6                          0:00               False              False
# 7                          1:01               False              False
# 8                          1:01               False              False
# 9                          1:01               False              False
# TEAM 1
#    overnight = 2
#    distance = 1282
#     Week Day (Str)  Time Slot  Team 1               Team 2  Location  \
# 10     0      Fri.          0       1      Trinity College         3
# 11     0      Sat.          5       1      Amherst College         3
# 12     1      Fri.          0       1      Bowdoin College         2
# 13     1      Sat.          2       1        Colby College         2
# 14     2      Fri.          0       1     Tufts University         1
# 15     3      Fri.          0       1  Wesleyan University         4
# 16     3      Sat.          2       1  Connecticut College         4
# 17     4      Fri.          0       1   Middlebury College         6
# 18     4      Sat.          3       1     Hamilton College         6
# 19     4      Sat.          5       1     Williams College         6
#
#     Home Game    Team 1 Name        Location Name Team 1 Travel Distance (mi)  \
# 10      False  Bates College        Colby College                          49
# 11      False  Bates College        Colby College                          49
# 12      False  Bates College      Bowdoin College                          21
# 13      False  Bates College      Bowdoin College                          21
# 14       True  Bates College        Bates College                           0
# 15      False  Bates College  Connecticut College                         240
# 16      False  Bates College  Connecticut College                         240
# 17      False  Bates College   Middlebury College                         261
# 18      False  Bates College   Middlebury College                         261
# 19      False  Bates College   Middlebury College                         261
#
#    Team 1 Travel Distance (hhmm)  Distance Overnight  Weekend Overnight
# 10                          0:51               False              False
# 11                          0:51               False              False
# 12                          0:39               False              False
# 13                          0:39               False              False
# 14                          0:00               False              False
# 15                          3:42                True              False
# 16                          3:42               False               True
# 17                          4:26                True              False
# 18                          4:26               False               True
# 19                          4:26               False              False
# TEAM 2
#    overnight = 2
#    distance = 1118
#     Week Day (Str)  Time Slot  Team 1               Team 2  Location  \
# 20     0      Sat.          2       2      Amherst College         3
# 21     0      Sat.          3       2      Trinity College         3
# 22     1      Fri.          0       2        Bates College         2
# 23     1      Sat.          1       2        Colby College         2
# 24     2      Sat.          2       2     Tufts University         1
# 25     3      Sat.          4       2  Connecticut College         4
# 26     3      Sat.          5       2  Wesleyan University         4
# 27     4      Fri.          1       2     Hamilton College         6
# 28     4      Sat.          6       2     Williams College         6
# 29     4      Sat.          8       2   Middlebury College         6
#
#     Home Game      Team 1 Name        Location Name  \
# 20      False  Bowdoin College        Colby College
# 21      False  Bowdoin College        Colby College
# 22       True  Bowdoin College      Bowdoin College
# 23       True  Bowdoin College      Bowdoin College
# 24      False  Bowdoin College        Bates College
# 25      False  Bowdoin College  Connecticut College
# 26      False  Bowdoin College  Connecticut College
# 27      False  Bowdoin College   Middlebury College
# 28      False  Bowdoin College   Middlebury College
# 29      False  Bowdoin College   Middlebury College
#
#    Team 1 Travel Distance (mi) Team 1 Travel Distance (hhmm)  \
# 20                          50                          0:52
# 21                          50                          0:52
# 22                           0                          0:00
# 23                           0                          0:00
# 24                          21                          0:39
# 25                         233                          3:38
# 26                         233                          3:38
# 27                         255                          4:22
# 28                         255                          4:22
# 29                         255                          4:22
#
#     Distance Overnight  Weekend Overnight
# 20               False              False
# 21               False              False
# 22               False              False
# 23               False              False
# 24               False              False
# 25                True              False
# 26                True              False
# 27                True              False
# 28               False               True
# 29               False              False
# TEAM 3
#    overnight = 2
#    distance = 1360
#     Week Day (Str)  Time Slot  Team 1               Team 2  Location  \
# 30     0      Fri.          1       3      Amherst College         3
# 31     0      Sat.          4       3      Trinity College         3
# 32     1      Sat.          1       3      Bowdoin College         2
# 33     1      Sat.          2       3        Bates College         2
# 34     2      Sat.          1       3     Tufts University         1
# 35     3      Fri.          1       3  Connecticut College         4
# 36     3      Sat.          3       3  Wesleyan University         4
# 37     4      Fri.          2       3     Williams College         6
# 38     4      Sat.          4       3     Hamilton College         6
# 39     4      Sat.          7       3   Middlebury College         6
#
#     Home Game    Team 1 Name        Location Name Team 1 Travel Distance (mi)  \
# 30       True  Colby College        Colby College                           0
# 31       True  Colby College        Colby College                           0
# 32      False  Colby College      Bowdoin College                          50
# 33      False  Colby College      Bowdoin College                          50
# 34      False  Colby College        Bates College                          49
# 35      False  Colby College  Connecticut College                         280
# 36      False  Colby College  Connecticut College                         280
# 37      False  Colby College   Middlebury College                         301
# 38      False  Colby College   Middlebury College                         301
# 39      False  Colby College   Middlebury College                         301
#
#    Team 1 Travel Distance (hhmm)  Distance Overnight  Weekend Overnight
# 30                          0:00               False              False
# 31                          0:00               False              False
# 32                          0:52               False              False
# 33                          0:52               False              False
# 34                          0:51               False              False
# 35                          4:13                True              False
# 36                          4:13               False               True
# 37                          4:57                True              False
# 38                          4:57               False               True
# 39                          4:57               False              False
# TEAM 4
#    overnight = 1
#    distance = 684
#     Week Day (Str)  Time Slot  Team 1               Team 2  Location  \
# 40     0      Sat.          0       4     Tufts University         9
# 41     1      Fri.          0       4   Middlebury College        10
# 42     1      Sat.          2       4     Williams College        10
# 43     1      Sat.          4       4     Hamilton College        10
# 44     2      Sat.          0       4  Wesleyan University         9
# 45     3      Fri.          1       4        Colby College         4
# 46     3      Sat.          2       4        Bates College         4
# 47     3      Sat.          4       4      Bowdoin College         4
# 48     4      Fri.          0       4      Amherst College         7
# 49     4      Sat.          2       4      Trinity College         7
#
#     Home Game          Team 1 Name        Location Name  \
# 40      False  Connecticut College  Wesleyan University
# 41      False  Connecticut College     Williams College
# 42      False  Connecticut College     Williams College
# 43      False  Connecticut College     Williams College
# 44      False  Connecticut College  Wesleyan University
# 45       True  Connecticut College  Connecticut College
# 46       True  Connecticut College  Connecticut College
# 47       True  Connecticut College  Connecticut College
# 48      False  Connecticut College      Trinity College
# 49      False  Connecticut College      Trinity College
#
#    Team 1 Travel Distance (mi) Team 1 Travel Distance (hhmm)  \
# 40                          40                          0:39
# 41                         158                          2:38
# 42                         158                          2:38
# 43                         158                          2:38
# 44                          40                          0:39
# 45                           0                          0:00
# 46                           0                          0:00
# 47                           0                          0:00
# 48                          52                          0:52
# 49                          52                          0:52
#
#     Distance Overnight  Weekend Overnight
# 40               False              False
# 41                True              False
# 42               False               True
# 43               False              False
# 44               False              False
# 45               False              False
# 46               False              False
# 47               False              False
# 48               False              False
# 49               False              False
# TEAM 5
#    overnight = 2
#    distance = 1328
#     Week Day (Str)  Time Slot  Team 1               Team 2  Location  \
# 50     0      Fri.          0       5   Middlebury College         5
# 51     0      Sat.          2       5     Williams College         5
# 52     1      Sat.          3       5  Wesleyan University        10
# 53     1      Sat.          4       5  Connecticut College        10
# 54     2      Fri.          1       5      Amherst College         0
# 55     2      Sat.          4       5      Trinity College         0
# 56     3      Fri.          0       5     Tufts University        10
# 57     4      Fri.          1       5      Bowdoin College         6
# 58     4      Sat.          3       5        Bates College         6
# 59     4      Sat.          4       5        Colby College         6
#
#     Home Game       Team 1 Name       Location Name  \
# 50       True  Hamilton College    Hamilton College
# 51       True  Hamilton College    Hamilton College
# 52      False  Hamilton College    Williams College
# 53      False  Hamilton College    Williams College
# 54      False  Hamilton College     Amherst College
# 55      False  Hamilton College     Amherst College
# 56      False  Hamilton College    Williams College
# 57      False  Hamilton College  Middlebury College
# 58      False  Hamilton College  Middlebury College
# 59      False  Hamilton College  Middlebury College
#
#    Team 1 Travel Distance (mi) Team 1 Travel Distance (hhmm)  \
# 50                           0                          0:00
# 51                           0                          0:00
# 52                         144                          2:33
# 53                         144                          2:33
# 54                         206                          3:18
# 55                         206                          3:18
# 56                         144                          2:33
# 57                         170                          3:29
# 58                         170                          3:29
# 59                         170                          3:29
#
#     Distance Overnight  Weekend Overnight
# 50               False              False
# 51               False              False
# 52               False              False
# 53               False              False
# 54                True              False
# 55               False               True
# 56               False              False
# 57                True              False
# 58               False               True
# 59               False              False
# TEAM 6
#    overnight = 2
#    distance = 1078
#     Week Day (Str)  Time Slot  Team 1               Team 2  Location  \
# 60     0      Fri.          0       6     Hamilton College         5
# 61     0      Sat.          1       6     Williams College         5
# 62     1      Fri.          0       6  Connecticut College        10
# 63     1      Sat.          5       6  Wesleyan University        10
# 64     2      Sat.          3       6      Trinity College         0
# 65     2      Sat.          5       6      Amherst College         0
# 66     3      Sat.          2       6     Tufts University        10
# 67     4      Fri.          0       6        Bates College         6
# 68     4      Sat.          7       6        Colby College         6
# 69     4      Sat.          8       6      Bowdoin College         6
#
#     Home Game         Team 1 Name       Location Name  \
# 60      False  Middlebury College    Hamilton College
# 61      False  Middlebury College    Hamilton College
# 62      False  Middlebury College    Williams College
# 63      False  Middlebury College    Williams College
# 64      False  Middlebury College     Amherst College
# 65      False  Middlebury College     Amherst College
# 66      False  Middlebury College    Williams College
# 67       True  Middlebury College  Middlebury College
# 68       True  Middlebury College  Middlebury College
# 69       True  Middlebury College  Middlebury College
#
#    Team 1 Travel Distance (mi) Team 1 Travel Distance (hhmm)  \
# 60                         170                          3:29
# 61                         170                          3:29
# 62                         108                          2:09
# 63                         108                          2:09
# 64                         153                          2:54
# 65                         153                          2:54
# 66                         108                          2:09
# 67                           0                          0:00
# 68                           0                          0:00
# 69                           0                          0:00
#
#     Distance Overnight  Weekend Overnight
# 60                True              False
# 61               False               True
# 62               False              False
# 63               False               True
# 64               False              False
# 65               False              False
# 66               False              False
# 67               False              False
# 68               False              False
# 69               False              False
# TEAM 7
#    overnight = 1
#    distance = 976
#     Week Day (Str)  Time Slot  Team 1               Team 2  Location  \
# 70     0      Fri.          0       7        Bates College         3
# 71     0      Sat.          3       7      Bowdoin College         3
# 72     0      Sat.          4       7        Colby College         3
# 73     1      Sat.          0       7     Tufts University         8
# 74     2      Fri.          0       7     Williams College         0
# 75     2      Sat.          3       7   Middlebury College         0
# 76     2      Sat.          4       7     Hamilton College         0
# 77     3      Sat.          0       7      Amherst College         7
# 78     4      Fri.          1       7  Wesleyan University         7
# 79     4      Sat.          2       7  Connecticut College         7
#
#     Home Game      Team 1 Name     Location Name Team 1 Travel Distance (mi)  \
# 70      False  Trinity College     Colby College                         274
# 71      False  Trinity College     Colby College                         274
# 72      False  Trinity College     Colby College                         274
# 73      False  Trinity College  Tufts University                         108
# 74      False  Trinity College   Amherst College                          53
# 75      False  Trinity College   Amherst College                          53
# 76      False  Trinity College   Amherst College                          53
# 77       True  Trinity College   Trinity College                           0
# 78       True  Trinity College   Trinity College                           0
# 79       True  Trinity College   Trinity College                           0
#
#    Team 1 Travel Distance (hhmm)  Distance Overnight  Weekend Overnight
# 70                          4:10                True              False
# 71                          4:10               False               True
# 72                          4:10               False              False
# 73                          1:46               False              False
# 74                          1:01               False              False
# 75                          1:01               False              False
# 76                          1:01               False              False
# 77                          0:00               False              False
# 78                          0:00               False              False
# 79                          0:00               False              False
# TEAM 8
#    overnight = 2
#    distance = 778
#     Week Day (Str)  Time Slot  Team 1               Team 2  Location  \
# 80     0      Sat.          0       8  Connecticut College         9
# 81     0      Sat.          1       8  Wesleyan University         9
# 82     1      Sat.          0       8      Trinity College         8
# 83     1      Sat.          1       8      Amherst College         8
# 84     2      Fri.          0       8        Bates College         1
# 85     2      Sat.          1       8        Colby College         1
# 86     2      Sat.          2       8      Bowdoin College         1
# 87     3      Fri.          0       8     Hamilton College        10
# 88     3      Sat.          1       8     Williams College        10
# 89     3      Sat.          2       8   Middlebury College        10
#
#     Home Game       Team 1 Name        Location Name  \
# 80      False  Tufts University  Wesleyan University
# 81      False  Tufts University  Wesleyan University
# 82       True  Tufts University     Tufts University
# 83       True  Tufts University     Tufts University
# 84      False  Tufts University        Bates College
# 85      False  Tufts University        Bates College
# 86      False  Tufts University        Bates College
# 87      False  Tufts University     Williams College
# 88      False  Tufts University     Williams College
# 89      False  Tufts University     Williams College
#
#    Team 1 Travel Distance (mi) Team 1 Travel Distance (hhmm)  \
# 80                         119                          1:58
# 81                         119                          1:58
# 82                           0                          0:00
# 83                           0                          0:00
# 84                         140                          2:14
# 85                         140                          2:14
# 86                         140                          2:14
# 87                         130                          2:43
# 88                         130                          2:43
# 89                         130                          2:43
#
#     Distance Overnight  Weekend Overnight
# 80               False              False
# 81               False              False
# 82               False              False
# 83               False              False
# 84               False              False
# 85               False               True
# 86               False              False
# 87               False              False
# 88               False               True
# 89               False              False
# TEAM 9
#    overnight = 1
#    distance = 476
#     Week Day (Str)  Time Slot  Team 1               Team 2  Location  \
# 90     0      Sat.          1       9     Tufts University         9
# 91     1      Fri.          1       9     Williams College        10
# 92     1      Sat.          3       9     Hamilton College        10
# 93     1      Sat.          5       9   Middlebury College        10
# 94     2      Sat.          0       9  Connecticut College         9
# 95     3      Fri.          0       9        Bates College         4
# 96     3      Sat.          3       9        Colby College         4
# 97     3      Sat.          5       9      Bowdoin College         4
# 98     4      Fri.          1       9      Trinity College         7
# 99     4      Sat.          3       9      Amherst College         7
#
#     Home Game          Team 1 Name        Location Name  \
# 90       True  Wesleyan University  Wesleyan University
# 91      False  Wesleyan University     Williams College
# 92      False  Wesleyan University     Williams College
# 93      False  Wesleyan University     Williams College
# 94       True  Wesleyan University  Wesleyan University
# 95      False  Wesleyan University  Connecticut College
# 96      False  Wesleyan University  Connecticut College
# 97      False  Wesleyan University  Connecticut College
# 98      False  Wesleyan University      Trinity College
# 99      False  Wesleyan University      Trinity College
#
#    Team 1 Travel Distance (mi) Team 1 Travel Distance (hhmm)  \
# 90                           0                          0:00
# 91                         126                          2:10
# 92                         126                          2:10
# 93                         126                          2:10
# 94                           0                          0:00
# 95                          40                          0:39
# 96                          40                          0:39
# 97                          40                          0:39
# 98                          16                          0:24
# 99                          16                          0:24
#
#     Distance Overnight  Weekend Overnight
# 90               False              False
# 91               False              False
# 92               False               True
# 93               False              False
# 94               False              False
# 95               False              False
# 96               False              False
# 97               False              False
# 98               False              False
# 99               False              False
# TEAM 10
#    overnight = 2
#    distance = 624
#      Week Day (Str)  Time Slot  Team 1               Team 2  Location  \
# 100     0      Sat.          1      10   Middlebury College         5
# 101     0      Sat.          2      10     Hamilton College         5
# 102     1      Fri.          1      10  Wesleyan University        10
# 103     1      Sat.          2      10  Connecticut College        10
# 104     2      Fri.          0      10      Trinity College         0
# 105     2      Sat.          2      10      Amherst College         0
# 106     3      Sat.          1      10     Tufts University        10
# 107     4      Fri.          2      10        Colby College         6
# 108     4      Sat.          5      10        Bates College         6
# 109     4      Sat.          6      10      Bowdoin College         6
#
#      Home Game       Team 1 Name       Location Name  \
# 100      False  Williams College    Hamilton College
# 101      False  Williams College    Hamilton College
# 102       True  Williams College    Williams College
# 103       True  Williams College    Williams College
# 104      False  Williams College     Amherst College
# 105      False  Williams College     Amherst College
# 106       True  Williams College    Williams College
# 107      False  Williams College  Middlebury College
# 108      False  Williams College  Middlebury College
# 109      False  Williams College  Middlebury College
#
#     Team 1 Travel Distance (mi) Team 1 Travel Distance (hhmm)  \
# 100                         144                          2:33
# 101                         144                          2:33
# 102                           0                          0:00
# 103                           0                          0:00
# 104                          60                          1:26
# 105                          60                          1:26
# 106                           0                          0:00
# 107                         108                          2:09
# 108                         108                          2:09
# 109                         108                          2:09
#
#      Distance Overnight  Weekend Overnight
# 100               False              False
# 101               False              False
# 102               False              False
# 103               False              False
# 104               False              False
# 105               False               True
# 106               False              False
# 107               False              False
# 108               False               True
# 109               False              False
# ########################################
# # 3_2215_optimized_team_schedule_1.csv #
# ########################################
# /Users/hcederna/anaconda3/envs/schedule-optimization/lib/python3.7/site-packages/ipykernel_launcher.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hcederna/anaconda3/envs/schedule-optimization/lib/python3.7/site-packages/ipykernel_launcher.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hcederna/anaconda3/envs/schedule-optimization/lib/python3.7/site-packages/ipykernel_launcher.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hcederna/anaconda3/envs/schedule-optimization/lib/python3.7/site-packages/ipykernel_launcher.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hcederna/anaconda3/envs/schedule-optimization/lib/python3.7/site-packages/ipykernel_launcher.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# TEAM 0
#    overnight = 2
#    distance = 998
#    Week Day (Str)  Time Slot  Team 1               Team 2  Location  \
# 0     0      Fri.          2       0        Colby College         2
# 1     0      Sat.          7       0        Bates College         2
# 2     0      Sat.          8       0      Bowdoin College         2
# 3     1      Sat.          2       0     Tufts University         8
# 4     2      Sat.          1       0     Hamilton College         6
# 5     3      Fri.          0       0     Williams College        10
# 6     3      Sat.          1       0   Middlebury College        10
# 7     4      Fri.          2       0      Trinity College         0
# 8     4      Sat.          4       0  Connecticut College         0
# 9     4      Sat.          7       0  Wesleyan University         0
#
#    Home Game      Team 1 Name       Location Name Team 1 Travel Distance (mi)  \
# 0      False  Amherst College     Bowdoin College                         199
# 1      False  Amherst College     Bowdoin College                         199
# 2      False  Amherst College     Bowdoin College                         199
# 3      False  Amherst College    Tufts University                          87
# 4      False  Amherst College  Middlebury College                         153
# 5      False  Amherst College    Williams College                          60
# 6      False  Amherst College    Williams College                          60
# 7       True  Amherst College     Amherst College                           0
# 8       True  Amherst College     Amherst College                           0
# 9       True  Amherst College     Amherst College                           0
#
#   Team 1 Travel Distance (hhmm)  Distance Overnight  Weekend Overnight
# 0                          3:19                True              False
# 1                          3:19               False               True
# 2                          3:19               False              False
# 3                          1:45               False              False
# 4                          2:54               False              False
# 5                          1:26               False              False
# 6                          1:26               False               True
# 7                          0:00               False              False
# 8                          0:00               False              False
# 9                          0:00               False              False
# TEAM 1
#    overnight = 1
#    distance = 748
#     Week Day (Str)  Time Slot  Team 1               Team 2  Location  \
# 10     0      Fri.          1       1   Middlebury College         2
# 11     0      Sat.          6       1     Williams College         2
# 12     0      Sat.          7       1      Amherst College         2
# 13     1      Fri.          2       1      Trinity College         7
# 14     1      Sat.          4       1  Connecticut College         7
# 15     1      Sat.          8       1  Wesleyan University         7
# 16     2      Fri.          0       1      Bowdoin College         1
# 17     2      Sat.          1       1        Colby College         1
# 18     3      Sat.          1       1     Tufts University         3
# 19     4      Fri.          0       1     Hamilton College         3
#
#     Home Game    Team 1 Name    Location Name Team 1 Travel Distance (mi)  \
# 10      False  Bates College  Bowdoin College                          21
# 11      False  Bates College  Bowdoin College                          21
# 12      False  Bates College  Bowdoin College                          21
# 13      False  Bates College  Trinity College                         234
# 14      False  Bates College  Trinity College                         234
# 15      False  Bates College  Trinity College                         234
# 16       True  Bates College    Bates College                           0
# 17       True  Bates College    Bates College                           0
# 18      False  Bates College    Colby College                          49
# 19      False  Bates College    Colby College                          49
#
#    Team 1 Travel Distance (hhmm)  Distance Overnight  Weekend Overnight
# 10                          0:39               False              False
# 11                          0:39               False              False
# 12                          0:39               False              False
# 13                          3:39                True              False
# 14                          3:39               False               True
# 15                          3:39               False              False
# 16                          0:00               False              False
# 17                          0:00               False              False
# 18                          0:51               False              False
# 19                          0:51               False              False
# TEAM 2
#    overnight = 1
#    distance = 738
#     Week Day (Str)  Time Slot  Team 1               Team 2  Location  \
# 20     0      Fri.          0       2     Williams College         2
# 21     0      Sat.          4       2   Middlebury College         2
# 22     0      Sat.          8       2      Amherst College         2
# 23     1      Fri.          0       2  Connecticut College         7
# 24     1      Sat.          3       2  Wesleyan University         7
# 25     1      Sat.          7       2      Trinity College         7
# 26     2      Fri.          0       2        Bates College         1
# 27     2      Sat.          2       2        Colby College         1
# 28     3      Sat.          2       2     Tufts University         3
# 29     4      Sat.          1       2     Hamilton College         3
#
#     Home Game      Team 1 Name    Location Name Team 1 Travel Distance (mi)  \
# 20       True  Bowdoin College  Bowdoin College                           0
# 21       True  Bowdoin College  Bowdoin College                           0
# 22       True  Bowdoin College  Bowdoin College                           0
# 23      False  Bowdoin College  Trinity College                         227
# 24      False  Bowdoin College  Trinity College                         227
# 25      False  Bowdoin College  Trinity College                         227
# 26      False  Bowdoin College    Bates College                          21
# 27      False  Bowdoin College    Bates College                          21
# 28      False  Bowdoin College    Colby College                          50
# 29      False  Bowdoin College    Colby College                          50
#
#    Team 1 Travel Distance (hhmm)  Distance Overnight  Weekend Overnight
# 20                          0:00               False              False
# 21                          0:00               False              False
# 22                          0:00               False              False
# 23                          3:35                True              False
# 24                          3:35               False               True
# 25                          3:35               False              False
# 26                          0:39               False              False
# 27                          0:39               False              False
# 28                          0:52               False              False
# 29                          0:52               False              False
# TEAM 3
#    overnight = 1
#    distance = 846
#     Week Day (Str)  Time Slot  Team 1               Team 2  Location  \
# 30     0      Fri.          2       3      Amherst College         2
# 31     0      Sat.          3       3   Middlebury College         2
# 32     0      Sat.          5       3     Williams College         2
# 33     1      Fri.          1       3  Wesleyan University         7
# 34     1      Sat.          5       3  Connecticut College         7
# 35     1      Sat.          6       3      Trinity College         7
# 36     2      Sat.          1       3        Bates College         1
# 37     2      Sat.          2       3      Bowdoin College         1
# 38     3      Fri.          0       3     Tufts University         3
# 39     4      Sat.          2       3     Hamilton College         3
#
#     Home Game    Team 1 Name    Location Name Team 1 Travel Distance (mi)  \
# 30      False  Colby College  Bowdoin College                          50
# 31      False  Colby College  Bowdoin College                          50
# 32      False  Colby College  Bowdoin College                          50
# 33      False  Colby College  Trinity College                         274
# 34      False  Colby College  Trinity College                         274
# 35      False  Colby College  Trinity College                         274
# 36      False  Colby College    Bates College                          49
# 37      False  Colby College    Bates College                          49
# 38       True  Colby College    Colby College                           0
# 39       True  Colby College    Colby College                           0
#
#    Team 1 Travel Distance (hhmm)  Distance Overnight  Weekend Overnight
# 30                          0:52               False              False
# 31                          0:52               False              False
# 32                          0:52               False              False
# 33                          4:10                True              False
# 34                          4:10               False               True
# 35                          4:10               False              False
# 36                          0:51               False              False
# 37                          0:51               False              False
# 38                          0:00               False              False
# 39                          0:00               False              False
# TEAM 4
#    overnight = 1
#    distance = 566
#     Week Day (Str)  Time Slot  Team 1               Team 2  Location  \
# 40     0      Fri.          0       4  Wesleyan University         4
# 41     0      Sat.          1       4      Trinity College         4
# 42     1      Fri.          0       4      Bowdoin College         7
# 43     1      Sat.          4       4        Bates College         7
# 44     1      Sat.          5       4        Colby College         7
# 45     2      Sat.          1       4     Tufts University         9
# 46     3      Sat.          1       4     Hamilton College         9
# 47     4      Fri.          0       4     Williams College         0
# 48     4      Sat.          3       4   Middlebury College         0
# 49     4      Sat.          4       4      Amherst College         0
#
#     Home Game          Team 1 Name        Location Name  \
# 40       True  Connecticut College  Connecticut College
# 41       True  Connecticut College  Connecticut College
# 42      False  Connecticut College      Trinity College
# 43      False  Connecticut College      Trinity College
# 44      False  Connecticut College      Trinity College
# 45      False  Connecticut College  Wesleyan University
# 46      False  Connecticut College  Wesleyan University
# 47      False  Connecticut College      Amherst College
# 48      False  Connecticut College      Amherst College
# 49      False  Connecticut College      Amherst College
#
#    Team 1 Travel Distance (mi) Team 1 Travel Distance (hhmm)  \
# 40                           0                          0:00
# 41                           0                          0:00
# 42                          52                          0:52
# 43                          52                          0:52
# 44                          52                          0:52
# 45                          40                          0:39
# 46                          40                          0:39
# 47                          99                          1:40
# 48                          99                          1:40
# 49                          99                          1:40
#
#     Distance Overnight  Weekend Overnight
# 40               False              False
# 41               False              False
# 42               False              False
# 43               False              False
# 44               False              False
# 45               False              False
# 46               False              False
# 47               False              False
# 48               False               True
# 49               False              False
# TEAM 5
#    overnight = 3
#    distance = 1702
#     Week Day (Str)  Time Slot  Team 1               Team 2  Location  \
# 50     0      Sat.          0       5     Tufts University         5
# 51     2      Fri.          0       5     Williams College         6
# 52     2      Sat.          1       5      Amherst College         6
# 53     2      Sat.          2       5   Middlebury College         6
# 54     3      Fri.          0       5      Trinity College         9
# 55     3      Sat.          1       5  Connecticut College         9
# 56     3      Sat.          2       5  Wesleyan University         9
# 57     4      Fri.          0       5        Bates College         3
# 58     4      Sat.          1       5      Bowdoin College         3
# 59     4      Sat.          2       5        Colby College         3
#
#     Home Game       Team 1 Name        Location Name  \
# 50       True  Hamilton College     Hamilton College
# 51      False  Hamilton College   Middlebury College
# 52      False  Hamilton College   Middlebury College
# 53      False  Hamilton College   Middlebury College
# 54      False  Hamilton College  Wesleyan University
# 55      False  Hamilton College  Wesleyan University
# 56      False  Hamilton College  Wesleyan University
# 57      False  Hamilton College        Colby College
# 58      False  Hamilton College        Colby College
# 59      False  Hamilton College        Colby College
#
#    Team 1 Travel Distance (mi) Team 1 Travel Distance (hhmm)  \
# 50                           0                          0:00
# 51                         170                          3:29
# 52                         170                          3:29
# 53                         170                          3:29
# 54                         235                          3:39
# 55                         235                          3:39
# 56                         235                          3:39
# 57                         446                          6:45
# 58                         446                          6:45
# 59                         446                          6:45
#
#     Distance Overnight  Weekend Overnight
# 50               False              False
# 51                True              False
# 52               False               True
# 53               False              False
# 54                True              False
# 55               False               True
# 56               False              False
# 57                True              False
# 58               False               True
# 59               False              False
# TEAM 6
#    overnight = 3
#    distance = 1398
#     Week Day (Str)  Time Slot  Team 1               Team 2  Location  \
# 60     0      Fri.          1       6        Bates College         2
# 61     0      Sat.          3       6        Colby College         2
# 62     0      Sat.          4       6      Bowdoin College         2
# 63     1      Fri.          0       6     Tufts University         8
# 64     2      Sat.          2       6     Hamilton College         6
# 65     3      Sat.          1       6      Amherst College        10
# 66     3      Sat.          2       6     Williams College        10
# 67     4      Fri.          1       6  Wesleyan University         0
# 68     4      Sat.          3       6  Connecticut College         0
# 69     4      Sat.          8       6      Trinity College         0
#
#     Home Game         Team 1 Name       Location Name  \
# 60      False  Middlebury College     Bowdoin College
# 61      False  Middlebury College     Bowdoin College
# 62      False  Middlebury College     Bowdoin College
# 63      False  Middlebury College    Tufts University
# 64       True  Middlebury College  Middlebury College
# 65      False  Middlebury College    Williams College
# 66      False  Middlebury College    Williams College
# 67      False  Middlebury College     Amherst College
# 68      False  Middlebury College     Amherst College
# 69      False  Middlebury College     Amherst College
#
#    Team 1 Travel Distance (mi) Team 1 Travel Distance (hhmm)  \
# 60                         255                          4:22
# 61                         255                          4:22
# 62                         255                          4:22
# 63                         183                          3:14
# 64                           0                          0:00
# 65                         108                          2:09
# 66                         108                          2:09
# 67                         153                          2:54
# 68                         153                          2:54
# 69                         153                          2:54
#
#     Distance Overnight  Weekend Overnight
# 60                True              False
# 61               False               True
# 62               False              False
# 63                True              False
# 64               False              False
# 65               False              False
# 66               False              False
# 67               False              False
# 68               False               True
# 69               False              False
# TEAM 7
#    overnight = 0
#    distance = 380
#     Week Day (Str)  Time Slot  Team 1               Team 2  Location  \
# 70     0      Sat.          1       7  Connecticut College         4
# 71     0      Sat.          2       7  Wesleyan University         4
# 72     1      Fri.          2       7        Bates College         7
# 73     1      Sat.          6       7        Colby College         7
# 74     1      Sat.          7       7      Bowdoin College         7
# 75     2      Fri.          0       7     Tufts University         9
# 76     3      Fri.          0       7     Hamilton College         9
# 77     4      Fri.          2       7      Amherst College         0
# 78     4      Sat.          6       7     Williams College         0
# 79     4      Sat.          8       7   Middlebury College         0
#
#     Home Game      Team 1 Name        Location Name  \
# 70      False  Trinity College  Connecticut College
# 71      False  Trinity College  Connecticut College
# 72       True  Trinity College      Trinity College
# 73       True  Trinity College      Trinity College
# 74       True  Trinity College      Trinity College
# 75      False  Trinity College  Wesleyan University
# 76      False  Trinity College  Wesleyan University
# 77      False  Trinity College      Amherst College
# 78      False  Trinity College      Amherst College
# 79      False  Trinity College      Amherst College
#
#    Team 1 Travel Distance (mi) Team 1 Travel Distance (hhmm)  \
# 70                          52                          0:52
# 71                          52                          0:52
# 72                           0                          0:00
# 73                           0                          0:00
# 74                           0                          0:00
# 75                          16                          0:24
# 76                          16                          0:24
# 77                          53                          1:01
# 78                          53                          1:01
# 79                          53                          1:01
#
#     Distance Overnight  Weekend Overnight
# 70               False              False
# 71               False              False
# 72               False              False
# 73               False              False
# 74               False              False
# 75               False              False
# 76               False              False
# 77               False              False
# 78               False              False
# 79               False              False
# TEAM 8
#    overnight = 3
#    distance = 1160
#     Week Day (Str)  Time Slot  Team 1               Team 2  Location  \
# 80     0      Sat.          0       8     Hamilton College         5
# 81     1      Fri.          0       8   Middlebury College         8
# 82     1      Sat.          1       8     Williams College         8
# 83     1      Sat.          2       8      Amherst College         8
# 84     2      Fri.          0       8      Trinity College         9
# 85     2      Sat.          1       8  Connecticut College         9
# 86     2      Sat.          2       8  Wesleyan University         9
# 87     3      Fri.          0       8        Colby College         3
# 88     3      Sat.          1       8        Bates College         3
# 89     3      Sat.          2       8      Bowdoin College         3
#
#     Home Game       Team 1 Name        Location Name  \
# 80      False  Tufts University     Hamilton College
# 81       True  Tufts University     Tufts University
# 82       True  Tufts University     Tufts University
# 83       True  Tufts University     Tufts University
# 84      False  Tufts University  Wesleyan University
# 85      False  Tufts University  Wesleyan University
# 86      False  Tufts University  Wesleyan University
# 87      False  Tufts University        Colby College
# 88      False  Tufts University        Colby College
# 89      False  Tufts University        Colby College
#
#    Team 1 Travel Distance (mi) Team 1 Travel Distance (hhmm)  \
# 80                         281                          4:20
# 81                           0                          0:00
# 82                           0                          0:00
# 83                           0                          0:00
# 84                         119                          1:58
# 85                         119                          1:58
# 86                         119                          1:58
# 87                         180                          2:45
# 88                         180                          2:45
# 89                         180                          2:45
#
#     Distance Overnight  Weekend Overnight
# 80                True              False
# 81               False              False
# 82               False              False
# 83               False              False
# 84               False              False
# 85               False               True
# 86               False              False
# 87                True              False
# 88               False               True
# 89               False              False
# TEAM 9
#    overnight = 1
#    distance = 358
#     Week Day (Str)  Time Slot  Team 1               Team 2  Location  \
# 90     0      Fri.          0       9  Connecticut College         4
# 91     0      Sat.          2       9      Trinity College         4
# 92     1      Fri.          1       9        Colby College         7
# 93     1      Sat.          3       9      Bowdoin College         7
# 94     1      Sat.          8       9        Bates College         7
# 95     2      Sat.          2       9     Tufts University         9
# 96     3      Sat.          2       9     Hamilton College         9
# 97     4      Fri.          1       9   Middlebury College         0
# 98     4      Sat.          5       9     Williams College         0
# 99     4      Sat.          7       9      Amherst College         0
#
#     Home Game          Team 1 Name        Location Name  \
# 90      False  Wesleyan University  Connecticut College
# 91      False  Wesleyan University  Connecticut College
# 92      False  Wesleyan University      Trinity College
# 93      False  Wesleyan University      Trinity College
# 94      False  Wesleyan University      Trinity College
# 95       True  Wesleyan University  Wesleyan University
# 96       True  Wesleyan University  Wesleyan University
# 97      False  Wesleyan University      Amherst College
# 98      False  Wesleyan University      Amherst College
# 99      False  Wesleyan University      Amherst College
#
#    Team 1 Travel Distance (mi) Team 1 Travel Distance (hhmm)  \
# 90                          40                          0:39
# 91                          40                          0:39
# 92                          16                          0:24
# 93                          16                          0:24
# 94                          16                          0:24
# 95                           0                          0:00
# 96                           0                          0:00
# 97                          67                          1:14
# 98                          67                          1:14
# 99                          67                          1:14
#
#     Distance Overnight  Weekend Overnight
# 90               False              False
# 91               False              False
# 92               False              False
# 93               False              False
# 94               False              False
# 95               False              False
# 96               False              False
# 97               False              False
# 98               False               True
# 99               False              False
# TEAM 10
#    overnight = 2
#    distance = 1080
#      Week Day (Str)  Time Slot  Team 1               Team 2  Location  \
# 100     0      Fri.          0      10      Bowdoin College         2
# 101     0      Sat.          5      10        Colby College         2
# 102     0      Sat.          6      10        Bates College         2
# 103     1      Sat.          1      10     Tufts University         8
# 104     2      Fri.          0      10     Hamilton College         6
# 105     3      Fri.          0      10      Amherst College        10
# 106     3      Sat.          2      10   Middlebury College        10
# 107     4      Fri.          0      10  Connecticut College         0
# 108     4      Sat.          5      10  Wesleyan University         0
# 109     4      Sat.          6      10      Trinity College         0
#
#      Home Game       Team 1 Name       Location Name  \
# 100      False  Williams College     Bowdoin College
# 101      False  Williams College     Bowdoin College
# 102      False  Williams College     Bowdoin College
# 103      False  Williams College    Tufts University
# 104      False  Williams College  Middlebury College
# 105       True  Williams College    Williams College
# 106       True  Williams College    Williams College
# 107      False  Williams College     Amherst College
# 108      False  Williams College     Amherst College
# 109      False  Williams College     Amherst College
#
#     Team 1 Travel Distance (mi) Team 1 Travel Distance (hhmm)  \
# 100                         242                          4:18
# 101                         242                          4:18
# 102                         242                          4:18
# 103                         130                          2:43
# 104                         108                          2:09
# 105                           0                          0:00
# 106                           0                          0:00
# 107                          60                          1:26
# 108                          60                          1:26
# 109                          60                          1:26
#
#      Distance Overnight  Weekend Overnight
# 100                True              False
# 101               False               True
# 102               False              False
# 103               False              False
# 104               False              False
# 105               False              False
# 106               False              False
# 107               False              False
# 108               False               True
# 109               False              False

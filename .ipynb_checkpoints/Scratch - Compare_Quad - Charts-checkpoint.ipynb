# %% [markdown]
# # Compare Optimized & Previous NESCAC Volleyball Conference Schedule Quads - Chart Creation
#
# Let's compare the optimized schedule quads with the previous NESCAC schedule quads to see how we did.

# %%
from src.configuration import *
from src.analyze_schedule import *

print("Loading necessary information ...\n")
best_quad_optimized_schedule_analysis_df = pd.read_pickle(BEST_QUAD_OPTIMIZED_SCHEDULE_ANALYSIS_FILENAME)
quad_nescac_schedule_analysis_df = pd.read_pickle(QUAD_NESCAC_SCHEDULE_ANALYSIS_FILENAME)

print("Creating quad schedule comparison DataFrame ...\n")
quad_schedule_comparison_df = best_quad_optimized_schedule_analysis_df.append(quad_nescac_schedule_analysis_df)
quad_schedule_comparison_df = create_score_columns(
    analysis_df=quad_schedule_comparison_df, 
    score_total_cost_weight=SCHEDULE_SCORE_TOTAL_COST_WEIGHT)
quad_schedule_comparison_df = create_optimized_change_columns(quad_schedule_comparison_df)
quad_schedule_comparison_df = quad_schedule_comparison_df.sort_values('Pair/Quad Score', ascending=True).reset_index(drop=True)

print("Saving quad schedule comparison to pickle ...")
quad_schedule_comparison_df.to_pickle(QUAD_SCHEDULE_COMPARISON_FILENAME)
print("... Saved as \"{}\"".format(QUAD_SCHEDULE_COMPARISON_FILENAME))

print("Preview:")
display(quad_schedule_comparison_df.head())
print()
# Out:
# Loading necessary information ...
#
# Creating quad schedule comparison DataFrame ...
#
# Saving quad schedule comparison to pickle ...
# ... Saved as "results/quad/quad_schedule_comparison.pickle"
# Preview:
#    (Average) Schedule Score  (Average) Team Experience Score  \
# 0                 23.598674                        35.335375
# 1                 27.017297                        38.136124
# 2                 27.289526                        38.345035
# 3                 25.728041                        39.390383
# 4                 28.317811                        30.982269
#
#   (Average) Team Home Game (Min, Max, Rng)  \
# 0                          (1.0, 3.0, 2.0)
# 1                          (1.5, 3.0, 1.5)
# 2                          (1.5, 3.0, 1.5)
# 3                        (1.25, 3.0, 1.75)
# 4                        (1.75, 3.0, 1.25)
#
#    (Average) Team Home Game Fairness Index  (Average) Team Home Game Score  \
# ...

# %%
from src.configuration import *
from src.figures import *


# Select two optimized schedule quads to compare to the previous NESCAC schedule quads
selected_idxs = [1, 4]

columns = [
    'Abbreviated Schedule ID',
#     'Schedule ID 0',
#     'Schedule ID 1',
#     'Schedule Indexes',
    'Pair/Quad Score',
    '(Sum) Total Cost',
    'Location Score',
    '(Average) Schedule Score',
    '(Average) Team Experience Score',
    'Team Different Location Average',
    'Team Different Location Fairness Index',
    'Team Different Location Score',
    'Team Unique Location Average',
    'Team Unique Location Fairness Index',
    'Team Unique Location Score',
#     '(Average) Team Experience Score',
    '(Average) Team Home Game (Min, Max, Rng)',
    '(Average) Team Home Game Fairness Index',
#     '(Average) Team Home Game Score',
    '(Average) Team Duration in Hours Average',
    '(Average) Team Duration in Hours Fairness Index',
#     '(Average) Team Duration in Hours Score',
    '(Average) Team Overnight Average',
    '(Average) Team Overnight Fairness Index',
#     '(Average) Team Overnight Score',
    '(Average) Test Success',
#     '(Sum) Total Distance',
    '(Sum) Total Duration in Hours',        
    '(Sum) Total Overnight', 
#     '(Sum) Total Distance Cost',
#     '(Sum) Total Overnight Cost',
]


print("Loading necessary information ...\n")
quad_schedule_comparison_df = pd.read_pickle(QUAD_SCHEDULE_COMPARISON_FILENAME)

# Comment/uncomment to see full DF or just selected indexes
quad_schedule_comparison_df = quad_schedule_comparison_df.iloc[selected_idxs][columns].append(quad_schedule_comparison_df[15:23][columns])

print("Applying color gradient to schedule analysis DataFrame ...\n")
color_gradient_df = apply_color_gradient(quad_schedule_comparison_df, columns)

print("Displaying schedule analysis DataFrame ...")
display(color_gradient_df)
# Out:
# Loading necessary information ...
#
# Applying color gradient to schedule analysis DataFrame ...
#
# Displaying schedule analysis DataFrame ...
# <style  type="text/css" >
#     #T_e93395e2_67d5_11ea_b1a4_8c2937e6cdeerow0_col1 {
#             background-color:  #2e8b57;
#             color:  #000000;
#         }    #T_e93395e2_67d5_11ea_b1a4_8c2937e6cdeerow0_col2 {
#             background-color:  #2e8b57;
#             color:  #000000;
#         }    #T_e93395e2_67d5_11ea_b1a4_8c2937e6cdeerow0_col3 {
#             background-color:  #d8ede1;
#             color:  #000000;
#         }    #T_e93395e2_67d5_11ea_b1a4_8c2937e6cdeerow0_col4 {
#             background-color:  #2e8b57;
#             color:  #000000;
#         }    #T_e93395e2_67d5_11ea_b1a4_8c2937e6cdeerow0_col5 {
#             background-color:  #8dc2a4;
#             color:  #000000;
#         }    #T_e93395e2_67d5_11ea_b1a4_8c2937e6cdeerow0_col6 {
#             background-color:  #d2eadc;
#             color:  #000000;
# ...

# %% [markdown]
# ## Chart Creation for Schedule Quads Comparison
#
# Let's see how our best optimized schedule quads compare with the previous NESCAC schedule quads in the following categories:
#
# - Total cost
# - Team home games
# - Team travel duration
# - Team overnights
# - Team different locations
# - Team unique locations
#
# We use the following patterns and colors to highlight schedule quads in the charts below:
#
# > <div style="float:left"><img src="hard_data/best_schedule.png"></div> $\quad$ indicates the previous NESCAC volleyball conference schedule pair with the best quad score
#
# > <div style="float:left"><img src="hard_data/best_result.png"></div> $\quad$ highlights the schedule quad with the best result in the charted category
#
# > <div style="float:left"><img src="hard_data/worst_result.png"></div> $\quad$ highlights the schedule quad with the worst result in the charted category
#
# ## Totals
#
# ### Total Cost

# %%
from src.configuration import *
from src.figures import *
# %matplotlib inline


print("Loading necessary information ...\n")
quad_schedule_comparison_df = pd.read_pickle(QUAD_SCHEDULE_COMPARISON_FILENAME)
quad_schedule_comparison_df = quad_schedule_comparison_df.iloc[selected_idxs][columns].append(quad_schedule_comparison_df[15:23]).reset_index(drop=True)

# shorten nescac quad abbreviated schedule IDs
quad_schedule_comparison_df['Abbreviated Schedule ID'][2:] = quad_schedule_comparison_df['Abbreviated Schedule ID'][2:].map(lambda x: x[2:])

print("Creating quad schedule total cost comparison bar chart ...")
plot_filename = plot_and_save_horizontal_bar_chart_min_max_mean(
    analysis_df=quad_schedule_comparison_df,
    column_name="(Sum) Total Cost",
    min_preferred=True,
    fig_title="Total cost ($) comparison.",
    nescac_mean_line=False,
    plot_path=QUAD_RESULTS_PLOT_PATH)

print("Saving quad schedule total cost comparison bar chart ...")
print("... Saved as \"{}\"\n".format(plot_filename))

print("Process complete.\n")
# Out:
# Loading necessary information ...
#
# Creating quad schedule total cost comparison bar chart ...
# /Users/hcederna/anaconda3/envs/schedule-optimization/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# Saving quad schedule total cost comparison bar chart ...
# ... Saved as "results/quad/figures/total_cost_($)_comparison.png"
#
# Process complete.

# %%
from src.configuration import *
from src.figures import *
# %matplotlib inline


print("Loading necessary information ...\n")
quad_schedule_comparison_df = pd.read_pickle(QUAD_SCHEDULE_COMPARISON_FILENAME)
quad_schedule_comparison_df = quad_schedule_comparison_df.iloc[selected_idxs][columns].append(quad_schedule_comparison_df[15:23]).reset_index(drop=True)
sched_id_0 = quad_schedule_comparison_df.loc[0]['Abbreviated Schedule ID']
sched_id_1 = quad_schedule_comparison_df.loc[1]['Abbreviated Schedule ID']

print("Creating quad schedule total cost change comparison bar chart ...")
plot_filename = plot_and_save_horizontal_bar_charts_min_max_mean(
    analysis_df=quad_schedule_comparison_df,
    column_names=("{} Total Cost Change".format(sched_id_0), "{} Total Cost Change".format(sched_id_1)),
    min_preferred_tuple=(True, True),
    fig_title="Total cost ($) change.",
    subplot_titles=("{}".format(sched_id_0), "{}".format(sched_id_1)),
    nescac_mean_line=True,
    optimized_schedule_lines=False,
    plot_path=QUAD_RESULTS_PLOT_PATH)

print("Saving quad schedule total cost change comparison bar chart ...")
print("... Saved as \"{}\"\n".format(plot_filename))

print("Process complete.\n")
# Out:
# Loading necessary information ...
#
# Creating quad schedule total cost change comparison bar chart ...
# Saving quad schedule total cost change comparison bar chart ...
# ... Saved as "results/quad/figures/total_cost_($)_change.png"
#
# Process complete.

# %%
from src.configuration import *
from src.figures import *
# %matplotlib inline


print("Loading necessary information ...\n")
quad_schedule_comparison_df = pd.read_pickle(QUAD_SCHEDULE_COMPARISON_FILENAME)
quad_schedule_comparison_df = quad_schedule_comparison_df.iloc[selected_idxs][columns].append(quad_schedule_comparison_df[15:23]).reset_index(drop=True)
sched_id_0 = quad_schedule_comparison_df.loc[0]['Abbreviated Schedule ID']
sched_id_1 = quad_schedule_comparison_df.loc[1]['Abbreviated Schedule ID']

print("Creating quad schedule total cost percent change comparison bar chart ...")
plot_filename = plot_and_save_horizontal_bar_charts_min_max_mean(
    analysis_df=quad_schedule_comparison_df,
    column_names=("{} Total Cost Percent Change".format(sched_id_0), "{} Total Cost Percent Change".format(sched_id_1)),
    min_preferred_tuple=(True, True),
    fig_title="Total cost percent change.",
    subplot_titles=("{}".format(sched_id_0), "{}".format(sched_id_1)),
    nescac_mean_line=True,
    optimized_schedule_lines=False,
    plot_path=QUAD_RESULTS_PLOT_PATH)

print("Saving quad schedule total cost percent change comparison bar chart ...")
print("... Saved as \"{}\"\n".format(plot_filename))

print("Process complete.\n")
# Out:
# Loading necessary information ...
#
# Creating quad schedule total cost percent change comparison bar chart ...
# Saving quad schedule total cost percent change comparison bar chart ...
# ... Saved as "results/quad/figures/total_cost_percent_change.png"
#
# Process complete.

# %% [markdown]
# ### Total Travel Duration

# %%
from src.configuration import *
from src.figures import *
# %matplotlib inline


print("Loading necessary information ...\n")
quad_schedule_comparison_df = pd.read_pickle(QUAD_SCHEDULE_COMPARISON_FILENAME)
quad_schedule_comparison_df = quad_schedule_comparison_df.iloc[selected_idxs][columns].append(quad_schedule_comparison_df[15:23]).reset_index(drop=True)

# shorten nescac quad abbreviated schedule IDs
quad_schedule_comparison_df['Abbreviated Schedule ID'][2:] = quad_schedule_comparison_df['Abbreviated Schedule ID'][2:].map(lambda x: x[2:])

print("Creating quad schedule total travel duration comparison bar chart ...")
plot_filename = plot_and_save_horizontal_bar_chart_min_max_mean(
    analysis_df=quad_schedule_comparison_df,
    column_name="(Sum) Total Duration in Hours",
    min_preferred=True,
    fig_title="Total travel duration in hours comparison.",
    nescac_mean_line=False,
    plot_path=QUAD_RESULTS_PLOT_PATH)

print("Saving quad schedule total travel duration comparison bar chart ...")
print("... Saved as \"{}\"\n".format(plot_filename))

print("Process complete.\n")
# Out:
# Loading necessary information ...
#
# Creating quad schedule total travel duration comparison bar chart ...
# /Users/hcederna/anaconda3/envs/schedule-optimization/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# Saving quad schedule total travel duration comparison bar chart ...
# ... Saved as "results/quad/figures/total_travel_duration_in_hours_comparison.png"
#
# Process complete.

# %%
# from src.configuration import *
# from src.figures import *
# %matplotlib inline


# print("Loading necessary information ...\n")
# quad_schedule_comparison_df = pd.read_pickle(QUAD_SCHEDULE_COMPARISON_FILENAME)
# quad_schedule_comparison_df = quad_schedule_comparison_df.iloc[selected_idxs][columns].append(quad_schedule_comparison_df[15:23]).reset_index(drop=True)
# sched_id_0 = quad_schedule_comparison_df.loc[0]['Abbreviated Schedule ID']
# sched_id_1 = quad_schedule_comparison_df.loc[1]['Abbreviated Schedule ID']

# # print("Creating quad schedule total travel duration percent change comparison bar chart ...")
# plot_filename = plot_and_save_horizontal_bar_charts_min_max_mean(
#     analysis_df=quad_schedule_comparison_df,
#     column_names=("{} Total Duration in Hours Percent Change".format(sched_id_0), "{} Total Duration in Hours Percent Change".format(sched_id_1)),
#     min_preferred_tuple=(True, True),
#     fig_title="Total travel duration in hours percent change.",
#     subplot_titles=("{}".format(sched_id_0), "{}".format(sched_id_1)),
#     nescac_mean_line=True,
#     optimized_schedule_lines=False,
#     plot_path=QUAD_RESULTS_PLOT_PATH)

# print("Saving quad schedule total travel duration percent change comparison bar chart ...")
# print("... Saved as \"{}\"\n".format(plot_filename))

# print("Process complete.\n")
# Out:
# Loading necessary information ...
# Saving quad schedule total travel duration percent change comparison bar chart ...
# ... Saved as "results/quad/figures/total_travel_duration_in_hours_percent_change.png"
#
# Process complete.

# %%
from src.configuration import *
from src.figures import *
# %matplotlib inline


print("Loading necessary information ...\n")
quad_schedule_comparison_df = pd.read_pickle(QUAD_SCHEDULE_COMPARISON_FILENAME)
quad_schedule_comparison_df = quad_schedule_comparison_df.iloc[selected_idxs][columns].append(quad_schedule_comparison_df[15:23]).reset_index(drop=True)
sched_id_0 = quad_schedule_comparison_df.loc[0]['Abbreviated Schedule ID']
sched_id_1 = quad_schedule_comparison_df.loc[1]['Abbreviated Schedule ID']

print("Creating quad schedule total travel duration change comparison bar chart ...")
plot_filename = plot_and_save_horizontal_bar_charts_min_max_mean(
    analysis_df=quad_schedule_comparison_df,
    column_names=("{} Total Duration in Hours Change".format(sched_id_0), "{} Total Duration in Hours Change".format(sched_id_1)),
    min_preferred_tuple=(True, True),
    fig_title="Total travel duration in hours change.",
    subplot_titles=("{}".format(sched_id_0), "{}".format(sched_id_1)),
    nescac_mean_line=True,
    optimized_schedule_lines=False,
    plot_path=QUAD_RESULTS_PLOT_PATH)

print("Saving quad schedule total travel duration change comparison bar chart ...")
print("... Saved as \"{}\"\n".format(plot_filename))

print("Process complete.\n")
# Out:
# Loading necessary information ...
#
# Creating quad schedule total travel duration change comparison bar chart ...
# Saving quad schedule total travel duration change comparison bar chart ...
# ... Saved as "results/quad/figures/total_travel_duration_in_hours_change.png"
#
# Process complete.

# %%
# Assume 14 players/team ==> how many hours saved
int(14*208)
# Out:
# 2912

# %%
# Assume 2 coaching staff/team ==> how many hours saved
int(2*208)
# Out:
# 416

# %% [markdown]
# ### Total Overnights

# %%
from src.configuration import *
from src.figures import *
# %matplotlib inline


print("Loading necessary information ...\n")
quad_schedule_comparison_df = pd.read_pickle(QUAD_SCHEDULE_COMPARISON_FILENAME)
quad_schedule_comparison_df = quad_schedule_comparison_df.iloc[selected_idxs][columns].append(quad_schedule_comparison_df[15:23]).reset_index(drop=True)

# shorten nescac quad abbreviated schedule IDs
quad_schedule_comparison_df['Abbreviated Schedule ID'][2:] = quad_schedule_comparison_df['Abbreviated Schedule ID'][2:].map(lambda x: x[2:])

print("Creating quad schedule total overnights comparison bar chart ...")
plot_filename = plot_and_save_horizontal_bar_chart_min_max_mean(
    analysis_df=quad_schedule_comparison_df,
    column_name="(Sum) Total Overnight",
    min_preferred=True,
    fig_title="Total overnights comparison.",
    nescac_mean_line=False,
    plot_path=QUAD_RESULTS_PLOT_PATH)

print("Saving quad schedule total overnights comparison bar chart ...")
print("... Saved as \"{}\"\n".format(plot_filename))

print("Process complete.\n")
# Out:
# Loading necessary information ...
#
# Creating quad schedule total overnights comparison bar chart ...
# /Users/hcederna/anaconda3/envs/schedule-optimization/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# Saving quad schedule total overnights comparison bar chart ...
# ... Saved as "results/quad/figures/total_overnights_comparison.png"
#
# Process complete.

# %%
# from src.configuration import *
# from src.figures import *
# %matplotlib inline


# print("Loading necessary information ...\n")
# quad_schedule_comparison_df = pd.read_pickle(QUAD_SCHEDULE_COMPARISON_FILENAME)
# quad_schedule_comparison_df = quad_schedule_comparison_df.iloc[selected_idxs][columns].append(quad_schedule_comparison_df[15:23]).reset_index(drop=True)
# sched_id_0 = quad_schedule_comparison_df.loc[0]['Abbreviated Schedule ID']
# sched_id_1 = quad_schedule_comparison_df.loc[1]['Abbreviated Schedule ID']

# print("Creating quad schedule total overnights percent change comparison bar chart ...")
# plot_filename = plot_and_save_horizontal_bar_charts_min_max_mean(
#     analysis_df=quad_schedule_comparison_df,
#     column_names=("{} Total Overnight Percent Change".format(sched_id_0), "{} Total Overnight Percent Change".format(sched_id_1)),
#     min_preferred_tuple=(True, True),
#     fig_title="Total overnights percent change.",
#     subplot_titles=("{}".format(sched_id_0), "{}".format(sched_id_1)),
#     nescac_mean_line=True,
#     optimized_schedule_lines=False,
#     plot_path=QUAD_RESULTS_PLOT_PATH)

# print("Saving quad schedule total overnights percent change comparison bar chart ...")
# print("... Saved as \"{}\"\n".format(plot_filename))

# print("Process complete.\n")
# Out:
# Loading necessary information ...
#
# Creating quad schedule total overnights percent change comparison bar chart ...
# Saving quad schedule total overnights percent change comparison bar chart ...
# ... Saved as "results/quad/figures/total_overnights_percent_change.png"
#
# Process complete.

# %%
from src.configuration import *
from src.figures import *
# %matplotlib inline


print("Loading necessary information ...\n")
quad_schedule_comparison_df = pd.read_pickle(QUAD_SCHEDULE_COMPARISON_FILENAME)
quad_schedule_comparison_df = quad_schedule_comparison_df.iloc[selected_idxs][columns].append(quad_schedule_comparison_df[15:23]).reset_index(drop=True)
sched_id_0 = quad_schedule_comparison_df.loc[0]['Abbreviated Schedule ID']
sched_id_1 = quad_schedule_comparison_df.loc[1]['Abbreviated Schedule ID']

print("Creating quad schedule total overnights change comparison bar chart ...")
plot_filename = plot_and_save_horizontal_bar_charts_min_max_mean(
    analysis_df=quad_schedule_comparison_df,
    column_names=("{} Total Overnight Change".format(sched_id_0), "{} Total Overnight Change".format(sched_id_1)),
    min_preferred_tuple=(True, True),
    fig_title="Total overnights change.",
    subplot_titles=("{}".format(sched_id_0), "{}".format(sched_id_1)),
    nescac_mean_line=True,
    optimized_schedule_lines=False,
    plot_path=QUAD_RESULTS_PLOT_PATH)

print("Saving quad schedule total overnights change comparison bar chart ...")
print("... Saved as \"{}\"\n".format(plot_filename))

print("Process complete.\n")
# Out:
# Loading necessary information ...
#
# Creating quad schedule total overnights change comparison bar chart ...
# Saving quad schedule total overnights change comparison bar chart ...
# ... Saved as "results/quad/figures/total_overnights_change.png"
#
# Process complete.

# %%
# Assume 14 players/team + 2 coaching staff/team ==> how many overnights saved
int(16*26)
# Out:
# 416

# %% [markdown]
# ## Team Experience

# %% [markdown]
# ### Team Home Games

# %%
from src.configuration import *
from src.figures import *
# %matplotlib inline


print("Loading necessary information ...\n")
quad_schedule_comparison_df = pd.read_pickle(QUAD_SCHEDULE_COMPARISON_FILENAME)
quad_schedule_comparison_df = quad_schedule_comparison_df.iloc[selected_idxs][columns].append(quad_schedule_comparison_df[15:23]).reset_index(drop=True)

print("Creating team home game comparison bar chart ...")
# Create team home game minimum column
quad_schedule_comparison_df['(Average) Team Home Game Minimum'] = quad_schedule_comparison_df['(Average) Team Home Game (Min, Max, Rng)'].apply(lambda x: x[0])
plot_filename = plot_and_save_horizontal_bar_charts_min_max_mean(
    analysis_df=quad_schedule_comparison_df,
    column_names=("(Average) Team Home Game Minimum", "(Average) Team Home Game Fairness Index"),
    min_preferred_tuple=(None, False),
    fig_title="Average team home game comparison.",
    subplot_titles=("Minimum Values", "Fairness Index"), 
    nescac_mean_line=False,
    optimized_schedule_lines=True,
    plot_path=QUAD_RESULTS_PLOT_PATH)


print("Saving team home game minimum and fairness index bar chart ...")
print("... Saved as \"{}\"\n".format(plot_filename))

print("Process complete.\n")
# Out:
# Loading necessary information ...
#
# Creating team home game comparison bar chart ...
# Saving team home game minimum and fairness index bar chart ...
# ... Saved as "results/quad/figures/average_team_home_game_comparison.png"
#
# Process complete.

# %% [markdown]
# ### Closer look @ team home games --> number values

# %%
# Closer look at team home game (min, max, rng) values for optimized
# schedules in optimized quad
columns = [
    'Abbreviated Schedule ID',
    'Schedule ID 0',
    'Schedule ID 1',
    'Schedule ID 2',
    'Schedule ID 3',
]

print("Loading necessary information ...\n")
optimized_schedule_analysis_df = pd.read_pickle(OPTIMIZED_SCHEDULE_ANALYSIS_FILENAME)
quad_schedule_comparison_df = pd.read_pickle(QUAD_SCHEDULE_COMPARISON_FILENAME)

# extract relevant optimized quads
_ = quad_schedule_comparison_df.iloc[selected_idxs][columns]
display(_)

# schedule ID columns
sched_ids = [col for col in _.columns if "Abbreviated" not in col]

# iterate over optimized quads
for idx, row in _.iterrows():
    
    print(row['Abbreviated Schedule ID'])
    print()
    
    for sched_id in sched_ids:
        print(row[sched_id])
        print('\t', optimized_schedule_analysis_df[optimized_schedule_analysis_df['Schedule ID'] == row[sched_id]]['Team Home Game (Min, Max, Rng)'].item())

    print()
# Out:
# Loading necessary information ...
#   Abbreviated Schedule ID                      Schedule ID 0  \
# 1                q6_1.5_3   3_2215_optimized_team_schedule_0
# 4              q11_1.75_3  15_2335_optimized_team_schedule_0
#
#                       Schedule ID 1                     Schedule ID 2  \
# 1  8_2315_optimized_team_schedule_0  5_2235_optimized_team_schedule_1
# 4  5_2235_optimized_team_schedule_0  5_2235_optimized_team_schedule_1
#
#                        Schedule ID 3
# 1  14_2234_optimized_team_schedule_0
# 4  14_2234_optimized_team_schedule_0
# q6_1.5_3
#
# 3_2215_optimized_team_schedule_0
# 	 (1, 3, 2)
# 8_2315_optimized_team_schedule_0
# 	 (1, 3, 2)
# 5_2235_optimized_team_schedule_1
# 	 (2, 3, 1)
# 14_2234_optimized_team_schedule_0
# 	 (2, 3, 1)
#
# q11_1.75_3
#
# 15_2335_optimized_team_schedule_0
# 	 (1, 3, 2)
# 5_2235_optimized_team_schedule_0
# 	 (2, 3, 1)
# 5_2235_optimized_team_schedule_1
# 	 (2, 3, 1)
# 14_2234_optimized_team_schedule_0
# 	 (2, 3, 1)

# %% [markdown]
# ### Team Travel Duration

# %%
from src.configuration import *
from src.figures import *
# %matplotlib inline


print("Loading necessary information ...\n")
quad_schedule_comparison_df = pd.read_pickle(QUAD_SCHEDULE_COMPARISON_FILENAME)
quad_schedule_comparison_df = quad_schedule_comparison_df.iloc[selected_idxs].append(quad_schedule_comparison_df[15:23]).reset_index(drop=True)

print("Creating team duration in hours comparison bar chart ...")
plot_filename = plot_and_save_horizontal_bar_charts_min_max_mean(
    analysis_df=quad_schedule_comparison_df,
    column_names=("(Average) Team Duration in Hours Average", "(Average) Team Duration in Hours Fairness Index"),
    min_preferred_tuple=(True, False),
    fig_title="Average team duration in hours comparison.",
    subplot_titles=("Average Values", "Fairness Index"),
    nescac_mean_line=False,
    optimized_schedule_lines=True,    
    plot_path=QUAD_RESULTS_PLOT_PATH)

print("Saving team duration in hours hours comparison bar chart ...")
print("... Saved as \"{}\"\n".format(plot_filename))

print("Process complete.\n")
# Out:
# Loading necessary information ...
#
# Creating team duration in hours comparison bar chart ...
# Saving team duration in hours hours comparison bar chart ...
# ... Saved as "results/quad/figures/average_team_duration_in_hours_comparison.png"
#
# Process complete.

# %% [markdown]
# ### Team Overnights

# %%
from src.configuration import *
from src.figures import *
# %matplotlib inline


print("Loading necessary information ...\n")
quad_schedule_comparison_df = pd.read_pickle(QUAD_SCHEDULE_COMPARISON_FILENAME)
quad_schedule_comparison_df = quad_schedule_comparison_df.iloc[selected_idxs].append(quad_schedule_comparison_df[15:23]).reset_index(drop=True)

print("Creating team overnight comparison bar chart ...")
plot_filename = plot_and_save_horizontal_bar_charts_min_max_mean(
    analysis_df=quad_schedule_comparison_df,
    column_names=("(Average) Team Overnight Average", "(Average) Team Overnight Fairness Index"),
    min_preferred_tuple=(True, False),
    fig_title="Average team overnight comparison.",
    subplot_titles=("Average Values", "Fairness Index"),   
    nescac_mean_line=False,
    optimized_schedule_lines=True,    
    plot_path=QUAD_RESULTS_PLOT_PATH)

print("Saving team overnight average and fairness index bar chart ...")
print("... Saved as \"{}\"\n".format(plot_filename))

print("Process complete.\n")
# Out:
# Loading necessary information ...
#
# Creating team overnight comparison bar chart ...
# Saving team overnight average and fairness index bar chart ...
# ... Saved as "results/quad/figures/average_team_overnight_comparison.png"
#
# Process complete.

# %% [markdown]
# ### Closer look @ team overnights --> distribution

# %%
quad_schedule_comparison_df[quad_schedule_comparison_df['Abbreviated Schedule ID'] == '2009_10_11_12'][columns]
# Out:
#   Abbreviated Schedule ID              Schedule ID 0  \
# 3           2009_10_11_12  2009_nescac_team_schedule
#
#                Schedule ID 1              Schedule ID 2  \
# 3  2010_nescac_team_schedule  2011_nescac_team_schedule
#
#                Schedule ID 3
# 3  2012_nescac_team_schedule

# %%
# Closer look at team overnight dict values for optimized
# schedules in optimized quad + worst performing in nescac quad
# based on overnight fairness
columns = [
    'Abbreviated Schedule ID',
    'Schedule ID 0',
    'Schedule ID 1',
    'Schedule ID 2',
    'Schedule ID 3',
]

# load necessary info
optimized_schedule_analysis_df = pd.read_pickle(OPTIMIZED_SCHEDULE_ANALYSIS_FILENAME)
nescac_schedule_analysis_df = pd.read_pickle(NESCAC_SCHEDULE_ANALYSIS_FILENAME)
quad_schedule_comparison_df = pd.read_pickle(QUAD_SCHEDULE_COMPARISON_FILENAME)

# extract relevant optimized quads + nescac quad to compare to
_ = quad_schedule_comparison_df.iloc[selected_idxs][columns].append(quad_schedule_comparison_df[quad_schedule_comparison_df['Abbreviated Schedule ID'] == '2009_10_11_12'][columns])
# display(_)

# schedule ID columns
sched_id_cols = [col for col in _.columns if "Abbreviated" not in col]


# create data dict to hold scheds info + team overnight values
data = {
    'Abbreviated Schedule ID': [],
    'Schedule # in Quad': [],
    'Schedule ID': [],
    'Team Overnight Dict': [],

}
# iterate over optimized quads
for idx, row in _.iterrows():
    
    abb_sched_id = row['Abbreviated Schedule ID']
    
    for sched_id_col in sched_id_cols:
                
        data['Schedule ID'].append(row[sched_id_col])
        data['Schedule # in Quad'].append(sched_id_col[-1])
        if "nescac" in row[sched_id_col]:
            team_overnight_dict = nescac_schedule_analysis_df[nescac_schedule_analysis_df['Schedule ID'] == row[sched_id_col]]['Team Overnight Dict'].item()
            data['Abbreviated Schedule ID'].append(row[sched_id_col][2:8])
        else:
            team_overnight_dict = optimized_schedule_analysis_df[optimized_schedule_analysis_df['Schedule ID'] == row[sched_id_col]]['Team Overnight Dict'].item()
            data['Abbreviated Schedule ID'].append(abb_sched_id[:3] + "_sch_" + sched_id_col[-1])

            
        data['Team Overnight Dict'].append(team_overnight_dict)

team_overnight_df = pd.DataFrame(data)
display(team_overnight_df)
# Out:
#    Abbreviated Schedule ID Schedule # in Quad  \
# 0                q6__sch_0                  0
# 1                q6__sch_1                  1
# 2                q6__sch_2                  2
# 3                q6__sch_3                  3
# 4                q11_sch_0                  0
# 5                q11_sch_1                  1
# 6                q11_sch_2                  2
# 7                q11_sch_3                  3
# 8                   09_nes                  0
# 9                   10_nes                  1
# 10                  11_nes                  2
# 11                  12_nes                  3
#
#                           Schedule ID  \
# 0    3_2215_optimized_team_schedule_0
# 1    8_2315_optimized_team_schedule_0
# 2    5_2235_optimized_team_schedule_1
# 3   14_2234_optimized_team_schedule_0
# 4   15_2335_optimized_team_schedule_0
# 5    5_2235_optimized_team_schedule_0
# 6    5_2235_optimized_team_schedule_1
# 7   14_2234_optimized_team_schedule_0
# ...

# %%
from src.configuration import *
from src.figures import *
# %matplotlib inline


print("Loading necessary information ...\n")
_ = team_overnight_df.iloc[0:4].append(team_overnight_df.iloc[8:12]).reset_index(drop=True)

display(_[[
    'Abbreviated Schedule ID',
    'Team Overnight Dict'
]])

print("Creating team overnight swarplot ...")
plot_filename = plot_and_save_dict_column_team_swarmplot_chart(
    analysis_df=_,
    dict_column_name="Team Overnight Dict",
    fig_title="Number of overnights per team - 2009-12 vs. q6_1.5_3",
    venues_mapping_filename=VENUES_MAPPING_FILENAME, 
    plot_path=QUAD_RESULTS_PLOT_PATH+'q6_')

print("Saving team overnight swarmplot ...")
print("... Saved as \"{}\"\n".format(plot_filename))

print("Process complete.\n")
# Out:
# Loading necessary information ...
#   Abbreviated Schedule ID                                Team Overnight Dict
# 0               q6__sch_0  {0: 1, 1: 1, 2: 1, 3: 1, 4: 1, 5: 3, 6: 3, 7: ...
# 1               q6__sch_1  {0: 0, 1: 2, 2: 2, 3: 2, 4: 2, 5: 2, 6: 2, 7: ...
# 2               q6__sch_2  {0: 2, 1: 1, 2: 1, 3: 1, 4: 2, 5: 3, 6: 4, 7: ...
# 3               q6__sch_3  {0: 2, 1: 0, 2: 1, 3: 1, 4: 2, 5: 3, 6: 3, 7: ...
# 4                  09_nes  {0: 2, 1: 2, 2: 3, 3: 2, 4: 1, 5: 3, 6: 2, 7: ...
# 5                  10_nes  {0: 3, 1: 2, 2: 3, 3: 2, 4: 0, 5: 3, 6: 3, 7: ...
# 6                  11_nes  {0: 3, 1: 1, 2: 1, 3: 1, 4: 2, 5: 3, 6: 4, 7: ...
# 7                  12_nes  {0: 3, 1: 2, 2: 1, 3: 2, 4: 1, 5: 3, 6: 3, 7: ...
# Creating team overnight swarplot ...
# Saving team overnight swarmplot ...
# ... Saved as "results/quad/figures/q6_team_overnight_swarmplot.png"
#
# Process complete.

# %%
from src.configuration import *
from src.figures import *
# %matplotlib inline


print("Loading necessary information ...\n")
_ = team_overnight_df.iloc[4:12].reset_index(drop=True)

display(_[[
    'Abbreviated Schedule ID',
    'Team Overnight Dict'
]])

print("Creating team overnight swarplot ...")
plot_filename = plot_and_save_dict_column_team_swarmplot_chart(
    analysis_df=_,
    dict_column_name="Team Overnight Dict",
    fig_title="Number of overnights per team - 2009-12 vs. q11_1.75_3",
    venues_mapping_filename=VENUES_MAPPING_FILENAME, 
    plot_path=QUAD_RESULTS_PLOT_PATH+'q11_')

print("Saving team overnight swarmplot ...")
print("... Saved as \"{}\"\n".format(plot_filename))

print("Process complete.\n")
# Out:
# Loading necessary information ...
#   Abbreviated Schedule ID                                Team Overnight Dict
# 0               q11_sch_0  {0: 1, 1: 2, 2: 2, 3: 2, 4: 1, 5: 2, 6: 2, 7: ...
# 1               q11_sch_1  {0: 2, 1: 1, 2: 1, 3: 1, 4: 1, 5: 3, 6: 4, 7: ...
# 2               q11_sch_2  {0: 2, 1: 1, 2: 1, 3: 1, 4: 2, 5: 3, 6: 4, 7: ...
# 3               q11_sch_3  {0: 2, 1: 0, 2: 1, 3: 1, 4: 2, 5: 3, 6: 3, 7: ...
# 4                  09_nes  {0: 2, 1: 2, 2: 3, 3: 2, 4: 1, 5: 3, 6: 2, 7: ...
# 5                  10_nes  {0: 3, 1: 2, 2: 3, 3: 2, 4: 0, 5: 3, 6: 3, 7: ...
# 6                  11_nes  {0: 3, 1: 1, 2: 1, 3: 1, 4: 2, 5: 3, 6: 4, 7: ...
# 7                  12_nes  {0: 3, 1: 2, 2: 1, 3: 2, 4: 1, 5: 3, 6: 3, 7: ...
# Creating team overnight swarplot ...
# Saving team overnight swarmplot ...
# ... Saved as "results/quad/figures/q11_team_overnight_swarmplot.png"
#
# Process complete.

# %% [markdown]
# ### Team Overnight + Duration --> Percent Change Columns

# %%
# Calculate percent change columns

analysis_df = quad_schedule_comparison_df.copy()

analysis_df['Schedule ID 0'] = analysis_df['Schedule ID 0'].fillna('')

# Extract nescac schedules with correct scores
nescac_schedule_analysis_df = analysis_df[analysis_df['Schedule ID 0'].str.contains('nescac')]

# Extract optimized schedules with correct scores
optimized_schedule_analysis_df = analysis_df[~analysis_df['Schedule ID 0'].str.contains('nescac')]

# Prevent setting with copy warning
nescac_schedule_analysis_df = nescac_schedule_analysis_df.copy()

# Add optimized change columns
for opt_idx, opt_row in optimized_schedule_analysis_df.iterrows():

    opt_abbrev_sched_id = opt_row['Abbreviated Schedule ID']

    for nes_idx, nes_row in nescac_schedule_analysis_df.iterrows():

        nescac_schedule_analysis_df.loc[nes_idx, "{} (Average) Team Duration in Hours Average Percent Change".format(opt_abbrev_sched_id)] = calculate_column_percent_change_optimized_nescac(opt_row, nes_row, 'Team Duration in Hours Average', '(Average) ')

        nescac_schedule_analysis_df.loc[nes_idx, "{} (Average) Team Overnight Average Percent Change".format(opt_abbrev_sched_id)] = calculate_column_percent_change_optimized_nescac(opt_row, nes_row, 'Team Overnight Average', '(Average) ')

# Recombine into one DataFrame
analysis_df = optimized_schedule_analysis_df.append(nescac_schedule_analysis_df)

quad_schedule_comparison_df = analysis_df.copy()

display(quad_schedule_comparison_df[quad_schedule_comparison_df.columns[-8:]].tail())
# Out:
#     q2_1_3 (Average) Team Duration in Hours Average Percent Change  \
# 18                                         -23.819742
# 19                                         -22.149123
# 20                                         -23.901393
# 21                                         -24.226254
# 22                                         -23.819742
#
#     q2_1_3 (Average) Team Overnight Average Percent Change  \
# 18                                         -28.000000
# 19                                         -25.773196
# 20                                         -28.000000
# 21                                         -28.000000
# 22                                         -27.272727
#
#     q13_2_3 (Average) Team Duration in Hours Average Percent Change  \
# 18                                         -18.133047
# 19                                         -16.337719
# 20                                         -18.220793
# 21                                         -18.569904
# ...

# %%
print("Creating quad schedule team duration in hours average percent change comparison bar chart ...")
plot_filename = plot_and_save_horizontal_bar_charts_min_max_mean(
    analysis_df=quad_schedule_comparison_df,
    column_names=("{} (Average) Team Duration in Hours Average Percent Change".format(sched_id_0), "{} (Average) Team Duration in Hours Average Percent Change".format(sched_id_1)),
    min_preferred_tuple=(True, True),
    fig_title="Team duration in hours average percent change.",
    subplot_titles=("{}".format(sched_id_0), "{}".format(sched_id_1)),
    nescac_mean_line=True,
    optimized_schedule_lines=False,
    plot_path=QUAD_RESULTS_PLOT_PATH)

print("Saving quad schedule team duration in hours average percent change comparison bar chart ...")
print("... Saved as \"{}\"\n".format(plot_filename))

print("Process complete.\n")
# Out:
# Creating quad schedule team duration in hours average percent change comparison bar chart ...
# Saving quad schedule team duration in hours average percent change comparison bar chart ...
# ... Saved as "results/quad/figures/team_duration_in_hours_average_percent_change.png"
#
# Process complete.

# %%
print("Creating quad schedule team overnight average percent change comparison bar chart ...")
plot_filename = plot_and_save_horizontal_bar_charts_min_max_mean(
    analysis_df=quad_schedule_comparison_df,
    column_names=("{} (Average) Team Overnight Average Percent Change".format(sched_id_0), "{} (Average) Team Overnight Average Percent Change".format(sched_id_1)),
    min_preferred_tuple=(True, True),
    fig_title="Team overnight average percent change.",
    subplot_titles=("{}".format(sched_id_0), "{}".format(sched_id_1)),
    nescac_mean_line=True,
    optimized_schedule_lines=False,
    plot_path=QUAD_RESULTS_PLOT_PATH)

print("Saving quad schedule team overnight average percent change comparison bar chart ...")
print("... Saved as \"{}\"\n".format(plot_filename))

print("Process complete.\n")
# Out:
# Creating quad schedule team overnight average percent change comparison bar chart ...
# Saving quad schedule team overnight average percent change comparison bar chart ...
# ... Saved as "results/quad/figures/team_overnight_average_percent_change.png"
#
# Process complete.

# %% [markdown]
# ## Team Location Experience

# %% [markdown]
# ### Team Different Locations

# %%
from src.configuration import *
from src.figures import *
# %matplotlib inline


print("Loading necessary information ...\n")
quad_schedule_comparison_df = pd.read_pickle(QUAD_SCHEDULE_COMPARISON_FILENAME)
quad_schedule_comparison_df = quad_schedule_comparison_df.iloc[selected_idxs].append(quad_schedule_comparison_df[15:23]).reset_index(drop=True)

print("Creating team different location comparison bar chart ...")
plot_filename = plot_and_save_horizontal_bar_charts_min_max_mean(
    analysis_df=quad_schedule_comparison_df,
    column_names=("Team Different Location Average", "Team Different Location Fairness Index"),
    min_preferred_tuple=(True, False),
    fig_title="Team different location comparison.",
    subplot_titles=("Average Values", "Fairness Index"),   
    nescac_mean_line=False,
    optimized_schedule_lines=True,    
    plot_path=QUAD_RESULTS_PLOT_PATH)

print("Saving team different location average and fairness index bar chart ...")
print("... Saved as \"{}\"\n".format(plot_filename))

print("Process complete.\n")
# Out:
# Loading necessary information ...
#
# Creating team different location comparison bar chart ...
# Saving team different location average and fairness index bar chart ...
# ... Saved as "results/quad/figures/team_different_location_comparison.png"
#
# Process complete.

# %% [markdown]
# ### Closer look @ team different location --> number + distribution

# %%
from src.configuration import *
from src.figures import *
# %matplotlib inline


print("Loading necessary information ...\n")
quad_schedule_comparison_df = pd.read_pickle(QUAD_SCHEDULE_COMPARISON_FILENAME)
quad_schedule_comparison_df = quad_schedule_comparison_df.iloc[selected_idxs].append(quad_schedule_comparison_df[15:23]).reset_index(drop=True)

# display(quad_schedule_comparison_df[[
#     'Abbreviated Schedule ID',
#     'Team Different Location Dict',
#     'Team Different Location Average'
# ]])

# average team different location dict values
# shorten abbreviated schedule IDs
quad_schedule_comparison_df['Average Team Different Location Dict'] = None
for idx, row in quad_schedule_comparison_df.iterrows():
    avg_dict = {} 
    for k, v in row['Team Different Location Dict'].items():
        avg_dict[k] = round(np.mean(v), 2)
    
    # optimized schedules
    if row['Abbreviated Schedule ID'][0] == 'q':
        quad_schedule_comparison_df['Abbreviated Schedule ID'][idx] = row['Abbreviated Schedule ID'][:7] + '...'
    # NESCAC schedules
    else:
        quad_schedule_comparison_df['Abbreviated Schedule ID'][idx] = 'nes_' + row['Abbreviated Schedule ID'][2:4] + '-' + row['Abbreviated Schedule ID'][-2:]
    
    quad_schedule_comparison_df['Average Team Different Location Dict'][idx] = avg_dict

    
display(quad_schedule_comparison_df[[
    'Abbreviated Schedule ID',
    'Team Different Location Dict',
    'Average Team Different Location Dict',
    'Team Different Location Average'
    
]]) 


print("Creating team different location swarplot ...")
plot_filename = plot_and_save_dict_column_team_swarmplot_chart(
    analysis_df=quad_schedule_comparison_df,
    dict_column_name="Average Team Different Location Dict",
    fig_title="Number of different locations per team.",
    venues_mapping_filename=VENUES_MAPPING_FILENAME, 
    plot_path=QUAD_RESULTS_PLOT_PATH)

print("Saving team different location swarmplot ...")
print("... Saved as \"{}\"\n".format(plot_filename))

print("Process complete.\n")
# Out:
# Loading necessary information ...
# /Users/hcederna/anaconda3/envs/schedule-optimization/lib/python3.7/site-packages/ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hcederna/anaconda3/envs/schedule-optimization/lib/python3.7/site-packages/ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hcederna/anaconda3/envs/schedule-optimization/lib/python3.7/site-packages/ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %% [markdown]
# ### Team Unique Locations

# %%
from src.configuration import *
from src.figures import *
# %matplotlib inline


print("Loading necessary information ...\n")
quad_schedule_comparison_df = pd.read_pickle(QUAD_SCHEDULE_COMPARISON_FILENAME)
quad_schedule_comparison_df = quad_schedule_comparison_df.iloc[selected_idxs].append(quad_schedule_comparison_df[15:23]).reset_index(drop=True)

print("Creating team unique location comparison bar chart ...")
plot_filename = plot_and_save_horizontal_bar_charts_min_max_mean(
    analysis_df=quad_schedule_comparison_df,
    column_names=("Team Unique Location Average", "Team Unique Location Fairness Index"),
    min_preferred_tuple=(True, False),
    fig_title="Team unique location comparison.",
    subplot_titles=("Average Values", "Fairness Index"),   
    nescac_mean_line=False,
    optimized_schedule_lines=True,    
    plot_path=QUAD_RESULTS_PLOT_PATH)

print("Saving team unique location average and fairness index bar chart ...")
print("... Saved as \"{}\"\n".format(plot_filename))

print("Process complete.\n")
# Out:
# Loading necessary information ...
#
# Creating team unique location comparison bar chart ...
# Saving team unique location average and fairness index bar chart ...
# ... Saved as "results/quad/figures/team_unique_location_comparison.png"
#
# Process complete.

# %% [markdown]
# ### Closer look @ team unique location --> number + distribution

# %%
from src.configuration import *
from src.figures import *
# %matplotlib inline


print("Loading necessary information ...\n")
quad_schedule_comparison_df = pd.read_pickle(QUAD_SCHEDULE_COMPARISON_FILENAME)
quad_schedule_comparison_df = quad_schedule_comparison_df.iloc[selected_idxs].append(quad_schedule_comparison_df[15:23]).reset_index(drop=True)


# shorten abbreviated schedule IDs
for idx, row in quad_schedule_comparison_df.iterrows():
    # optimized schedules
    if row['Abbreviated Schedule ID'][0] == 'q':
        quad_schedule_comparison_df['Abbreviated Schedule ID'][idx] = row['Abbreviated Schedule ID'][:7] + '...'
    # NESCAC schedules
    else:
        quad_schedule_comparison_df['Abbreviated Schedule ID'][idx] = 'nes_' + row['Abbreviated Schedule ID'][2:4] + '-' + row['Abbreviated Schedule ID'][-2:]
    
display(quad_schedule_comparison_df[[
    'Abbreviated Schedule ID',
    'Team Unique Location Dict'
]])

print("Creating team unique location swarplot ...")
plot_filename = plot_and_save_dict_column_team_swarmplot_chart(
    analysis_df=quad_schedule_comparison_df,
    dict_column_name="Team Unique Location Dict",
    fig_title="Number of unique locations per team.",
    venues_mapping_filename=VENUES_MAPPING_FILENAME, 
    plot_path=QUAD_RESULTS_PLOT_PATH)

print("Saving team unique location swarmplot ...")
print("... Saved as \"{}\"\n".format(plot_filename))

print("Process complete.\n")
# Out:
# Loading necessary information ...
# /Users/hcederna/anaconda3/envs/schedule-optimization/lib/python3.7/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# /Users/hcederna/anaconda3/envs/schedule-optimization/lib/python3.7/site-packages/ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Abbreviated Schedule ID                          Team Unique Location Dict
# 0              q6_1.5_...  {0: 9, 1: 7, 2: 7, 3: 7, 4: 7, 5: 8, 6: 9, 7: ...
# ...

# %% [markdown]
# ### Team Different + Unique Location --> Percent Change Columns

# %%
# Calculate percent change columns
quad_schedule_comparison_df = pd.read_pickle(QUAD_SCHEDULE_COMPARISON_FILENAME)
quad_schedule_comparison_df = quad_schedule_comparison_df.iloc[selected_idxs].append(quad_schedule_comparison_df[15:23]).reset_index(drop=True)

analysis_df = quad_schedule_comparison_df.copy()

analysis_df['Schedule ID 0'] = analysis_df['Schedule ID 0'].fillna('')

# Extract nescac schedules with correct scores
nescac_schedule_analysis_df = analysis_df[analysis_df['Schedule ID 0'].str.contains('nescac')]

# Extract optimized schedules with correct scores
optimized_schedule_analysis_df = analysis_df[~analysis_df['Schedule ID 0'].str.contains('nescac')]

# Prevent setting with copy warning
nescac_schedule_analysis_df = nescac_schedule_analysis_df.copy()

# Add optimized change columns
for opt_idx, opt_row in optimized_schedule_analysis_df.iterrows():

    opt_abbrev_sched_id = opt_row['Abbreviated Schedule ID']

    for nes_idx, nes_row in nescac_schedule_analysis_df.iterrows():

        nescac_schedule_analysis_df.loc[nes_idx, "{} Team Different Location Average Percent Change".format(opt_abbrev_sched_id)] = calculate_column_percent_change_optimized_nescac(opt_row, nes_row, 'Team Different Location Average', '')

        nescac_schedule_analysis_df.loc[nes_idx, "{} Team Unique Location Average Percent Change".format(opt_abbrev_sched_id)] = calculate_column_percent_change_optimized_nescac(opt_row, nes_row, 'Team Unique Location Average', '')

# Recombine into one DataFrame
analysis_df = optimized_schedule_analysis_df.append(nescac_schedule_analysis_df)

quad_schedule_comparison_df = analysis_df.copy()

display(quad_schedule_comparison_df[quad_schedule_comparison_df.columns[-8:]])
# Out:
#    q14_2_3 Total Duration in Hours Change  \
# 0                                     NaN
# 1                                     NaN
# 2                                   -68.0
# 3                                   -47.0
# 4                                  -104.0
# 5                                  -166.0
# 6                                  -145.0
# 7                                  -166.0
# 8                                  -169.0
# 9                                  -165.0
#
#    q14_2_3 Total Duration in Hours Percent Change  \
# 0                                             NaN
# 1                                             NaN
# 2                                       -8.124253
# 3                                       -5.759804
# 4                                      -11.912944
# 5                                      -17.754011
# 6                                      -15.864333
# 7                                      -17.754011
# ...

# %%
sched_id_0 = quad_schedule_comparison_df.loc[0]['Abbreviated Schedule ID']
sched_id_1 = quad_schedule_comparison_df.loc[1]['Abbreviated Schedule ID']

print("Creating quad schedule team different location average percent change comparison bar chart ...")
plot_filename = plot_and_save_horizontal_bar_charts_min_max_mean(
    analysis_df=quad_schedule_comparison_df,
    column_names=("{} Team Different Location Average Percent Change".format(sched_id_0), "{} Team Different Location Average Percent Change".format(sched_id_1)),
    min_preferred_tuple=(True, True),
    fig_title="Team different location average percent change.",
    subplot_titles=("{}".format(sched_id_0), "{}".format(sched_id_1)),
    nescac_mean_line=True,
    optimized_schedule_lines=False,
    plot_path=QUAD_RESULTS_PLOT_PATH)

print("Saving quad schedule team different location average percent change comparison bar chart ...")
print("... Saved as \"{}\"\n".format(plot_filename))

print("Process complete.\n")
# Out:
# Creating quad schedule team different location average percent change comparison bar chart ...
# Saving quad schedule team different location average percent change comparison bar chart ...
# ... Saved as "results/quad/figures/team_different_location_average_percent_change.png"
#
# Process complete.

# %%
sched_id_0 = quad_schedule_comparison_df.loc[0]['Abbreviated Schedule ID']
sched_id_1 = quad_schedule_comparison_df.loc[1]['Abbreviated Schedule ID']

print("Creating quad schedule team unique location average percent change comparison bar chart ...")
plot_filename = plot_and_save_horizontal_bar_charts_min_max_mean(
    analysis_df=quad_schedule_comparison_df,
    column_names=("{} Team Unique Location Average Percent Change".format(sched_id_0), "{} Team Unique Location Average Percent Change".format(sched_id_1)),
    min_preferred_tuple=(True, True),
    fig_title="Team unique location average percent change.",
    subplot_titles=("{}".format(sched_id_0), "{}".format(sched_id_1)),
    nescac_mean_line=True,
    optimized_schedule_lines=False,
    plot_path=QUAD_RESULTS_PLOT_PATH)

print("Saving quad schedule team unique location average percent change comparison bar chart ...")
print("... Saved as \"{}\"\n".format(plot_filename))

print("Process complete.\n")
# Out:
# Creating quad schedule team unique location average percent change comparison bar chart ...
# Saving quad schedule team unique location average percent change comparison bar chart ...
# ... Saved as "results/quad/figures/team_unique_location_average_percent_change.png"
#
# Process complete.

# %% [markdown]
# ## Score Metrics

# %%
from src.configuration import *
from src.figures import *
# %matplotlib inline


print("Loading necessary information ...\n")
quad_schedule_comparison_df = pd.read_pickle(QUAD_SCHEDULE_COMPARISON_FILENAME)
quad_schedule_comparison_df = quad_schedule_comparison_df.iloc[selected_idxs].append(quad_schedule_comparison_df[15:23]).reset_index(drop=True)

print("Creating schedule score components comparison bar chart ...")
plot_filename = plot_and_save_horizontal_bar_charts_min_max_mean(
    analysis_df=quad_schedule_comparison_df,
    column_names=("(Average) Team Experience Score", "Location Score"),
    min_preferred_tuple=(True, True),
    fig_title="Quad score components comparison.",
    subplot_titles=("Team Experience Score", "Location Score"),
    nescac_mean_line=False,
    optimized_schedule_lines=True,
    plot_path=QUAD_RESULTS_PLOT_PATH)

print("Saving schedule score components comparison bar chart ...")
print("... Saved as \"{}\"\n".format(plot_filename))

print("Process complete.\n")
# Out:
# Loading necessary information ...
#
# Creating schedule score components comparison bar chart ...
# Saving schedule score components comparison bar chart ...
# ... Saved as "results/quad/figures/quad_score_components_comparison.png"
#
# Process complete.

# %%
from src.configuration import *
from src.figures import *
# %matplotlib inline


print("Loading necessary information ...\n")
quad_schedule_comparison_df = pd.read_pickle(QUAD_SCHEDULE_COMPARISON_FILENAME)
quad_schedule_comparison_df = quad_schedule_comparison_df.iloc[selected_idxs].append(quad_schedule_comparison_df[15:23]).reset_index(drop=True)

print("Creating quad schedule score comparison bar chart ...")
plot_filename = plot_and_save_horizontal_bar_chart_min_max_mean(
    analysis_df=quad_schedule_comparison_df,
    column_name="Pair/Quad Score",
    min_preferred=True,
    fig_title="Quad schedule score comparison.",
    nescac_mean_line=False,
    plot_path=QUAD_RESULTS_PLOT_PATH)

print("Saving quad schedule score comparison bar chart ...")
print("... Saved as \"{}\"\n".format(plot_filename))

print("Process complete.\n")
# Out:
# Loading necessary information ...
#
# Creating quad schedule score comparison bar chart ...
# Saving quad schedule score comparison bar chart ...
# ... Saved as "results/quad/figures/quad_schedule_score_comparison.png"
#
# Process complete.

# %% [markdown]
# ## Review Schedules

# %%
# schedules in optimized quad
columns = [
    'Abbreviated Schedule ID',
    'Schedule ID 0',
    'Schedule ID 1',
    'Schedule ID 2',
    'Schedule ID 3',
]

quad_schedule_comparison_df = pd.read_pickle(QUAD_SCHEDULE_COMPARISON_FILENAME)
quad_schedule_comparison_df = quad_schedule_comparison_df.iloc[selected_idxs]

display(quad_schedule_comparison_df[columns])
# Out:
#   Abbreviated Schedule ID                      Schedule ID 0  \
# 1                q6_1.5_3   3_2215_optimized_team_schedule_0
# 4              q11_1.75_3  15_2335_optimized_team_schedule_0
#
#                       Schedule ID 1                     Schedule ID 2  \
# 1  8_2315_optimized_team_schedule_0  5_2235_optimized_team_schedule_1
# 4  5_2235_optimized_team_schedule_0  5_2235_optimized_team_schedule_1
#
#                        Schedule ID 3
# 1  14_2234_optimized_team_schedule_0
# 4  14_2234_optimized_team_schedule_0

# %%
# Adjust idx value to review schedules
# idx = 0 --> q6_1.5_3 schedule quad
# idx = 1 --> q11_1.75_3 schedule quad
idx = 0

quad_schedule_comparison_df = pd.read_pickle(QUAD_SCHEDULE_COMPARISON_FILENAME)
quad_schedule_comparison_df = quad_schedule_comparison_df.iloc[selected_idxs]
_ = quad_schedule_comparison_df.iloc[idx]
display(_[columns])
# Out:
# Abbreviated Schedule ID                             q6_1.5_3
# Schedule ID 0               3_2215_optimized_team_schedule_0
# Schedule ID 1               8_2315_optimized_team_schedule_0
# Schedule ID 2               5_2235_optimized_team_schedule_1
# Schedule ID 3              14_2234_optimized_team_schedule_0
# Name: 1, dtype: object

# %%
# review full schedule
# toggle and untoggle display lines to review full schedule or full schedule grouped by week
for col_name, schedule in _[columns].items():
    if "Abbreviated" not in col_name:
        
        print('##############')
        print('# SCHEDULE ' + col_name[-1] + ' #')
        print('##############')

        schedule_df = pd.read_csv(f"results/quad/optimized_schedules/{schedule.replace('team_', '')}.csv", index_col=0)
        
#         display(schedule_df)

        # review schedule grouped by week
        for week, week_df in schedule_df.groupby('Week'):
            display(week_df)
# Out:
# ##############
# # SCHEDULE 0 #
# ##############
#     Week Day (Str)  Time Slot               Team 1               Team 2  \
# 0      0      Fri.          0        Bates College      Amherst College
# 1      0      Fri.          1      Bowdoin College   Middlebury College
# 2      0      Fri.          2        Colby College     Williams College
# 3      0      Sat.          3      Bowdoin College      Amherst College
# 4      0      Sat.          4        Bates College   Middlebury College
# 5      0      Sat.          5        Colby College   Middlebury College
# 6      0      Sat.          6      Bowdoin College     Williams College
# 7      0      Sat.          7        Colby College      Amherst College
# 8      0      Sat.          8        Bates College     Williams College
# 9      0      Sat.          0     Hamilton College     Tufts University
# 10     0      Fri.          0      Trinity College  Connecticut College
# ...

# %%
# review team schedules
# toggle and untoggle display lines to review team schedules grouped by team or team and week
for col_name, schedule in _[columns].items():
    if "Abbreviated" not in col_name:
        
        print('##############')
        print('# SCHEDULE ' + col_name[-1] + ' #')
        print('##############')

        schedule_df = pd.read_csv(f"results/quad/optimized_schedules/{schedule}.csv", index_col=0)
    
        for team_1,team_1_df in schedule_df.groupby('Team 1'):
            print(team_1)
            
#             # review team schedule grouped by team
#             display(team_1_df)
            
            # review team schedule grouped by team and week
            for week, week_df in team_1_df.groupby('Week'):
                display(week_df)
# Out:
# ##############
# # SCHEDULE 0 #
# ##############
# Amherst College
#    Week Day (Str)  Time Slot           Team 1           Team 2       Location
# 0     0      Fri.          0  Amherst College    Bates College  Bates College
# 1     0      Sat.          3  Amherst College  Bowdoin College  Bates College
# 2     0      Sat.          7  Amherst College    Colby College  Bates College
#    Week Day (Str)  Time Slot           Team 1            Team 2  \
# 3     1      Sat.          1  Amherst College  Tufts University
#
#            Location
# 3  Tufts University
#    Week Day (Str)  Time Slot           Team 1            Team 2  \
# 4     2      Fri.          0  Amherst College  Hamilton College
#
#            Location
# 4  Williams College
#    Week Day (Str)  Time Slot           Team 1              Team 2  \
# 5     3      Sat.          1  Amherst College  Middlebury College
# 6     3      Sat.          2  Amherst College    Williams College
#
#              Location
# ...

# %% [markdown]
# ## Check Schedules

# %%
# schedules in optimized quad
columns = [
    'Abbreviated Schedule ID',
    'Schedule ID 0',
    'Schedule ID 1',
    'Schedule ID 2',
    'Schedule ID 3',
]

optimized_schedule_analysis_df = pd.read_pickle(OPTIMIZED_SCHEDULE_ANALYSIS_FILENAME)
quad_schedule_comparison_df = pd.read_pickle(QUAD_SCHEDULE_COMPARISON_FILENAME)
quad_schedule_comparison_df = quad_schedule_comparison_df.iloc[selected_idxs]

name_to_id_mapping = create_venue_id_mapping_dicts_from_file(VENUES_MAPPING_FILENAME)[0]
venue_one_way_distance_matrix = pd.read_csv(DISTANCE_MATRIX_FILENAME, index_col=0)
venue_one_way_duration_matrix_hhmm = pd.read_csv(DURATION_MATRIX_HHMM_FILENAME, index_col=0)

display(quad_schedule_comparison_df[columns])
# Out:
#   Abbreviated Schedule ID                      Schedule ID 0  \
# 1                q6_1.5_3   3_2215_optimized_team_schedule_0
# 4              q11_1.75_3  15_2335_optimized_team_schedule_0
#
#                       Schedule ID 1                     Schedule ID 2  \
# 1  8_2315_optimized_team_schedule_0  5_2235_optimized_team_schedule_1
# 4  5_2235_optimized_team_schedule_0  5_2235_optimized_team_schedule_1
#
#                        Schedule ID 3
# 1  14_2234_optimized_team_schedule_0
# 4  14_2234_optimized_team_schedule_0

# %%
# create list of schedules included in our schedule quads
filenames = []
for idx in [0, 1]:
    for col_name, schedule in quad_schedule_comparison_df[columns].iloc[idx].items():
        if "Abbreviated" not in col_name:
            filenames.append(f"{schedule}.csv")
            
filenames
# Out:
# ['3_2215_optimized_team_schedule_0.csv',
#  '8_2315_optimized_team_schedule_0.csv',
#  '5_2235_optimized_team_schedule_1.csv',
#  '14_2234_optimized_team_schedule_0.csv',
#  '15_2335_optimized_team_schedule_0.csv',
#  '5_2235_optimized_team_schedule_0.csv',
#  '5_2235_optimized_team_schedule_1.csv',
#  '14_2234_optimized_team_schedule_0.csv']

# %%
from src.configuration import WEEKEND_OVERNIGHT_THRESHOLD, DISTANCE_OVERNIGHT_THRESHOLD

print(f"WEEKEND_OVERNIGHT_THRESHOLD = {WEEKEND_OVERNIGHT_THRESHOLD}")
print("""
    \tMaximum number of miles to drive one-way without staying for an
    \tovernight between Friday and Saturday matches (recommended = 53
    \t==> max one-way distance with duration < 1 hour)
    """)
      
print(f"DISTANCE_OVERNIGHT_THRESHOLD = {DISTANCE_OVERNIGHT_THRESHOLD}")
print("""
    \tMaximum number of miles to drive one-way without staying for an
    \tovernight (recommended = 153 ==> max one-way distance with duration
    \t< 3 hours)
    """)


for filename in filenames[:2]:
    
    print("########################################")
    print(f"# {filename} #")
    print("########################################")

    schedule_df = pd.read_csv(f"results/quad/optimized_schedules/{filename}", index_col=0)

    schedule_df['Home Game'] = schedule_df['Team 1'] == schedule_df['Location']
    schedule_df['Team 1 Name'] = schedule_df['Team 1']
    schedule_df['Location Name'] = schedule_df['Location']
    schedule_df['Team 1'] = schedule_df['Team 1'].map(name_to_id_mapping)
    schedule_df['Location'] = schedule_df['Location'].map(name_to_id_mapping)

    schedule_df['Team 1 Travel Distance (mi)'] = None
    schedule_df['Team 1 Travel Distance (hhmm)'] = None
    for idx, row in schedule_df.iterrows():
        schedule_df['Team 1 Travel Distance (mi)'][idx] = venue_one_way_distance_matrix.iloc[row['Team 1'], row['Location']]
        schedule_df['Team 1 Travel Distance (hhmm)'][idx] = venue_one_way_duration_matrix_hhmm.iloc[row['Team 1'], row['Location']]


    schedule_df['Distance Overnight'] = False
    schedule_df['Weekend Overnight'] = False
    for team_week, team_week_df in schedule_df.groupby(['Team 1', 'Week']):

        team_week_df = team_week_df.reset_index(drop=False)
        curr_team = team_week[0]

        # Iterate over team 1 matches for the week
        for idx, row in team_week_df.iterrows():
            current_match = team_week_df.loc[idx]
            schedule_df_idx = current_match['index']

            # Check for a distance overnight
            if is_distance_overnight(current_match, venue_one_way_distance_matrix, DISTANCE_OVERNIGHT_THRESHOLD):
                schedule_df['Distance Overnight'][schedule_df_idx] = True

            # Check for a weekend overnight
            if idx > 0:
                previous_match = team_week_df.loc[idx - 1]

                if is_weekend_overnight(previous_match, current_match, venue_one_way_distance_matrix, WEEKEND_OVERNIGHT_THRESHOLD):

                    # Count weekend overnight
                    schedule_df['Weekend Overnight'][schedule_df_idx] = True

                    # Remove distance overnight because have weekend overnight ==> already staying overnight
                    schedule_df['Distance Overnight'][schedule_df_idx] = False

                    break

    # Display results                
    columns = [
        'Week',
        'Day (Str)',
        'Time Slot',
        'Team 1 Name',
        'Team 2',
        'Location Name',
        'Home Game',
        'Team 1 Travel Distance (mi)',
        'Team 1 Travel Distance (hhmm)',
        'Distance Overnight',
        'Weekend Overnight'
    ]

    # for team_1_group_name, team_1_group in _.groupby('Team 1'):

    #         display(team_1_group[columns])
    #         print(single_schedule_comparison_df['Team Overnight Dict'][0][team_1_group_name])

    optimized_schedule_analysis_df = pd.read_pickle(OPTIMIZED_SCHEDULE_ANALYSIS_FILENAME)

    for team_1, team_1_df in schedule_df.groupby('Team 1'):

        print(f"TEAM {team_1}")
        _ = optimized_schedule_analysis_df[optimized_schedule_analysis_df['Schedule ID'] == filename[:-4]]
        print(f"   overnight = {_['Team Overnight Dict'].item()[team_1]}")
        print(f"   distance = {_['Team Distance Dict'].item()[team_1]}")

        display(team_1_df)

    #     for week, week_df in team_1_df.groupby('Week'):

    #         display(week_df[columns])
# Out:
# WEEKEND_OVERNIGHT_THRESHOLD = 53
#
#     	Maximum number of miles to drive one-way without staying for an
#     	overnight between Friday and Saturday matches (recommended = 53
#     	==> max one-way distance with duration < 1 hour)
#
# DISTANCE_OVERNIGHT_THRESHOLD = 153
#
#     	Maximum number of miles to drive one-way without staying for an
#     	overnight (recommended = 153 ==> max one-way distance with duration
#     	< 3 hours)
#
# ########################################
# # 3_2215_optimized_team_schedule_0.csv #
# ########################################
# /Users/hcederna/anaconda3/envs/schedule-optimization/lib/python3.7/site-packages/ipykernel_launcher.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...
